# %% [markdown]
# # Imports

# %%
from math import ceil
import json
import os
import sys

src_path = os.path.join(os.path.dirname(os.path.abspath('')), 'src')
sys.path.append(src_path)

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve, classification_report
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import visdom

from datasets import link_prediction
from layers import MeanAggregator, LSTMAggregator, MaxPoolAggregator, MeanPoolAggregator
import models
import utils

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set up arguments for datasets, models and training.

# %%
args = {
    "task" : "link_prediction",
    
    "dataset" : "IAContactsHypertext",
    "dataset_path" : "/Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contacts_hypertext2009/ia-contacts_hypertext2009.edges",
    "mode" : "train",
    "generate_neg_examples" : False,
    
    "duplicate_examples" : False,
    "repeat_examples" : True,
    
    "self_loop" : True,
    "normalize_adj" : False,
    
    "cuda" : "True",
    "model" : "GraphSAGE",
    "agg_class" : "MeanAggregator",
    "hidden_dims" : [32],
    "dropout" : 0,
    "num_samples" : -1,
    
    "epochs" : 15,
    "batch_size" : 32,
    "lr" : 1e-3,
    "weight_decay" : 1e-3,
    "stats_per_batch" : 3,
    "visdom" : True,
    
    "load" : False,
    "save" : False
}
config = args
config['num_layers'] = len(config['hidden_dims']) + 1


if config['cuda'] and torch.cuda.is_available():
    device = 'cuda:0'
else:
    device = 'cpu'
config['device'] = device

# %% [markdown]
# # Get the dataset, dataloader and model.

# %%
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'train',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contacts_hypertext2009/ia-contacts_hypertext2009.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: train
# Number of vertices: 113
# Number of static edges: 1010
# Number of temporal edges: 6245
# Number of examples/datapoints: 1722
# --------------------------------

# %%
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=True, collate_fn=dataset.collate_wrapper)
input_dim, output_dim = dataset.get_dims()

# %%
agg_class = utils.get_agg_class(config['agg_class'])
model = models.GraphSAGE(input_dim, config['hidden_dims'],
                         output_dim, config['dropout'],
                         agg_class, config['num_samples'],
                         config['device'])
model.to(config['device'])
print(model)
# Out:
# GraphSAGE(
#   (aggregators): ModuleList(
#     (0): MeanAggregator()
#     (1): MeanAggregator()
#   )
#   (fcs): ModuleList(
#     (0): Linear(in_features=226, out_features=32, bias=True)
#     (1): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dropout): Dropout(p=0)
#   (relu): ReLU()
# )

# %% [markdown]
# # Compute ROC-AUC score for the untrained model.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset before training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset before training.
#     Batch 1 / 54
#     Batch 2 / 54
#     Batch 3 / 54
#     Batch 4 / 54
#     Batch 5 / 54
#     Batch 6 / 54
#     Batch 7 / 54
#     Batch 8 / 54
#     Batch 9 / 54
#     Batch 10 / 54
#     Batch 11 / 54
#     Batch 12 / 54
#     Batch 13 / 54
#     Batch 14 / 54
#     Batch 15 / 54
#     Batch 16 / 54
#     Batch 17 / 54
#     Batch 18 / 54
#     Batch 19 / 54
#     Batch 20 / 54
#     Batch 21 / 54
#     Batch 22 / 54
#     Batch 23 / 54
#     Batch 24 / 54
#     Batch 25 / 54
#     Batch 26 / 54
#     Batch 27 / 54
#     Batch 28 / 54
#     Batch 29 / 54
#     Batch 30 / 54
#     Batch 31 / 54
#     Batch 32 / 54
#     Batch 33 / 54
#     Batch 34 / 54
#     Batch 35 / 54
#     Batch 36 / 54
#     Batch 37 / 54
#     Batch 38 / 54
#     Batch 39 / 54
#     Batch 40 / 54
#     Batch 41 / 54
#     Batch 42 / 54
#     Batch 43 / 54
#     Batch 44 / 54
#     Batch 45 / 54
#     Batch 46 / 54
#     Batch 47 / 54
#     Batch 48 / 54
#     Batch 49 / 54
#     Batch 50 / 54
#     Batch 51 / 54
#     Batch 52 / 54
#     Batch 53 / 54
#     Batch 54 / 54
# ROC-AUC score: 0.5028
# --------------------------------

# %% [markdown]
# # Train.

# %%
if not config['load']:
    use_visdom = config['visdom']
    if use_visdom:
        vis = visdom.Visdom()
        loss_window = None
    criterion = utils.get_criterion(config['task'])
    optimizer = optim.Adam(model.parameters(), lr=config['lr'],
                           weight_decay=config['weight_decay'])
    epochs = config['epochs']
    stats_per_batch = config['stats_per_batch']
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    # scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=150, gamma=0.8)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[80, 400], gamma=0.7)
    model.train()
    print('--------------------------------')
    print('Training.')
    for epoch in range(epochs):
        print('Epoch {} / {}'.format(epoch+1, epochs))
        running_loss = 0.0
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            loss = criterion(scores, labels.float())
            loss.backward()
            optimizer.step()
            with torch.no_grad():
                running_loss += loss.item()
            if (idx + 1) % stats_per_batch == 0:
                running_loss /= stats_per_batch
                print('    Batch {} / {}: loss {:.4f}'.format(
                    idx+1, num_batches, running_loss))
                if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
                    area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
                    print('    ROC-AUC score: {:.4f}'.format(area))
                running_loss = 0.0
                num_correct, num_examples = 0, 0
            if use_visdom:
                if loss_window is None:
                    loss_window = vis.line(
                        Y=[loss.item()],
                        X=[epoch*num_batches+idx],
                        opts=dict(xlabel='batch', ylabel='Loss', title='Training Loss', legend=['Loss']))
                else:
                    vis.line(
                        [loss.item()],
                        [epoch*num_batches+idx],
                        win=loss_window,
                        update='append')
            scheduler.step()
    if use_visdom:
        vis.close(win=loss_window)
    print('Finished training.')
    print('--------------------------------')
# Out:
# WARNING:root:Setting up a new session...
# --------------------------------
# Training.
# Epoch 1 / 15
#     Batch 3 / 54: loss 0.6931
#     ROC-AUC score: 0.3008
#     Batch 6 / 54: loss 0.6939
#     ROC-AUC score: 0.4235
#     Batch 9 / 54: loss 0.6927
#     ROC-AUC score: 0.5437
#     Batch 12 / 54: loss 0.6931
#     ROC-AUC score: 0.5958
#     Batch 15 / 54: loss 0.6935
#     ROC-AUC score: 0.3725
#     Batch 18 / 54: loss 0.6932
#     ROC-AUC score: 0.4291
#     Batch 21 / 54: loss 0.6940
#     ROC-AUC score: 0.5325
#     Batch 24 / 54: loss 0.6930
#     ROC-AUC score: 0.4841
#     Batch 27 / 54: loss 0.6934
#     ROC-AUC score: 0.4180
#     Batch 30 / 54: loss 0.6928
#     ROC-AUC score: 0.5397
#     Batch 33 / 54: loss 0.6927
#     ROC-AUC score: 0.6316
#     Batch 36 / 54: loss 0.6916
#     ROC-AUC score: 0.6431
#     Batch 39 / 54: loss 0.6919
#     ROC-AUC score: 0.5352
#     Batch 42 / 54: loss 0.6918
#     ROC-AUC score: 0.5098
#     Batch 45 / 54: loss 0.6930
#     ROC-AUC score: 0.5873
#     Batch 48 / 54: loss 0.6918
#     ROC-AUC score: 0.6746
#     Batch 51 / 54: loss 0.6916
#     ROC-AUC score: 0.4603
#     Batch 54 / 54: loss 0.6906
#     ROC-AUC score: 0.5375
# Epoch 2 / 15
#     Batch 3 / 54: loss 0.6902
#     ROC-AUC score: 0.4372
#     Batch 6 / 54: loss 0.6892
#     ROC-AUC score: 0.6944
#     Batch 9 / 54: loss 0.6868
#     ROC-AUC score: 0.7059
#     Batch 12 / 54: loss 0.6850
#     ROC-AUC score: 0.6071
#     Batch 15 / 54: loss 0.6790
#     ROC-AUC score: 0.7773
#     Batch 18 / 54: loss 0.6805
#     ROC-AUC score: 0.7458
#     Batch 21 / 54: loss 0.6690
#     ROC-AUC score: 0.7792
#     Batch 24 / 54: loss 0.6746
#     ROC-AUC score: 0.6445
#     Batch 27 / 54: loss 0.6675
#     ROC-AUC score: 0.7922
#     Batch 30 / 54: loss 0.6765
#     ROC-AUC score: 0.7549
#     Batch 33 / 54: loss 0.6581
#     ROC-AUC score: 0.7961
#     Batch 36 / 54: loss 0.6647
#     ROC-AUC score: 0.5873
#     Batch 39 / 54: loss 0.6643
#     ROC-AUC score: 0.6863
#     Batch 42 / 54: loss 0.7032
#     ROC-AUC score: 0.5437
#     Batch 45 / 54: loss 0.6628
#     ROC-AUC score: 0.7083
#     Batch 48 / 54: loss 0.6683
#     ROC-AUC score: 0.6190
#     Batch 51 / 54: loss 0.6665
#     ROC-AUC score: 0.7031
#     Batch 54 / 54: loss 0.6566
#     ROC-AUC score: 0.7091
# Epoch 3 / 15
#     Batch 3 / 54: loss 0.6506
#     ROC-AUC score: 0.6902
#     Batch 6 / 54: loss 0.6333
#     ROC-AUC score: 0.9294
#     Batch 9 / 54: loss 0.6505
#     ROC-AUC score: 0.7421
#     Batch 12 / 54: loss 0.6448
#     ROC-AUC score: 0.6750
#     Batch 15 / 54: loss 0.6266
#     ROC-AUC score: 0.6926
#     Batch 18 / 54: loss 0.6337
#     ROC-AUC score: 0.9307
#     Batch 21 / 54: loss 0.6549
#     ROC-AUC score: 0.7183
#     Batch 24 / 54: loss 0.5910
#     ROC-AUC score: 0.9028
#     Batch 27 / 54: loss 0.6327
#     ROC-AUC score: 0.6273
#     Batch 30 / 54: loss 0.6520
#     ROC-AUC score: 0.7576
#     Batch 33 / 54: loss 0.6228
#     ROC-AUC score: 0.7922
#     Batch 36 / 54: loss 0.5956
#     ROC-AUC score: 0.8235
#     Batch 39 / 54: loss 0.6517
#     ROC-AUC score: 0.7328
#     Batch 42 / 54: loss 0.6570
#     ROC-AUC score: 0.6353
#     Batch 45 / 54: loss 0.6771
#     ROC-AUC score: 0.6151
#     Batch 48 / 54: loss 0.6816
#     ROC-AUC score: 0.6417
#     Batch 51 / 54: loss 0.6430
#     ROC-AUC score: 0.6602
#     Batch 54 / 54: loss 0.6352
#     ROC-AUC score: 0.8000
# Epoch 4 / 15
#     Batch 3 / 54: loss 0.6051
#     ROC-AUC score: 0.7698
#     Batch 6 / 54: loss 0.6256
#     ROC-AUC score: 0.7686
#     Batch 9 / 54: loss 0.6288
#     ROC-AUC score: 0.6623
#     Batch 12 / 54: loss 0.5921
#     ROC-AUC score: 0.8438
#     Batch 15 / 54: loss 0.6131
#     ROC-AUC score: 0.7698
#     Batch 18 / 54: loss 0.6225
#     ROC-AUC score: 0.7765
#     Batch 21 / 54: loss 0.6738
#     ROC-AUC score: 0.6478
#     Batch 24 / 54: loss 0.5942
#     ROC-AUC score: 0.7085
#     Batch 27 / 54: loss 0.6184
#     ROC-AUC score: 0.7500
#     Batch 30 / 54: loss 0.6503
#     ROC-AUC score: 0.6549
#     Batch 33 / 54: loss 0.6250
#     ROC-AUC score: 0.6923
#     Batch 36 / 54: loss 0.5933
#     ROC-AUC score: 0.5789
#     Batch 39 / 54: loss 0.6232
#     ROC-AUC score: 0.7843
#     Batch 42 / 54: loss 0.6640
#     ROC-AUC score: 0.6865
#     Batch 45 / 54: loss 0.5980
#     ROC-AUC score: 0.7333
#     Batch 48 / 54: loss 0.6101
#     ROC-AUC score: 0.7137
#     Batch 51 / 54: loss 0.6475
#     ROC-AUC score: 0.6923
#     Batch 54 / 54: loss 0.6465
#     ROC-AUC score: 0.7688
# Epoch 5 / 15
#     Batch 3 / 54: loss 0.6273
#     ROC-AUC score: 0.7247
#     Batch 6 / 54: loss 0.6430
#     ROC-AUC score: 0.6863
#     Batch 9 / 54: loss 0.5734
#     ROC-AUC score: 0.8178
#     Batch 12 / 54: loss 0.6217
#     ROC-AUC score: 0.8455
#     Batch 15 / 54: loss 0.6150
#     ROC-AUC score: 0.7619
#     Batch 18 / 54: loss 0.5685
#     ROC-AUC score: 0.8196
#     Batch 21 / 54: loss 0.6229
#     ROC-AUC score: 0.7262
#     Batch 24 / 54: loss 0.6859
#     ROC-AUC score: 0.6157
#     Batch 27 / 54: loss 0.5892
#     ROC-AUC score: 0.7137
#     Batch 30 / 54: loss 0.6113
#     ROC-AUC score: 0.8175
#     Batch 33 / 54: loss 0.5871
#     ROC-AUC score: 0.7348
#     Batch 36 / 54: loss 0.5769
#     ROC-AUC score: 0.8095
#     Batch 39 / 54: loss 0.5902
#     ROC-AUC score: 0.8359
#     Batch 42 / 54: loss 0.5993
#     ROC-AUC score: 0.7569
#     Batch 45 / 54: loss 0.6304
#     ROC-AUC score: 0.6508
#     Batch 48 / 54: loss 0.6368
#     ROC-AUC score: 0.6680
#     Batch 51 / 54: loss 0.5887
#     ROC-AUC score: 0.6773
#     Batch 54 / 54: loss 0.6814
#     ROC-AUC score: 0.4510
# Epoch 6 / 15
#     Batch 3 / 54: loss 0.5992
#     ROC-AUC score: 0.7488
#     Batch 6 / 54: loss 0.5899
#     ROC-AUC score: 0.7958
#     Batch 9 / 54: loss 0.6506
#     ROC-AUC score: 0.6875
#     Batch 12 / 54: loss 0.6060
#     ROC-AUC score: 0.8196
#     Batch 15 / 54: loss 0.6336
#     ROC-AUC score: 0.6964
#     Batch 18 / 54: loss 0.6905
#     ROC-AUC score: 0.6437
#     Batch 21 / 54: loss 0.6172
#     ROC-AUC score: 0.8658
#     Batch 24 / 54: loss 0.5845
#     ROC-AUC score: 0.7937
#     Batch 27 / 54: loss 0.5909
#     ROC-AUC score: 0.8980
#     Batch 30 / 54: loss 0.5913
#     ROC-AUC score: 0.7373
#     Batch 33 / 54: loss 0.5995
#     ROC-AUC score: 0.8516
#     Batch 36 / 54: loss 0.5840
#     ROC-AUC score: 0.8906
#     Batch 39 / 54: loss 0.6120
#     ROC-AUC score: 0.7053
#     Batch 42 / 54: loss 0.5901
#     ROC-AUC score: 0.8235
#     Batch 45 / 54: loss 0.6106
#     ROC-AUC score: 0.7063
#     Batch 48 / 54: loss 0.6072
#     ROC-AUC score: 0.6941
#     Batch 51 / 54: loss 0.5724
#     ROC-AUC score: 0.7206
#     Batch 54 / 54: loss 0.6081
#     ROC-AUC score: 0.7250
# Epoch 7 / 15
#     Batch 3 / 54: loss 0.5722
#     ROC-AUC score: 0.7625
#     Batch 6 / 54: loss 0.5888
#     ROC-AUC score: 0.8549
#     Batch 9 / 54: loss 0.6053
#     ROC-AUC score: 0.7930
#     Batch 12 / 54: loss 0.6143
#     ROC-AUC score: 0.6468
#     Batch 15 / 54: loss 0.6273
#     ROC-AUC score: 0.6824
#     Batch 18 / 54: loss 0.5892
#     ROC-AUC score: 0.8633
#     Batch 21 / 54: loss 0.6038
#     ROC-AUC score: 0.7611
#     Batch 24 / 54: loss 0.6332
#     ROC-AUC score: 0.8788
#     Batch 27 / 54: loss 0.5728
#     ROC-AUC score: 0.7738
#     Batch 30 / 54: loss 0.5689
#     ROC-AUC score: 0.7375
#     Batch 33 / 54: loss 0.6013
#     ROC-AUC score: 0.8865
#     Batch 36 / 54: loss 0.6307
#     ROC-AUC score: 0.6863
#     Batch 39 / 54: loss 0.6323
#     ROC-AUC score: 0.6667
#     Batch 42 / 54: loss 0.5893
#     ROC-AUC score: 0.8340
#     Batch 45 / 54: loss 0.6271
#     ROC-AUC score: 0.6706
#     Batch 48 / 54: loss 0.5691
#     ROC-AUC score: 0.8706
#     Batch 51 / 54: loss 0.6488
#     ROC-AUC score: 0.7686
#     Batch 54 / 54: loss 0.5849
#     ROC-AUC score: 0.9053
# Epoch 8 / 15
#     Batch 3 / 54: loss 0.5864
#     ROC-AUC score: 0.8373
#     Batch 6 / 54: loss 0.6265
#     ROC-AUC score: 0.6914
#     Batch 9 / 54: loss 0.5708
#     ROC-AUC score: 0.8667
#     Batch 12 / 54: loss 0.5960
#     ROC-AUC score: 0.7579
#     Batch 15 / 54: loss 0.5884
#     ROC-AUC score: 0.7686
#     Batch 18 / 54: loss 0.5486
#     ROC-AUC score: 0.7843
#     Batch 21 / 54: loss 0.5843
#     ROC-AUC score: 0.8471
#     Batch 24 / 54: loss 0.5777
#     ROC-AUC score: 0.6292
#     Batch 27 / 54: loss 0.6063
#     ROC-AUC score: 0.6232
#     Batch 30 / 54: loss 0.5458
#     ROC-AUC score: 0.8000
#     Batch 33 / 54: loss 0.6117
#     ROC-AUC score: 0.6708
#     Batch 36 / 54: loss 0.6620
#     ROC-AUC score: 0.6865
#     Batch 39 / 54: loss 0.6347
#     ROC-AUC score: 0.6599
#     Batch 42 / 54: loss 0.6025
#     ROC-AUC score: 0.8792
#     Batch 45 / 54: loss 0.6053
#     ROC-AUC score: 0.8477
#     Batch 48 / 54: loss 0.6054
#     ROC-AUC score: 0.8477
#     Batch 51 / 54: loss 0.6393
#     ROC-AUC score: 0.5742
#     Batch 54 / 54: loss 0.5812
#     ROC-AUC score: 0.9030
# Epoch 9 / 15
#     Batch 3 / 54: loss 0.5346
#     ROC-AUC score: 0.8042
#     Batch 6 / 54: loss 0.5734
#     ROC-AUC score: 0.7578
#     Batch 9 / 54: loss 0.6242
#     ROC-AUC score: 0.7059
#     Batch 12 / 54: loss 0.6366
#     ROC-AUC score: 0.7368
#     Batch 15 / 54: loss 0.6224
#     ROC-AUC score: 0.8502
#     Batch 18 / 54: loss 0.5563
#     ROC-AUC score: 0.7318
#     Batch 21 / 54: loss 0.5807
#     ROC-AUC score: 0.8320
#     Batch 24 / 54: loss 0.5882
#     ROC-AUC score: 0.9059
#     Batch 27 / 54: loss 0.6659
#     ROC-AUC score: 0.6154
#     Batch 30 / 54: loss 0.5735
#     ROC-AUC score: 0.8135
#     Batch 33 / 54: loss 0.5623
#     ROC-AUC score: 0.8353
#     Batch 36 / 54: loss 0.5733
#     ROC-AUC score: 0.8214
#     Batch 39 / 54: loss 0.5994
#     ROC-AUC score: 0.6627
#     Batch 42 / 54: loss 0.5123
#     ROC-AUC score: 0.8745
#     Batch 45 / 54: loss 0.6387
#     ROC-AUC score: 0.5882
#     Batch 48 / 54: loss 0.6516
#     ROC-AUC score: 0.6407
#     Batch 51 / 54: loss 0.6346
#     ROC-AUC score: 0.7451
#     Batch 54 / 54: loss 0.6008
#     ROC-AUC score: 0.6982
# Epoch 10 / 15
#     Batch 3 / 54: loss 0.5344
#     ROC-AUC score: 0.8633
#     Batch 6 / 54: loss 0.5549
#     ROC-AUC score: 0.8333
#     Batch 9 / 54: loss 0.6218
#     ROC-AUC score: 0.5635
#     Batch 12 / 54: loss 0.6474
#     ROC-AUC score: 0.7143
#     Batch 15 / 54: loss 0.5877
#     ROC-AUC score: 0.7695
#     Batch 18 / 54: loss 0.5437
#     ROC-AUC score: 0.8549
#     Batch 21 / 54: loss 0.6353
#     ROC-AUC score: 0.6045
#     Batch 24 / 54: loss 0.6101
#     ROC-AUC score: 0.6270
#     Batch 27 / 54: loss 0.5960
#     ROC-AUC score: 0.9020
#     Batch 30 / 54: loss 0.5235
#     ROC-AUC score: 0.8300
#     Batch 33 / 54: loss 0.5800
#     ROC-AUC score: 0.8056
#     Batch 36 / 54: loss 0.6302
#     ROC-AUC score: 0.6190
#     Batch 39 / 54: loss 0.5826
#     ROC-AUC score: 0.7222
#     Batch 42 / 54: loss 0.5935
#     ROC-AUC score: 0.6627
#     Batch 45 / 54: loss 0.6615
#     ROC-AUC score: 0.7750
#     Batch 48 / 54: loss 0.6318
#     ROC-AUC score: 0.7143
#     Batch 51 / 54: loss 0.5653
#     ROC-AUC score: 0.8594
#     Batch 54 / 54: loss 0.6114
#     ROC-AUC score: 0.6970
# Epoch 11 / 15
#     Batch 3 / 54: loss 0.5738
#     ROC-AUC score: 0.5628
#     Batch 6 / 54: loss 0.6769
#     ROC-AUC score: 0.9167
#     Batch 9 / 54: loss 0.6265
#     ROC-AUC score: 0.7895
#     Batch 12 / 54: loss 0.6102
#     ROC-AUC score: 0.6235
#     Batch 15 / 54: loss 0.6273
#     ROC-AUC score: 0.6961
#     Batch 18 / 54: loss 0.5987
#     ROC-AUC score: 0.7373
#     Batch 21 / 54: loss 0.5233
#     ROC-AUC score: 0.8417
#     Batch 24 / 54: loss 0.5953
#     ROC-AUC score: 0.8750
#     Batch 27 / 54: loss 0.5715
#     ROC-AUC score: 0.8242
#     Batch 30 / 54: loss 0.5501
#     ROC-AUC score: 0.9000
#     Batch 33 / 54: loss 0.5986
#     ROC-AUC score: 0.6700
#     Batch 36 / 54: loss 0.6007
#     ROC-AUC score: 0.8773
#     Batch 39 / 54: loss 0.5622
#     ROC-AUC score: 0.9167
#     Batch 42 / 54: loss 0.5785
#     ROC-AUC score: 0.7176
#     Batch 45 / 54: loss 0.5416
#     ROC-AUC score: 0.9569
#     Batch 48 / 54: loss 0.6433
#     ROC-AUC score: 0.6875
#     Batch 51 / 54: loss 0.6388
#     ROC-AUC score: 0.6923
#     Batch 54 / 54: loss 0.5689
#     ROC-AUC score: 0.8693
# Epoch 12 / 15
#     Batch 3 / 54: loss 0.5720
#     ROC-AUC score: 0.8906
#     Batch 6 / 54: loss 0.5819
#     ROC-AUC score: 0.8664
#     Batch 9 / 54: loss 0.5750
#     ROC-AUC score: 0.8413
#     Batch 12 / 54: loss 0.6222
#     ROC-AUC score: 0.8431
#     Batch 15 / 54: loss 0.6008
#     ROC-AUC score: 0.8947
#     Batch 18 / 54: loss 0.6013
#     ROC-AUC score: 0.7143
#     Batch 21 / 54: loss 0.5352
#     ROC-AUC score: 0.8555
#     Batch 24 / 54: loss 0.6006
#     ROC-AUC score: 0.8281
#     Batch 27 / 54: loss 0.5556
#     ROC-AUC score: 0.8392
#     Batch 30 / 54: loss 0.6001
#     ROC-AUC score: 0.7020
#     Batch 33 / 54: loss 0.5633
#     ROC-AUC score: 0.7579
#     Batch 36 / 54: loss 0.5706
#     ROC-AUC score: 0.7569
#     Batch 39 / 54: loss 0.6400
#     ROC-AUC score: 0.6277
#     Batch 42 / 54: loss 0.6217
#     ROC-AUC score: 0.7137
#     Batch 45 / 54: loss 0.6135
#     ROC-AUC score: 0.8588
#     Batch 48 / 54: loss 0.6550
#     ROC-AUC score: 0.6154
#     Batch 51 / 54: loss 0.5469
#     ROC-AUC score: 0.7734
#     Batch 54 / 54: loss 0.6047
#     ROC-AUC score: 0.6182
# Epoch 13 / 15
#     Batch 3 / 54: loss 0.6465
#     ROC-AUC score: 0.8083
#     Batch 6 / 54: loss 0.6011
#     ROC-AUC score: 0.7381
#     Batch 9 / 54: loss 0.7062
#     ROC-AUC score: 0.6032
#     Batch 12 / 54: loss 0.5477
#     ROC-AUC score: 0.7490
#     Batch 15 / 54: loss 0.5224
#     ROC-AUC score: 0.7765
#     Batch 18 / 54: loss 0.6124
#     ROC-AUC score: 0.8196
#     Batch 21 / 54: loss 0.5803
#     ROC-AUC score: 0.8745
#     Batch 24 / 54: loss 0.5665
#     ROC-AUC score: 0.7773
#     Batch 27 / 54: loss 0.6226
#     ROC-AUC score: 0.6627
#     Batch 30 / 54: loss 0.5482
#     ROC-AUC score: 0.8333
#     Batch 33 / 54: loss 0.5974
#     ROC-AUC score: 0.8056
#     Batch 36 / 54: loss 0.5587
#     ROC-AUC score: 0.8138
#     Batch 39 / 54: loss 0.5402
#     ROC-AUC score: 0.7708
#     Batch 42 / 54: loss 0.5890
#     ROC-AUC score: 0.7409
#     Batch 45 / 54: loss 0.5562
#     ROC-AUC score: 0.7882
#     Batch 48 / 54: loss 0.6136
#     ROC-AUC score: 0.7216
#     Batch 51 / 54: loss 0.6325
#     ROC-AUC score: 0.6562
#     Batch 54 / 54: loss 0.5839
#     ROC-AUC score: 0.8929
# Epoch 14 / 15
#     Batch 3 / 54: loss 0.6473
#     ROC-AUC score: 0.7611
#     Batch 6 / 54: loss 0.5219
#     ROC-AUC score: 0.7583
#     Batch 9 / 54: loss 0.5923
#     ROC-AUC score: 0.6508
#     Batch 12 / 54: loss 0.5902
#     ROC-AUC score: 0.8373
#     Batch 15 / 54: loss 0.5265
#     ROC-AUC score: 0.7625
#     Batch 18 / 54: loss 0.5647
#     ROC-AUC score: 0.8157
#     Batch 21 / 54: loss 0.5453
#     ROC-AUC score: 0.7833
#     Batch 24 / 54: loss 0.6468
#     ROC-AUC score: 0.7059
#     Batch 27 / 54: loss 0.5603
#     ROC-AUC score: 0.6786
#     Batch 30 / 54: loss 0.6052
#     ROC-AUC score: 0.7103
#     Batch 33 / 54: loss 0.6198
#     ROC-AUC score: 0.5820
#     Batch 36 / 54: loss 0.5328
#     ROC-AUC score: 0.8135
#     Batch 39 / 54: loss 0.5834
#     ROC-AUC score: 0.7530
#     Batch 42 / 54: loss 0.6158
#     ROC-AUC score: 0.7490
#     Batch 45 / 54: loss 0.5980
#     ROC-AUC score: 0.6364
#     Batch 48 / 54: loss 0.6124
#     ROC-AUC score: 0.6802
#     Batch 51 / 54: loss 0.6009
#     ROC-AUC score: 0.8167
#     Batch 54 / 54: loss 0.6490
#     ROC-AUC score: 0.8036
# Epoch 15 / 15
#     Batch 3 / 54: loss 0.6373
#     ROC-AUC score: 0.6333
#     Batch 6 / 54: loss 0.6441
#     ROC-AUC score: 0.7328
#     Batch 9 / 54: loss 0.6186
#     ROC-AUC score: 0.7137
#     Batch 12 / 54: loss 0.5920
#     ROC-AUC score: 0.8788
#     Batch 15 / 54: loss 0.5161
#     ROC-AUC score: 0.7045
#     Batch 18 / 54: loss 0.6445
#     ROC-AUC score: 0.8095
#     Batch 21 / 54: loss 0.5986
#     ROC-AUC score: 0.7409
#     Batch 24 / 54: loss 0.6312
#     ROC-AUC score: 0.6923
#     Batch 27 / 54: loss 0.5598
#     ROC-AUC score: 0.8294
#     Batch 30 / 54: loss 0.5884
#     ROC-AUC score: 0.7137
#     Batch 33 / 54: loss 0.5812
#     ROC-AUC score: 0.7341
#     Batch 36 / 54: loss 0.6013
#     ROC-AUC score: 0.7431
#     Batch 39 / 54: loss 0.6079
#     ROC-AUC score: 0.5992
#     Batch 42 / 54: loss 0.5634
#     ROC-AUC score: 0.8057
#     Batch 45 / 54: loss 0.6159
#     ROC-AUC score: 0.6923
#     Batch 48 / 54: loss 0.4844
#     ROC-AUC score: 0.8875
#     Batch 51 / 54: loss 0.5575
#     ROC-AUC score: 0.7539
#     Batch 54 / 54: loss 0.5684
#     ROC-AUC score: 0.8876
# Finished training.
# --------------------------------

# %%
if not config['load']:
    if config['save']:
        print('--------------------------------')
        directory = os.path.join(os.path.dirname(os.getcwd()),
                                'trained_models')
        if not os.path.exists(directory):
            os.makedirs(directory)
        fname = utils.get_fname(config)
        path = os.path.join(directory, fname)
        print('Saving model at {}'.format(path))
        torch.save(model.state_dict(), path)
        print('Finished saving model.')
        print('--------------------------------')

# %% [markdown]
# # Compute ROC-AUC score after training.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset after training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset after training.
#     Batch 1 / 54
#     Batch 2 / 54
#     Batch 3 / 54
#     Batch 4 / 54
#     Batch 5 / 54
#     Batch 6 / 54
#     Batch 7 / 54
#     Batch 8 / 54
#     Batch 9 / 54
#     Batch 10 / 54
#     Batch 11 / 54
#     Batch 12 / 54
#     Batch 13 / 54
#     Batch 14 / 54
#     Batch 15 / 54
#     Batch 16 / 54
#     Batch 17 / 54
#     Batch 18 / 54
#     Batch 19 / 54
#     Batch 20 / 54
#     Batch 21 / 54
#     Batch 22 / 54
#     Batch 23 / 54
#     Batch 24 / 54
#     Batch 25 / 54
#     Batch 26 / 54
#     Batch 27 / 54
#     Batch 28 / 54
#     Batch 29 / 54
#     Batch 30 / 54
#     Batch 31 / 54
#     Batch 32 / 54
#     Batch 33 / 54
#     Batch 34 / 54
#     Batch 35 / 54
#     Batch 36 / 54
#     Batch 37 / 54
#     Batch 38 / 54
#     Batch 39 / 54
#     Batch 40 / 54
#     Batch 41 / 54
#     Batch 42 / 54
#     Batch 43 / 54
#     Batch 44 / 54
#     Batch 45 / 54
#     Batch 46 / 54
#     Batch 47 / 54
#     Batch 48 / 54
#     Batch 49 / 54
#     Batch 50 / 54
#     Batch 51 / 54
#     Batch 52 / 54
#     Batch 53 / 54
#     Batch 54 / 54
# ROC-AUC score: 0.7778
# --------------------------------

# %% [markdown]
# # Plot the true positive rate and true negative rate vs threshold.

# %%
if not config['load']:
    tpr, fpr, thresholds = roc_curve(y_true, y_scores)
    tnr = 1 - fpr
    plt.plot(thresholds, tpr, label='tpr')
    plt.plot(thresholds, tnr, label='tnr')
    plt.xlabel('Threshold')
    plt.title('TPR / TNR vs Threshold')
    plt.legend()

# %% [markdown]
# # Choose an appropriate threshold and generate classification report on the train set.

# %%
idx1 = np.where(tpr <= tnr)[0]
idx2 = np.where(tpr >= tnr)[0]
t = thresholds[idx1[-1]]
total_correct, total_examples = 0, 0
y_true, y_pred = [], []
num_batches = int(ceil(len(dataset) / config['batch_size']))
with torch.no_grad():
    for (idx, batch) in enumerate(loader):
        edges, features, node_layers, mappings, rows, labels = batch
        features, labels = features.to(device), labels.to(device)
        out = model(features, node_layers, mappings, rows)
        all_pairs = torch.mm(out, out.t())
        scores = all_pairs[edges.T]
        predictions = (scores >= t).long()
        y_true.extend(labels.detach().numpy())
        y_pred.extend(predictions.detach().numpy())
        total_correct += torch.sum(predictions == labels.long()).item()
        total_examples += len(labels) 
        print('    Batch {} / {}'.format(idx+1, num_batches))
print('Threshold: {:.4f}, accuracy: {:.4f}'.format(t, total_correct / total_examples))
y_true = np.array(y_true).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
print('Classification report\n', report)
# Out:
#     Batch 1 / 54
#     Batch 2 / 54
#     Batch 3 / 54
#     Batch 4 / 54
#     Batch 5 / 54
#     Batch 6 / 54
#     Batch 7 / 54
#     Batch 8 / 54
#     Batch 9 / 54
#     Batch 10 / 54
#     Batch 11 / 54
#     Batch 12 / 54
#     Batch 13 / 54
#     Batch 14 / 54
#     Batch 15 / 54
#     Batch 16 / 54
#     Batch 17 / 54
#     Batch 18 / 54
#     Batch 19 / 54
#     Batch 20 / 54
#     Batch 21 / 54
#     Batch 22 / 54
#     Batch 23 / 54
#     Batch 24 / 54
#     Batch 25 / 54
#     Batch 26 / 54
#     Batch 27 / 54
#     Batch 28 / 54
#     Batch 29 / 54
#     Batch 30 / 54
#     Batch 31 / 54
#     Batch 32 / 54
#     Batch 33 / 54
#     Batch 34 / 54
#     Batch 35 / 54
#     Batch 36 / 54
#     Batch 37 / 54
#     Batch 38 / 54
#     Batch 39 / 54
#     Batch 40 / 54
#     Batch 41 / 54
#     Batch 42 / 54
#     Batch 43 / 54
#     Batch 44 / 54
#     Batch 45 / 54
#     Batch 46 / 54
#     Batch 47 / 54
#     Batch 48 / 54
#     Batch 49 / 54
#     Batch 50 / 54
#     Batch 51 / 54
#     Batch 52 / 54
#     Batch 53 / 54
#     Batch 54 / 54
# Threshold: 0.2621, accuracy: 0.6940
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.69      0.69      0.69       861
#          1.0       0.69      0.69      0.69       861
#
#     accuracy                           0.69      1722
#    macro avg       0.69      0.69      0.69      1722
# weighted avg       0.69      0.69      0.69      1722

# %% [markdown]
# # Evaluate on validation set.

# %%
if config['load']:
    directory = os.path.join(os.path.dirname(os.getcwd()),
                             'trained_models')
    fname = utils.get_fname(config)
    path = os.path.join(directory, fname)
    model.load_state_dict(torch.load(path))
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'val',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=False, collate_fn=dataset.collate_wrapper)
criterion = utils.get_criterion(config['task'])
stats_per_batch = config['stats_per_batch']
num_batches = int(ceil(len(dataset) / config['batch_size']))
model.eval()
print('--------------------------------')
print('Computing ROC-AUC score for the validation dataset after training.')
running_loss, total_loss = 0.0, 0.0
num_correct, num_examples = 0, 0
total_correct, total_examples = 0, 0
y_true, y_scores, y_pred = [], [], []
for (idx, batch) in enumerate(loader):
    edges, features, node_layers, mappings, rows, labels = batch
    features, labels = features.to(device), labels.to(device)
    out = model(features, node_layers, mappings, rows)
    all_pairs = torch.mm(out, out.t())
    scores = all_pairs[edges.T]
    loss = criterion(scores, labels.float())
    running_loss += loss.item()
    total_loss += loss.item()
    predictions = (scores >= t).long()
    num_correct += torch.sum(predictions == labels.long()).item()
    total_correct += torch.sum(predictions == labels.long()).item()
    num_examples += len(labels)
    total_examples += len(labels)
    y_true.extend(labels.detach().numpy())
    y_scores.extend(scores.detach().numpy())
    y_pred.extend(predictions.detach().numpy())
    if (idx + 1) % stats_per_batch == 0:
        running_loss /= stats_per_batch
        accuracy = num_correct / num_examples
        print('    Batch {} / {}: loss {:.4f}, accuracy {:.4f}'.format(
            idx+1, num_batches, running_loss, accuracy))
        if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
            area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
            print('    ROC-AUC score: {:.4f}'.format(area))
        running_loss = 0.0
        num_correct, num_examples = 0, 0
total_loss /= num_batches
total_accuracy = total_correct / total_examples
print('Loss {:.4f}, accuracy {:.4f}'.format(total_loss, total_accuracy))
y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
area = roc_auc_score(y_true, y_scores)
print('ROC-AUC score: {:.4f}'.format(area))
print('Classification report\n', report)
print('Finished validating.')
print('--------------------------------')
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contacts_hypertext2009/ia-contacts_hypertext2009.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: val
# Number of vertices: 113
# Number of static edges: 1636
# Number of temporal edges: 10409
# Number of examples/datapoints: 1638
# --------------------------------
# --------------------------------
# Computing ROC-AUC score for the validation dataset after training.
#     Batch 3 / 52: loss 0.7407, accuracy 0.5833
#     ROC-AUC score: 0.6190
#     Batch 6 / 52: loss 0.5530, accuracy 0.7396
#     ROC-AUC score: 0.7206
#     Batch 9 / 52: loss 0.5975, accuracy 0.6875
#     ROC-AUC score: 0.7608
#     Batch 12 / 52: loss 0.6824, accuracy 0.6042
#     ROC-AUC score: 0.8214
#     Batch 15 / 52: loss 0.6293, accuracy 0.6667
#     ROC-AUC score: 0.6667
#     Batch 18 / 52: loss 0.6251, accuracy 0.6771
#     ROC-AUC score: 0.7619
#     Batch 21 / 52: loss 0.7181, accuracy 0.5625
#     ROC-AUC score: 0.6017
#     Batch 24 / 52: loss 0.6672, accuracy 0.5833
#     ROC-AUC score: 0.6758
#     Batch 27 / 52: loss 0.6909, accuracy 0.6875
#     ROC-AUC score: 0.7013
#     Batch 30 / 52: loss 0.6298, accuracy 0.6771
#     ROC-AUC score: 0.7738
#     Batch 33 / 52: loss 0.7146, accuracy 0.5521
#     ROC-AUC score: 0.5922
#     Batch 36 / 52: loss 0.6737, accuracy 0.6250
#     ROC-AUC score: 0.4453
#     Batch 39 / 52: loss 0.7363, accuracy 0.5938
#     ROC-AUC score: 0.5368
#     Batch 42 / 52: loss 0.7199, accuracy 0.5938
#     ROC-AUC score: 0.7460
#     Batch 45 / 52: loss 0.6514, accuracy 0.6250
#     ROC-AUC score: 0.7773
#     Batch 48 / 52: loss 0.6862, accuracy 0.5521
#     ROC-AUC score: 0.7608
#     Batch 51 / 52: loss 0.6876, accuracy 0.6667
#     ROC-AUC score: 0.6157
# Loss 0.6783, accuracy 0.6270
# ROC-AUC score: 0.6713
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.63      0.61      0.62       819
#          1.0       0.62      0.64      0.63       819
#
#     accuracy                           0.63      1638
#    macro avg       0.63      0.63      0.63      1638
# weighted avg       0.63      0.63      0.63      1638
#
# Finished validating.
# --------------------------------

# %% [markdown]
# # Evaluate on test set.

# %%
if config['load']:
    directory = os.path.join(os.path.dirname(os.getcwd()),
                             'trained_models')
    fname = utils.get_fname(config)
    path = os.path.join(directory, fname)
    model.load_state_dict(torch.load(path))
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'test',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=False, collate_fn=dataset.collate_wrapper)
criterion = utils.get_criterion(config['task'])
stats_per_batch = config['stats_per_batch']
num_batches = int(ceil(len(dataset) / config['batch_size']))
model.eval()
print('--------------------------------')
print('Computing ROC-AUC score for the test dataset after training.')
running_loss, total_loss = 0.0, 0.0
num_correct, num_examples = 0, 0
total_correct, total_examples = 0, 0
y_true, y_scores, y_pred = [], [], []
for (idx, batch) in enumerate(loader):
    edges, features, node_layers, mappings, rows, labels = batch
    features, labels = features.to(device), labels.to(device)
    out = model(features, node_layers, mappings, rows)
    all_pairs = torch.mm(out, out.t())
    scores = all_pairs[edges.T]
    loss = criterion(scores, labels.float())
    running_loss += loss.item()
    total_loss += loss.item()
    predictions = (scores >= t).long()
    num_correct += torch.sum(predictions == labels.long()).item()
    total_correct += torch.sum(predictions == labels.long()).item()
    num_examples += len(labels)
    total_examples += len(labels)
    y_true.extend(labels.detach().numpy())
    y_scores.extend(scores.detach().numpy())
    y_pred.extend(predictions.detach().numpy())
    if (idx + 1) % stats_per_batch == 0:
        running_loss /= stats_per_batch
        accuracy = num_correct / num_examples
        print('    Batch {} / {}: loss {:.4f}, accuracy {:.4f}'.format(
            idx+1, num_batches, running_loss, accuracy))
        if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
            area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
            print('    ROC-AUC score: {:.4f}'.format(area))
        running_loss = 0.0
        num_correct, num_examples = 0, 0
total_loss /= num_batches
total_accuracy = total_correct / total_examples
print('Loss {:.4f}, accuracy {:.4f}'.format(total_loss, total_accuracy))
y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
area = roc_auc_score(y_true, y_scores)
print('ROC-AUC score: {:.4f}'.format(area))
print('Classification report\n', report)
print('Finished testing.')
print('--------------------------------')
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contacts_hypertext2009/ia-contacts_hypertext2009.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: test
# Number of vertices: 113
# Number of static edges: 2096
# Number of temporal edges: 15613
# Number of examples/datapoints: 1548
# --------------------------------
# --------------------------------
# Computing ROC-AUC score for the test dataset after training.
#     Batch 3 / 49: loss 0.7232, accuracy 0.6042
#     ROC-AUC score: 0.6133
#     Batch 6 / 49: loss 0.7386, accuracy 0.6146
#     ROC-AUC score: 0.8542
#     Batch 9 / 49: loss 0.7301, accuracy 0.5625
#     ROC-AUC score: 0.6389
#     Batch 12 / 49: loss 0.6244, accuracy 0.6250
#     ROC-AUC score: 0.6494
#     Batch 15 / 49: loss 0.6950, accuracy 0.5729
#     ROC-AUC score: 0.5314
#     Batch 18 / 49: loss 0.7073, accuracy 0.5521
#     ROC-AUC score: 0.6071
#     Batch 21 / 49: loss 0.7452, accuracy 0.5938
#     ROC-AUC score: 0.6111
#     Batch 24 / 49: loss 0.7031, accuracy 0.6042
#     ROC-AUC score: 0.6198
#     Batch 27 / 49: loss 0.6895, accuracy 0.6458
#     ROC-AUC score: 0.6071
#     Batch 30 / 49: loss 0.6931, accuracy 0.5625
#     ROC-AUC score: 0.6508
#     Batch 33 / 49: loss 0.6616, accuracy 0.6667
#     ROC-AUC score: 0.6167
#     Batch 36 / 49: loss 0.7049, accuracy 0.5938
#     ROC-AUC score: 0.6627
#     Batch 39 / 49: loss 0.7483, accuracy 0.5625
#     ROC-AUC score: 0.6471
#     Batch 42 / 49: loss 0.6269, accuracy 0.6875
#     ROC-AUC score: 0.6113
#     Batch 45 / 49: loss 0.7691, accuracy 0.5521
#     ROC-AUC score: 0.6157
#     Batch 48 / 49: loss 0.7373, accuracy 0.5729
#     ROC-AUC score: 0.7578
# Loss 0.7055, accuracy 0.5988
# ROC-AUC score: 0.6151
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.60      0.60      0.60       774
#          1.0       0.60      0.60      0.60       774
#
#     accuracy                           0.60      1548
#    macro avg       0.60      0.60      0.60      1548
# weighted avg       0.60      0.60      0.60      1548
#
# Finished testing.
# --------------------------------
