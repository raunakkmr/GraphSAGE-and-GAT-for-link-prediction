# %% [markdown]
# # Imports

# %%
from math import ceil
import json
import os
import sys

src_path = os.path.join(os.path.dirname(os.path.abspath('')), 'src')
sys.path.append(src_path)

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve, classification_report
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import visdom

from datasets import link_prediction
from layers import MeanAggregator, LSTMAggregator, MaxPoolAggregator, MeanPoolAggregator
import models
import utils

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# # Set up arguments for datasets, models and training.

# %%
args = {
    "task" : "link_prediction",
    
    "dataset" : "IAEnronEmployees",
    "dataset_path" : "/Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-enron-employees/ia-enron-employees.edges",
    "mode" : "train",
    "generate_neg_examples" : True,
    
    "duplicate_examples" : True,
    "repeat_examples" : False,
    
    "self_loop" : False,
    "normalize_adj" : False,
    
    "cuda" : "True",
    "model" : "GraphSAGE",
    "agg_class" : "MaxPoolAggregator",
    "hidden_dims" : [64],
    "dropout" : 0.5,
    "num_samples" : -1,
    
    "epochs" : 3,
    "batch_size" : 32,
    "lr" : 1e-4,
    "weight_decay" : 5e-4,
    "stats_per_batch" : 3,
    "visdom" : True,
    
    "load" : False,
    "save" : False
}
config = args
config['num_layers'] = len(config['hidden_dims']) + 1


if config['cuda'] and torch.cuda.is_available():
    device = 'cuda:0'
else:
    device = 'cpu'
config['device'] = device

# %% [markdown]
# # Get the dataset, dataloader and model.

# %%
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'train',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-enron-employees/ia-enron-employees.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: train
# Number of vertices: 151
# Number of static edges: 759
# Number of temporal edges: 15171
# Number of examples/datapoints: 19166
# --------------------------------

# %%
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=True, collate_fn=dataset.collate_wrapper)
input_dim, output_dim = dataset.get_dims()
config['input_dim'], config['output_dim'] = input_dim, output_dim

# %%
model = utils.get_model(config)
print(model)
# Out:
# GraphSAGE(
#   (aggregators): ModuleList(
#     (0): MaxPoolAggregator(
#       (fc1): Linear(in_features=151, out_features=151, bias=True)
#       (relu): ReLU()
#     )
#     (1): MaxPoolAggregator(
#       (fc1): Linear(in_features=64, out_features=64, bias=True)
#       (relu): ReLU()
#     )
#   )
#   (fcs): ModuleList(
#     (0): Linear(in_features=302, out_features=64, bias=True)
#     (1): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dropout): Dropout(p=0.5)
#   (relu): ReLU()
# )

# %% [markdown]
# # Compute ROC-AUC score for the untrained model.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset before training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset before training.
#     Batch 1 / 599
#     Batch 2 / 599
#     Batch 3 / 599
#     Batch 4 / 599
#     Batch 5 / 599
#     Batch 6 / 599
#     Batch 7 / 599
#     Batch 8 / 599
#     Batch 9 / 599
#     Batch 10 / 599
#     Batch 11 / 599
#     Batch 12 / 599
#     Batch 13 / 599
#     Batch 14 / 599
#     Batch 15 / 599
#     Batch 16 / 599
#     Batch 17 / 599
#     Batch 18 / 599
#     Batch 19 / 599
#     Batch 20 / 599
#     Batch 21 / 599
#     Batch 22 / 599
#     Batch 23 / 599
#     Batch 24 / 599
#     Batch 25 / 599
#     Batch 26 / 599
#     Batch 27 / 599
#     Batch 28 / 599
#     Batch 29 / 599
#     Batch 30 / 599
#     Batch 31 / 599
#     Batch 32 / 599
#     Batch 33 / 599
#     Batch 34 / 599
#     Batch 35 / 599
#     Batch 36 / 599
#     Batch 37 / 599
#     Batch 38 / 599
#     Batch 39 / 599
#     Batch 40 / 599
#     Batch 41 / 599
#     Batch 42 / 599
#     Batch 43 / 599
#     Batch 44 / 599
#     Batch 45 / 599
#     Batch 46 / 599
#     Batch 47 / 599
#     Batch 48 / 599
#     Batch 49 / 599
#     Batch 50 / 599
#     Batch 51 / 599
#     Batch 52 / 599
#     Batch 53 / 599
#     Batch 54 / 599
#     Batch 55 / 599
#     Batch 56 / 599
#     Batch 57 / 599
#     Batch 58 / 599
#     Batch 59 / 599
#     Batch 60 / 599
#     Batch 61 / 599
#     Batch 62 / 599
#     Batch 63 / 599
#     Batch 64 / 599
#     Batch 65 / 599
#     Batch 66 / 599
#     Batch 67 / 599
#     Batch 68 / 599
#     Batch 69 / 599
#     Batch 70 / 599
#     Batch 71 / 599
#     Batch 72 / 599
#     Batch 73 / 599
#     Batch 74 / 599
#     Batch 75 / 599
#     Batch 76 / 599
#     Batch 77 / 599
#     Batch 78 / 599
#     Batch 79 / 599
#     Batch 80 / 599
#     Batch 81 / 599
#     Batch 82 / 599
#     Batch 83 / 599
#     Batch 84 / 599
#     Batch 85 / 599
#     Batch 86 / 599
#     Batch 87 / 599
#     Batch 88 / 599
#     Batch 89 / 599
#     Batch 90 / 599
#     Batch 91 / 599
#     Batch 92 / 599
#     Batch 93 / 599
#     Batch 94 / 599
#     Batch 95 / 599
#     Batch 96 / 599
#     Batch 97 / 599
#     Batch 98 / 599
#     Batch 99 / 599
#     Batch 100 / 599
#     Batch 101 / 599
#     Batch 102 / 599
#     Batch 488 / 599
#     Batch 489 / 599
#     Batch 490 / 599
#     Batch 491 / 599
#     Batch 492 / 599
#     Batch 493 / 599
#     Batch 494 / 599
#     Batch 495 / 599
#     Batch 496 / 599
#     Batch 497 / 599
#     Batch 498 / 599
#     Batch 499 / 599
#     Batch 500 / 599
#     Batch 501 / 599
#     Batch 502 / 599
#     Batch 503 / 599
#     Batch 504 / 599
#     Batch 505 / 599
#     Batch 506 / 599
#     Batch 507 / 599
#     Batch 508 / 599
#     Batch 509 / 599
#     Batch 510 / 599
#     Batch 511 / 599
#     Batch 512 / 599
#     Batch 513 / 599
#     Batch 514 / 599
#     Batch 515 / 599
#     Batch 516 / 599
#     Batch 517 / 599
#     Batch 518 / 599
#     Batch 519 / 599
#     Batch 520 / 599
#     Batch 521 / 599
#     Batch 522 / 599
#     Batch 523 / 599
#     Batch 524 / 599
#     Batch 525 / 599
#     Batch 526 / 599
#     Batch 527 / 599
#     Batch 528 / 599
#     Batch 529 / 599
#     Batch 530 / 599
#     Batch 531 / 599
#     Batch 532 / 599
#     Batch 533 / 599
#     Batch 534 / 599
#     Batch 535 / 599
#     Batch 536 / 599
#     Batch 537 / 599
#     Batch 538 / 599
#     Batch 539 / 599
#     Batch 540 / 599
#     Batch 541 / 599
#     Batch 542 / 599
#     Batch 543 / 599
#     Batch 544 / 599
#     Batch 545 / 599
#     Batch 546 / 599
#     Batch 547 / 599
#     Batch 548 / 599
#     Batch 549 / 599
#     Batch 550 / 599
#     Batch 551 / 599
#     Batch 552 / 599
#     Batch 553 / 599
#     Batch 554 / 599
#     Batch 555 / 599
#     Batch 556 / 599
#     Batch 557 / 599
#     Batch 558 / 599
#     Batch 559 / 599
#     Batch 560 / 599
#     Batch 561 / 599
#     Batch 562 / 599
#     Batch 563 / 599
#     Batch 564 / 599
#     Batch 565 / 599
#     Batch 566 / 599
#     Batch 567 / 599
#     Batch 568 / 599
#     Batch 569 / 599
#     Batch 570 / 599
#     Batch 571 / 599
#     Batch 572 / 599
#     Batch 573 / 599
#     Batch 574 / 599
#     Batch 575 / 599
#     Batch 576 / 599
#     Batch 577 / 599
#     Batch 578 / 599
#     Batch 579 / 599
#     Batch 580 / 599
#     Batch 581 / 599
#     Batch 582 / 599
#     Batch 583 / 599
#     Batch 584 / 599
#     Batch 585 / 599
#     Batch 586 / 599
#     Batch 587 / 599
#     Batch 588 / 599
#     Batch 589 / 599
#     Batch 590 / 599
#     Batch 591 / 599
#     Batch 592 / 599
#     Batch 593 / 599
#     Batch 594 / 599
#     Batch 595 / 599
#     Batch 596 / 599
#     Batch 597 / 599
#     Batch 598 / 599
#     Batch 599 / 599
# ROC-AUC score: 0.5715
# --------------------------------

# %% [markdown]
# # Train.

# %%
if not config['load']:
    use_visdom = config['visdom']
    if use_visdom:
        vis = visdom.Visdom()
        loss_window = None
    criterion = utils.get_criterion(config['task'])
    optimizer = optim.Adam(model.parameters(), lr=config['lr'],
                           weight_decay=config['weight_decay'])
    epochs = config['epochs']
    stats_per_batch = config['stats_per_batch']
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    # scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=150, gamma=0.8)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[200, 600, 1000, 1400], gamma=0.7)
    model.train()
    print('--------------------------------')
    print('Training.')
    for epoch in range(epochs):
        print('Epoch {} / {}'.format(epoch+1, epochs))
        running_loss = 0.0
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            loss = criterion(scores, labels.float())
            loss.backward()
            optimizer.step()
            with torch.no_grad():
                running_loss += loss.item()
            if (idx + 1) % stats_per_batch == 0:
                running_loss /= stats_per_batch
                print('    Batch {} / {}: loss {:.4f}'.format(
                    idx+1, num_batches, running_loss))
                if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
                    area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
                    print('    ROC-AUC score: {:.4f}'.format(area))
                running_loss = 0.0
                num_correct, num_examples = 0, 0
            if use_visdom:
                if loss_window is None:
                    loss_window = vis.line(
                        Y=[loss.item()],
                        X=[epoch*num_batches+idx],
                        opts=dict(xlabel='batch', ylabel='Loss', title='Training Loss', legend=['Loss']))
                else:
                    vis.line(
                        [loss.item()],
                        [epoch*num_batches+idx],
                        win=loss_window,
                        update='append')
            scheduler.step()
    if use_visdom:
        vis.close(win=loss_window)
    print('Finished training.')
    print('--------------------------------')
# Out:
# WARNING:root:Setting up a new session...
# --------------------------------
# Training.
# Epoch 1 / 3
#     Batch 3 / 599: loss 0.6933
#     ROC-AUC score: 0.4258
#     Batch 6 / 599: loss 0.6928
#     ROC-AUC score: 0.6235
#     Batch 9 / 599: loss 0.6927
#     ROC-AUC score: 0.6984
#     Batch 12 / 599: loss 0.6928
#     ROC-AUC score: 0.6328
#     Batch 15 / 599: loss 0.6927
#     ROC-AUC score: 0.7341
#     Batch 18 / 599: loss 0.6926
#     ROC-AUC score: 0.5508
#     Batch 21 / 599: loss 0.6930
#     ROC-AUC score: 0.5529
#     Batch 24 / 599: loss 0.6927
#     ROC-AUC score: 0.7229
#     Batch 27 / 599: loss 0.6920
#     ROC-AUC score: 0.7490
#     Batch 30 / 599: loss 0.6920
#     ROC-AUC score: 0.7692
#     Batch 33 / 599: loss 0.6925
#     ROC-AUC score: 0.7085
#     Batch 36 / 599: loss 0.6927
#     ROC-AUC score: 0.7206
#     Batch 39 / 599: loss 0.6922
#     ROC-AUC score: 0.6923
#     Batch 42 / 599: loss 0.6912
#     ROC-AUC score: 0.7897
#     Batch 45 / 599: loss 0.6927
#     ROC-AUC score: 0.6087
#     Batch 48 / 599: loss 0.6919
#     ROC-AUC score: 0.6570
#     Batch 51 / 599: loss 0.6927
#     ROC-AUC score: 0.6468
#     Batch 54 / 599: loss 0.6909
#     ROC-AUC score: 0.5476
#     Batch 57 / 599: loss 0.6913
#     ROC-AUC score: 0.7381
#     Batch 60 / 599: loss 0.6899
#     ROC-AUC score: 0.5749
#     Batch 63 / 599: loss 0.6910
#     ROC-AUC score: 0.5586
#     Batch 66 / 599: loss 0.6911
#     ROC-AUC score: 0.6992
#     Batch 69 / 599: loss 0.6912
#     ROC-AUC score: 0.6500
#     Batch 72 / 599: loss 0.6899
#     ROC-AUC score: 0.4688
#     Batch 75 / 599: loss 0.6915
#     ROC-AUC score: 0.4118
#     Batch 78 / 599: loss 0.6912
#     ROC-AUC score: 0.4863
#     Batch 81 / 599: loss 0.6871
#     ROC-AUC score: 0.9048
#     Batch 84 / 599: loss 0.6918
#     ROC-AUC score: 0.5635
#     Batch 87 / 599: loss 0.6879
#     ROC-AUC score: 0.7446
#     Batch 90 / 599: loss 0.6885
#     ROC-AUC score: 0.7451
#     Batch 93 / 599: loss 0.6890
#     ROC-AUC score: 0.7368
#     Batch 96 / 599: loss 0.6866
#     ROC-AUC score: 0.6706
#     Batch 99 / 599: loss 0.6847
#     ROC-AUC score: 0.8182
#     Batch 102 / 599: loss 0.6920
#     ROC-AUC score: 0.5958
#     Batch 105 / 599: loss 0.6831
#     ROC-AUC score: 0.7266
#     Batch 108 / 599: loss 0.6884
#     ROC-AUC score: 0.5882
#     Batch 111 / 599: loss 0.6857
#     ROC-AUC score: 0.6941
#     Batch 114 / 599: loss 0.6871
#     ROC-AUC score: 0.7305
#     Batch 117 / 599: loss 0.6865
#     ROC-AUC score: 0.5508
#     Batch 120 / 599: loss 0.6897
#     ROC-AUC score: 0.8016
#     Batch 123 / 599: loss 0.6861
#     ROC-AUC score: 0.6548
#     Batch 126 / 599: loss 0.6865
#     ROC-AUC score: 0.7817
#     Batch 129 / 599: loss 0.6842
#     ROC-AUC score: 0.6627
#     Batch 132 / 599: loss 0.6884
#     ROC-AUC score: 0.6389
#     Batch 135 / 599: loss 0.6852
#     ROC-AUC score: 0.6353
#     Batch 138 / 599: loss 0.6897
#     ROC-AUC score: 0.7611
#     Batch 141 / 599: loss 0.6794
#     ROC-AUC score: 0.6627
#     Batch 144 / 599: loss 0.6812
#     ROC-AUC score: 0.6917
#     Batch 147 / 599: loss 0.6777
#     ROC-AUC score: 0.7449
#     Batch 150 / 599: loss 0.6765
#     ROC-AUC score: 0.8458
#     Batch 153 / 599: loss 0.6876
#     ROC-AUC score: 0.5516
#     Batch 156 / 599: loss 0.6778
#     ROC-AUC score: 0.5061
#     Batch 159 / 599: loss 0.6771
#     ROC-AUC score: 0.7381
#     Batch 162 / 599: loss 0.6731
#     ROC-AUC score: 0.6510
#     Batch 165 / 599: loss 0.6803
#     ROC-AUC score: 0.7930
#     Batch 168 / 599: loss 0.6719
#     ROC-AUC score: 0.7619
#     Batch 171 / 599: loss 0.6802
#     ROC-AUC score: 0.8647
#     Batch 174 / 599: loss 0.6750
#     ROC-AUC score: 0.7412
#     Batch 177 / 599: loss 0.6780
#     ROC-AUC score: 0.6825
#     Batch 180 / 599: loss 0.6720
#     ROC-AUC score: 0.7652
#     Batch 183 / 599: loss 0.6806
#     ROC-AUC score: 0.4008
#     Batch 186 / 599: loss 0.6715
#     ROC-AUC score: 0.7619
#     Batch 189 / 599: loss 0.6823
#     ROC-AUC score: 0.6445
#     Batch 192 / 599: loss 0.6652
#     ROC-AUC score: 0.5765
#     Batch 195 / 599: loss 0.6766
#     ROC-AUC score: 0.7188
#     Batch 198 / 599: loss 0.6797
#     ROC-AUC score: 0.8047
#     Batch 201 / 599: loss 0.6641
#     ROC-AUC score: 0.8452
#     Batch 204 / 599: loss 0.6752
#     ROC-AUC score: 0.8442
#     Batch 207 / 599: loss 0.6724
#     ROC-AUC score: 0.7176
#     Batch 210 / 599: loss 0.6700
#     ROC-AUC score: 0.6958
#     Batch 213 / 599: loss 0.6580
#     ROC-AUC score: 0.8591
#     Batch 216 / 599: loss 0.6767
#     ROC-AUC score: 0.7305
#     Batch 219 / 599: loss 0.6575
#     ROC-AUC score: 0.8664
#     Batch 222 / 599: loss 0.6765
#     ROC-AUC score: 0.7091
#     Batch 225 / 599: loss 0.6737
#     ROC-AUC score: 0.6923
#     Batch 228 / 599: loss 0.6682
#     ROC-AUC score: 0.7922
#     Batch 231 / 599: loss 0.6585
#     ROC-AUC score: 0.8941
#     Batch 234 / 599: loss 0.6615
#     ROC-AUC score: 0.7529
#     Batch 237 / 599: loss 0.6665
#     ROC-AUC score: 0.9087
#     Batch 240 / 599: loss 0.6468
#     ROC-AUC score: 0.7294
#     Batch 243 / 599: loss 0.6465
#     ROC-AUC score: 0.8225
#     Batch 246 / 599: loss 0.6688
#     ROC-AUC score: 0.7922
#     Batch 249 / 599: loss 0.6526
#     ROC-AUC score: 0.7137
#     Batch 252 / 599: loss 0.6639
#     ROC-AUC score: 0.7569
#     Batch 255 / 599: loss 0.6536
#     ROC-AUC score: 0.7667
#     Batch 258 / 599: loss 0.6556
#     ROC-AUC score: 0.7328
#     Batch 261 / 599: loss 0.6545
#     ROC-AUC score: 0.7294
#     Batch 264 / 599: loss 0.6522
#     ROC-AUC score: 0.7804
#     Batch 267 / 599: loss 0.6707
#     ROC-AUC score: 0.6599
#     Batch 270 / 599: loss 0.6598
#     ROC-AUC score: 0.5844
#     Batch 273 / 599: loss 0.6662
#     ROC-AUC score: 0.8196
#     Batch 276 / 599: loss 0.6659
#     ROC-AUC score: 0.8254
#     Batch 279 / 599: loss 0.6842
#     ROC-AUC score: 0.6190
#     Batch 282 / 599: loss 0.6472
#     ROC-AUC score: 0.7542
#     Batch 285 / 599: loss 0.6467
#     ROC-AUC score: 0.7619
#     Batch 288 / 599: loss 0.6481
#     ROC-AUC score: 0.6786
#     Batch 291 / 599: loss 0.6544
#     ROC-AUC score: 0.8175
#     Batch 294 / 599: loss 0.6578
#     ROC-AUC score: 0.7540
#     Batch 297 / 599: loss 0.6695
#     ROC-AUC score: 0.6627
#     Batch 300 / 599: loss 0.6553
#     ROC-AUC score: 0.8135
#     Batch 303 / 599: loss 0.6508
#     ROC-AUC score: 0.6510
#     Batch 306 / 599: loss 0.6677
#     ROC-AUC score: 0.8157
#     Batch 309 / 599: loss 0.6615
#     ROC-AUC score: 0.6389
#     Batch 312 / 599: loss 0.6474
#     ROC-AUC score: 0.7579
#     Batch 315 / 599: loss 0.6318
#     ROC-AUC score: 0.8711
#     Batch 318 / 599: loss 0.6756
#     ROC-AUC score: 0.6836
#     Batch 321 / 599: loss 0.6583
#     ROC-AUC score: 0.7216
#     Batch 324 / 599: loss 0.6543
#     ROC-AUC score: 0.7529
#     Batch 327 / 599: loss 0.6639
#     ROC-AUC score: 0.7891
#     Batch 330 / 599: loss 0.6469
#     ROC-AUC score: 0.8413
#     Batch 333 / 599: loss 0.6415
#     ROC-AUC score: 0.8941
#     Batch 336 / 599: loss 0.6648
#     ROC-AUC score: 0.6039
#     Batch 339 / 599: loss 0.6438
#     ROC-AUC score: 0.7578
#     Batch 342 / 599: loss 0.6637
#     ROC-AUC score: 0.6865
#     Batch 345 / 599: loss 0.6542
#     ROC-AUC score: 0.7976
#     Batch 348 / 599: loss 0.6369
#     ROC-AUC score: 0.8135
#     Batch 351 / 599: loss 0.6204
#     ROC-AUC score: 0.7545
#     Batch 354 / 599: loss 0.6370
#     ROC-AUC score: 0.7725
#     Batch 357 / 599: loss 0.6385
#     ROC-AUC score: 0.6172
#     Batch 360 / 599: loss 0.6360
#     ROC-AUC score: 0.7409
#     Batch 363 / 599: loss 0.6381
#     ROC-AUC score: 0.7773
#     Batch 366 / 599: loss 0.6413
#     ROC-AUC score: 0.8633
#     Batch 369 / 599: loss 0.6650
#     ROC-AUC score: 0.7166
#     Batch 372 / 599: loss 0.6208
#     ROC-AUC score: 0.7976
#     Batch 375 / 599: loss 0.6296
#     ROC-AUC score: 0.7608
#     Batch 378 / 599: loss 0.6492
#     ROC-AUC score: 0.6211
#     Batch 381 / 599: loss 0.6484
#     ROC-AUC score: 0.6636
#     Batch 384 / 599: loss 0.6228
#     ROC-AUC score: 0.7328
#     Batch 387 / 599: loss 0.6158
#     ROC-AUC score: 0.8958
#     Batch 390 / 599: loss 0.6395
#     ROC-AUC score: 0.8594
#     Batch 393 / 599: loss 0.6461
#     ROC-AUC score: 0.7137
#     Batch 396 / 599: loss 0.6458
#     ROC-AUC score: 0.6000
#     Batch 399 / 599: loss 0.6054
#     ROC-AUC score: 0.7733
#     Batch 402 / 599: loss 0.6264
#     ROC-AUC score: 0.7804
#     Batch 405 / 599: loss 0.6411
#     ROC-AUC score: 0.6431
#     Batch 408 / 599: loss 0.6515
#     ROC-AUC score: 0.8083
#     Batch 411 / 599: loss 0.6347
#     ROC-AUC score: 0.6039
#     Batch 414 / 599: loss 0.5896
#     ROC-AUC score: 0.8591
#     Batch 417 / 599: loss 0.6478
#     ROC-AUC score: 0.7818
#     Batch 420 / 599: loss 0.6261
#     ROC-AUC score: 0.7922
#     Batch 423 / 599: loss 0.6242
#     ROC-AUC score: 0.8182
#     Batch 426 / 599: loss 0.6250
#     ROC-AUC score: 0.8016
#     Batch 429 / 599: loss 0.6421
#     ROC-AUC score: 0.7451
#     Batch 432 / 599: loss 0.6518
#     ROC-AUC score: 0.5223
#     Batch 435 / 599: loss 0.6408
#     ROC-AUC score: 0.6039
#     Batch 438 / 599: loss 0.6475
#     ROC-AUC score: 0.8164
#     Batch 441 / 599: loss 0.6227
#     ROC-AUC score: 0.6941
#     Batch 444 / 599: loss 0.6099
#     ROC-AUC score: 0.8320
#     Batch 447 / 599: loss 0.6233
#     ROC-AUC score: 0.8095
#     Batch 450 / 599: loss 0.6077
#     ROC-AUC score: 0.8157
#     Batch 453 / 599: loss 0.6135
#     ROC-AUC score: 0.8281
#     Batch 456 / 599: loss 0.6510
#     ROC-AUC score: 0.7222
#     Batch 459 / 599: loss 0.6486
#     ROC-AUC score: 0.8500
#     Batch 462 / 599: loss 0.6146
#     ROC-AUC score: 0.8611
#     Batch 465 / 599: loss 0.5700
#     ROC-AUC score: 0.8406
#     Batch 468 / 599: loss 0.6273
#     ROC-AUC score: 0.6836
#     Batch 471 / 599: loss 0.6450
#     ROC-AUC score: 0.8042
#     Batch 474 / 599: loss 0.6755
#     ROC-AUC score: 0.7725
#     Batch 477 / 599: loss 0.6006
#     ROC-AUC score: 0.7373
#     Batch 480 / 599: loss 0.5598
#     ROC-AUC score: 0.6537
#     Batch 483 / 599: loss 0.6244
#     ROC-AUC score: 0.6721
#     Batch 486 / 599: loss 0.6516
#     ROC-AUC score: 0.6587
#     Batch 489 / 599: loss 0.5953
#     ROC-AUC score: 0.8792
#     Batch 492 / 599: loss 0.6377
#     ROC-AUC score: 0.7460
#     Batch 495 / 599: loss 0.6016
#     ROC-AUC score: 0.8458
#     Batch 498 / 599: loss 0.5667
#     ROC-AUC score: 0.9481
#     Batch 501 / 599: loss 0.6236
#     ROC-AUC score: 0.7461
#     Batch 504 / 599: loss 0.6267
#     ROC-AUC score: 0.8078
#     Batch 507 / 599: loss 0.6217
#     ROC-AUC score: 0.8863
#     Batch 510 / 599: loss 0.6351
#     ROC-AUC score: 0.8208
#     Batch 513 / 599: loss 0.6391
#     ROC-AUC score: 0.7333
#     Batch 516 / 599: loss 0.6616
#     ROC-AUC score: 0.5955
#     Batch 519 / 599: loss 0.6231
#     ROC-AUC score: 0.8730
#     Batch 522 / 599: loss 0.6050
#     ROC-AUC score: 0.8824
#     Batch 525 / 599: loss 0.6181
#     ROC-AUC score: 0.7882
#     Batch 528 / 599: loss 0.6376
#     ROC-AUC score: 0.7333
#     Batch 531 / 599: loss 0.5880
#     ROC-AUC score: 0.5804
#     Batch 534 / 599: loss 0.6154
#     ROC-AUC score: 0.8690
#     Batch 537 / 599: loss 0.6092
#     ROC-AUC score: 0.8458
#     Batch 540 / 599: loss 0.6378
#     ROC-AUC score: 0.7843
#     Batch 543 / 599: loss 0.6199
#     ROC-AUC score: 0.8259
#     Batch 546 / 599: loss 0.6477
#     ROC-AUC score: 0.7098
#     Batch 549 / 599: loss 0.5833
#     ROC-AUC score: 0.7814
#     Batch 552 / 599: loss 0.5998
#     ROC-AUC score: 0.8588
#     Batch 555 / 599: loss 0.6414
#     ROC-AUC score: 0.8057
#     Batch 558 / 599: loss 0.6110
#     ROC-AUC score: 0.7143
#     Batch 561 / 599: loss 0.6313
#     ROC-AUC score: 0.7461
#     Batch 564 / 599: loss 0.5844
#     ROC-AUC score: 0.9069
#     Batch 567 / 599: loss 0.5624
#     ROC-AUC score: 0.9255
#     Batch 570 / 599: loss 0.6363
#     ROC-AUC score: 0.7935
#     Batch 573 / 599: loss 0.6236
#     ROC-AUC score: 0.6078
#     Batch 576 / 599: loss 0.6398
#     ROC-AUC score: 0.7961
#     Batch 579 / 599: loss 0.6372
#     ROC-AUC score: 0.7126
#     Batch 582 / 599: loss 0.6103
#     ROC-AUC score: 0.7266
#     Batch 585 / 599: loss 0.5948
#     ROC-AUC score: 0.7843
#     Batch 588 / 599: loss 0.6049
#     ROC-AUC score: 0.7976
#     Batch 591 / 599: loss 0.6001
#     ROC-AUC score: 0.8118
#     Batch 594 / 599: loss 0.6264
#     ROC-AUC score: 0.6039
#     Batch 597 / 599: loss 0.6244
#     ROC-AUC score: 0.7625
# Epoch 2 / 3
#     Batch 3 / 599: loss 0.5858
#     ROC-AUC score: 0.8510
#     Batch 6 / 599: loss 0.6032
#     ROC-AUC score: 0.8906
#     Batch 9 / 599: loss 0.6028
#     ROC-AUC score: 0.8000
#     Batch 12 / 599: loss 0.6184
#     ROC-AUC score: 0.7422
#     Batch 15 / 599: loss 0.6178
#     ROC-AUC score: 0.6356
#     Batch 18 / 599: loss 0.6639
#     ROC-AUC score: 0.7773
#     Batch 21 / 599: loss 0.6081
#     ROC-AUC score: 0.8941
#     Batch 24 / 599: loss 0.5853
#     ROC-AUC score: 0.8929
#     Batch 27 / 599: loss 0.5858
#     ROC-AUC score: 0.8118
#     Batch 30 / 599: loss 0.6422
#     ROC-AUC score: 0.6407
#     Batch 33 / 599: loss 0.6046
#     ROC-AUC score: 0.8929
#     Batch 36 / 599: loss 0.5993
#     ROC-AUC score: 0.9028
#     Batch 39 / 599: loss 0.5792
#     ROC-AUC score: 0.9246
#     Batch 42 / 599: loss 0.6450
#     ROC-AUC score: 0.8095
#     Batch 45 / 599: loss 0.6102
#     ROC-AUC score: 0.9216
#     Batch 48 / 599: loss 0.6041
#     ROC-AUC score: 0.7166
#     Batch 51 / 599: loss 0.5880
#     ROC-AUC score: 0.7227
#     Batch 54 / 599: loss 0.5819
#     ROC-AUC score: 0.9167
#     Batch 57 / 599: loss 0.5837
#     ROC-AUC score: 0.8701
#     Batch 60 / 599: loss 0.6051
#     ROC-AUC score: 0.8039
#     Batch 63 / 599: loss 0.6126
#     ROC-AUC score: 0.8824
#     Batch 66 / 599: loss 0.5948
#     ROC-AUC score: 0.8294
#     Batch 69 / 599: loss 0.5938
#     ROC-AUC score: 0.7692
#     Batch 72 / 599: loss 0.5785
#     ROC-AUC score: 0.7166
#     Batch 75 / 599: loss 0.5977
#     ROC-AUC score: 0.8203
#     Batch 78 / 599: loss 0.6023
#     ROC-AUC score: 0.8320
#     Batch 81 / 599: loss 0.6022
#     ROC-AUC score: 0.8667
#     Batch 84 / 599: loss 0.5943
#     ROC-AUC score: 0.8078
#     Batch 87 / 599: loss 0.6245
#     ROC-AUC score: 0.7166
#     Batch 90 / 599: loss 0.6165
#     ROC-AUC score: 0.8730
#     Batch 93 / 599: loss 0.5813
#     ROC-AUC score: 0.7804
#     Batch 96 / 599: loss 0.6040
#     ROC-AUC score: 0.8047
#     Batch 99 / 599: loss 0.6278
#     ROC-AUC score: 0.7208
#     Batch 102 / 599: loss 0.6017
#     ROC-AUC score: 0.7969
#     Batch 105 / 599: loss 0.6120
#     ROC-AUC score: 0.8178
#     Batch 108 / 599: loss 0.6093
#     ROC-AUC score: 0.7148
#     Batch 111 / 599: loss 0.6050
#     ROC-AUC score: 0.8242
#     Batch 114 / 599: loss 0.6117
#     ROC-AUC score: 0.7091
#     Batch 117 / 599: loss 0.6022
#     ROC-AUC score: 0.7725
#     Batch 120 / 599: loss 0.6127
#     ROC-AUC score: 0.7969
#     Batch 123 / 599: loss 0.5690
#     ROC-AUC score: 0.7287
#     Batch 126 / 599: loss 0.6356
#     ROC-AUC score: 0.7647
#     Batch 129 / 599: loss 0.5535
#     ROC-AUC score: 0.8219
#     Batch 132 / 599: loss 0.5602
#     ROC-AUC score: 0.9405
#     Batch 135 / 599: loss 0.5914
#     ROC-AUC score: 0.9818
#     Batch 138 / 599: loss 0.5807
#     ROC-AUC score: 0.7804
#     Batch 141 / 599: loss 0.5711
#     ROC-AUC score: 0.7879
#     Batch 144 / 599: loss 0.5923
#     ROC-AUC score: 0.8532
#     Batch 147 / 599: loss 0.6466
#     ROC-AUC score: 0.7765
#     Batch 150 / 599: loss 0.5614
#     ROC-AUC score: 0.8373
#     Batch 153 / 599: loss 0.5933
#     ROC-AUC score: 0.7333
#     Batch 156 / 599: loss 0.6473
#     ROC-AUC score: 0.7328
#     Batch 159 / 599: loss 0.6001
#     ROC-AUC score: 0.7409
#     Batch 162 / 599: loss 0.6252
#     ROC-AUC score: 0.7458
#     Batch 165 / 599: loss 0.6072
#     ROC-AUC score: 0.7381
#     Batch 168 / 599: loss 0.5821
#     ROC-AUC score: 0.8571
#     Batch 171 / 599: loss 0.5835
#     ROC-AUC score: 0.9255
#     Batch 174 / 599: loss 0.5848
#     ROC-AUC score: 0.8333
#     Batch 177 / 599: loss 0.5071
#     ROC-AUC score: 0.9542
#     Batch 180 / 599: loss 0.6015
#     ROC-AUC score: 0.7733
#     Batch 183 / 599: loss 0.6442
#     ROC-AUC score: 0.9682
#     Batch 186 / 599: loss 0.5926
#     ROC-AUC score: 0.9087
#     Batch 189 / 599: loss 0.5973
#     ROC-AUC score: 0.7857
#     Batch 192 / 599: loss 0.6229
#     ROC-AUC score: 0.7341
#     Batch 195 / 599: loss 0.6278
#     ROC-AUC score: 0.8056
#     Batch 198 / 599: loss 0.6290
#     ROC-AUC score: 0.8800
#     Batch 201 / 599: loss 0.5646
#     ROC-AUC score: 0.8611
#     Batch 204 / 599: loss 0.6227
#     ROC-AUC score: 0.8275
#     Batch 207 / 599: loss 0.5972
#     ROC-AUC score: 0.8254
#     Batch 210 / 599: loss 0.5657
#     ROC-AUC score: 0.7500
#     Batch 213 / 599: loss 0.5727
#     ROC-AUC score: 0.9294
#     Batch 216 / 599: loss 0.5916
#     ROC-AUC score: 0.7176
#     Batch 219 / 599: loss 0.5906
#     ROC-AUC score: 0.8902
#     Batch 222 / 599: loss 0.5690
#     ROC-AUC score: 0.9838
#     Batch 225 / 599: loss 0.6552
#     ROC-AUC score: 0.5754
#     Batch 228 / 599: loss 0.6155
#     ROC-AUC score: 0.8314
#     Batch 231 / 599: loss 0.6367
#     ROC-AUC score: 0.7579
#     Batch 234 / 599: loss 0.6035
#     ROC-AUC score: 0.7611
#     Batch 237 / 599: loss 0.6048
#     ROC-AUC score: 0.9059
#     Batch 240 / 599: loss 0.5971
#     ROC-AUC score: 0.9453
#     Batch 243 / 599: loss 0.5678
#     ROC-AUC score: 0.7461
#     Batch 246 / 599: loss 0.5985
#     ROC-AUC score: 0.8968
#     Batch 249 / 599: loss 0.6129
#     ROC-AUC score: 0.8353
#     Batch 252 / 599: loss 0.5724
#     ROC-AUC score: 0.8945
#     Batch 255 / 599: loss 0.5741
#     ROC-AUC score: 0.7854
#     Batch 258 / 599: loss 0.5780
#     ROC-AUC score: 0.9102
#     Batch 261 / 599: loss 0.5645
#     ROC-AUC score: 0.7765
#     Batch 264 / 599: loss 0.5746
#     ROC-AUC score: 0.8824
#     Batch 267 / 599: loss 0.5932
#     ROC-AUC score: 0.7814
#     Batch 270 / 599: loss 0.5790
#     ROC-AUC score: 0.9150
#     Batch 273 / 599: loss 0.5849
#     ROC-AUC score: 0.8047
#     Batch 276 / 599: loss 0.5703
#     ROC-AUC score: 0.8462
#     Batch 279 / 599: loss 0.5666
#     ROC-AUC score: 0.8219
#     Batch 282 / 599: loss 0.5887
#     ROC-AUC score: 0.8259
#     Batch 285 / 599: loss 0.5696
#     ROC-AUC score: 0.8502
#     Batch 288 / 599: loss 0.6133
#     ROC-AUC score: 0.8375
#     Batch 291 / 599: loss 0.6044
#     ROC-AUC score: 0.8471
#     Batch 294 / 599: loss 0.6227
#     ROC-AUC score: 0.6812
#     Batch 297 / 599: loss 0.6750
#     ROC-AUC score: 0.5628
#     Batch 300 / 599: loss 0.6401
#     ROC-AUC score: 0.7000
#     Batch 303 / 599: loss 0.5698
#     ROC-AUC score: 0.9292
#     Batch 306 / 599: loss 0.5464
#     ROC-AUC score: 0.7843
#     Batch 309 / 599: loss 0.6198
#     ROC-AUC score: 0.7686
#     Batch 312 / 599: loss 0.6107
#     ROC-AUC score: 0.7773
#     Batch 315 / 599: loss 0.6038
#     ROC-AUC score: 0.8866
#     Batch 318 / 599: loss 0.5693
#     ROC-AUC score: 0.7897
#     Batch 321 / 599: loss 0.5763
#     ROC-AUC score: 0.7961
#     Batch 324 / 599: loss 0.6162
#     ROC-AUC score: 0.8196
#     Batch 327 / 599: loss 0.5980
#     ROC-AUC score: 0.6905
#     Batch 330 / 599: loss 0.6441
#     ROC-AUC score: 0.8235
#     Batch 333 / 599: loss 0.6065
#     ROC-AUC score: 0.6157
#     Batch 336 / 599: loss 0.5953
#     ROC-AUC score: 0.7143
#     Batch 339 / 599: loss 0.5297
#     ROC-AUC score: 0.8864
#     Batch 342 / 599: loss 0.6162
#     ROC-AUC score: 0.7383
#     Batch 345 / 599: loss 0.5945
#     ROC-AUC score: 0.7652
#     Batch 348 / 599: loss 0.5736
#     ROC-AUC score: 0.8196
#     Batch 351 / 599: loss 0.5983
#     ROC-AUC score: 0.9286
#     Batch 354 / 599: loss 0.6076
#     ROC-AUC score: 0.8471
#     Batch 357 / 599: loss 0.6079
#     ROC-AUC score: 0.8458
#     Batch 360 / 599: loss 0.5902
#     ROC-AUC score: 0.8866
#     Batch 363 / 599: loss 0.5967
#     ROC-AUC score: 0.9625
#     Batch 366 / 599: loss 0.5614
#     ROC-AUC score: 0.8203
#     Batch 369 / 599: loss 0.6018
#     ROC-AUC score: 0.7922
#     Batch 372 / 599: loss 0.5958
#     ROC-AUC score: 0.8125
#     Batch 375 / 599: loss 0.6024
#     ROC-AUC score: 0.9417
#     Batch 378 / 599: loss 0.5748
#     ROC-AUC score: 0.7591
#     Batch 381 / 599: loss 0.5906
#     ROC-AUC score: 0.8125
#     Batch 384 / 599: loss 0.5581
#     ROC-AUC score: 0.8690
#     Batch 387 / 599: loss 0.5980
#     ROC-AUC score: 0.7854
#     Batch 390 / 599: loss 0.6098
#     ROC-AUC score: 0.9098
#     Batch 393 / 599: loss 0.5565
#     ROC-AUC score: 0.8196
#     Batch 396 / 599: loss 0.5692
#     ROC-AUC score: 0.7302
#     Batch 399 / 599: loss 0.6152
#     ROC-AUC score: 0.7344
#     Batch 402 / 599: loss 0.5925
#     ROC-AUC score: 0.7611
#     Batch 405 / 599: loss 0.5590
#     ROC-AUC score: 0.8549
#     Batch 408 / 599: loss 0.5701
#     ROC-AUC score: 0.8543
#     Batch 411 / 599: loss 0.5860
#     ROC-AUC score: 0.7500
#     Batch 414 / 599: loss 0.5217
#     ROC-AUC score: 0.9127
#     Batch 417 / 599: loss 0.5733
#     ROC-AUC score: 0.8918
#     Batch 420 / 599: loss 0.5728
#     ROC-AUC score: 0.8340
#     Batch 423 / 599: loss 0.5506
#     ROC-AUC score: 0.8828
#     Batch 426 / 599: loss 0.5628
#     ROC-AUC score: 0.8785
#     Batch 429 / 599: loss 0.5764
#     ROC-AUC score: 0.9444
#     Batch 432 / 599: loss 0.5630
#     ROC-AUC score: 0.9444
#     Batch 435 / 599: loss 0.6435
#     ROC-AUC score: 0.8196
#     Batch 438 / 599: loss 0.5479
#     ROC-AUC score: 0.8627
#     Batch 441 / 599: loss 0.6164
#     ROC-AUC score: 0.8016
#     Batch 444 / 599: loss 0.6652
#     ROC-AUC score: 0.8516
#     Batch 447 / 599: loss 0.5955
#     ROC-AUC score: 0.9524
#     Batch 450 / 599: loss 0.5521
#     ROC-AUC score: 0.8219
#     Batch 453 / 599: loss 0.5524
#     ROC-AUC score: 0.9062
#     Batch 456 / 599: loss 0.6378
#     ROC-AUC score: 0.8333
#     Batch 459 / 599: loss 0.6015
#     ROC-AUC score: 0.6784
#     Batch 462 / 599: loss 0.6034
#     ROC-AUC score: 0.7579
#     Batch 465 / 599: loss 0.5898
#     ROC-AUC score: 0.7000
#     Batch 468 / 599: loss 0.6108
#     ROC-AUC score: 0.8784
#     Batch 471 / 599: loss 0.6068
#     ROC-AUC score: 0.7148
#     Batch 474 / 599: loss 0.5806
#     ROC-AUC score: 0.7098
#     Batch 477 / 599: loss 0.5871
#     ROC-AUC score: 0.8611
#     Batch 480 / 599: loss 0.5882
#     ROC-AUC score: 0.7930
#     Batch 483 / 599: loss 0.5980
#     ROC-AUC score: 0.6842
#     Batch 486 / 599: loss 0.5889
#     ROC-AUC score: 0.6510
#     Batch 489 / 599: loss 0.5470
#     ROC-AUC score: 0.5072
#     Batch 492 / 599: loss 0.5838
#     ROC-AUC score: 0.7698
#     Batch 495 / 599: loss 0.6119
#     ROC-AUC score: 0.7922
#     Batch 498 / 599: loss 0.5862
#     ROC-AUC score: 0.6640
#     Batch 501 / 599: loss 0.5636
#     ROC-AUC score: 0.7004
#     Batch 504 / 599: loss 0.5645
#     ROC-AUC score: 0.8214
#     Batch 507 / 599: loss 0.5671
#     ROC-AUC score: 0.7773
#     Batch 510 / 599: loss 0.5624
#     ROC-AUC score: 0.7579
#     Batch 513 / 599: loss 0.6154
#     ROC-AUC score: 0.7287
#     Batch 516 / 599: loss 0.6163
#     ROC-AUC score: 0.7247
#     Batch 519 / 599: loss 0.5545
#     ROC-AUC score: 0.8294
#     Batch 522 / 599: loss 0.5635
#     ROC-AUC score: 0.8810
#     Batch 525 / 599: loss 0.5430
#     ROC-AUC score: 0.8125
#     Batch 528 / 599: loss 0.5163
#     ROC-AUC score: 0.8788
#     Batch 531 / 599: loss 0.6040
#     ROC-AUC score: 0.6786
#     Batch 534 / 599: loss 0.6016
#     ROC-AUC score: 0.7176
#     Batch 537 / 599: loss 0.6473
#     ROC-AUC score: 0.7695
#     Batch 540 / 599: loss 0.6062
#     ROC-AUC score: 0.8588
#     Batch 543 / 599: loss 0.5795
#     ROC-AUC score: 0.8961
#     Batch 546 / 599: loss 0.5634
#     ROC-AUC score: 0.6407
#     Batch 549 / 599: loss 0.6284
#     ROC-AUC score: 0.7804
#     Batch 552 / 599: loss 0.5541
#     ROC-AUC score: 0.9137
#     Batch 555 / 599: loss 0.5883
#     ROC-AUC score: 0.8008
#     Batch 558 / 599: loss 0.5813
#     ROC-AUC score: 0.6984
#     Batch 561 / 599: loss 0.5098
#     ROC-AUC score: 0.8831
#     Batch 564 / 599: loss 0.5991
#     ROC-AUC score: 0.9710
#     Batch 567 / 599: loss 0.5711
#     ROC-AUC score: 0.8431
#     Batch 570 / 599: loss 0.6179
#     ROC-AUC score: 0.7422
#     Batch 573 / 599: loss 0.5660
#     ROC-AUC score: 0.9654
#     Batch 576 / 599: loss 0.5948
#     ROC-AUC score: 0.7490
#     Batch 579 / 599: loss 0.5709
#     ROC-AUC score: 0.8000
#     Batch 582 / 599: loss 0.5724
#     ROC-AUC score: 0.7725
#     Batch 585 / 599: loss 0.5839
#     ROC-AUC score: 0.7552
#     Batch 588 / 599: loss 0.6692
#     ROC-AUC score: 0.7020
#     Batch 591 / 599: loss 0.5735
#     ROC-AUC score: 0.8078
#     Batch 594 / 599: loss 0.6142
#     ROC-AUC score: 0.9167
#     Batch 597 / 599: loss 0.5573
#     ROC-AUC score: 0.8314
# Epoch 3 / 3
#     Batch 3 / 599: loss 0.4989
#     ROC-AUC score: 0.8875
#     Batch 6 / 599: loss 0.5608
#     ROC-AUC score: 0.8409
#     Batch 9 / 599: loss 0.5732
#     ROC-AUC score: 0.7792
#     Batch 12 / 599: loss 0.5942
#     ROC-AUC score: 0.7738
#     Batch 15 / 599: loss 0.5400
#     ROC-AUC score: 0.7804
#     Batch 18 / 599: loss 0.6323
#     ROC-AUC score: 0.8353
#     Batch 21 / 599: loss 0.5336
#     ROC-AUC score: 0.9294
#     Batch 24 / 599: loss 0.5960
#     ROC-AUC score: 0.8500
#     Batch 27 / 599: loss 0.5959
#     ROC-AUC score: 0.7857
#     Batch 30 / 599: loss 0.5676
#     ROC-AUC score: 0.8810
#     Batch 33 / 599: loss 0.5934
#     ROC-AUC score: 0.7461
#     Batch 36 / 599: loss 0.6145
#     ROC-AUC score: 0.6392
#     Batch 39 / 599: loss 0.5501
#     ROC-AUC score: 0.9643
#     Batch 42 / 599: loss 0.5682
#     ROC-AUC score: 0.7891
#     Batch 45 / 599: loss 0.5337
#     ROC-AUC score: 0.8866
#     Batch 48 / 599: loss 0.5758
#     ROC-AUC score: 0.7882
#     Batch 51 / 599: loss 0.6236
#     ROC-AUC score: 0.6275
#     Batch 54 / 599: loss 0.5481
#     ROC-AUC score: 0.9134
#     Batch 57 / 599: loss 0.6268
#     ROC-AUC score: 0.8431
#     Batch 60 / 599: loss 0.5997
#     ROC-AUC score: 0.7922
#     Batch 63 / 599: loss 0.5702
#     ROC-AUC score: 0.8708
#     Batch 66 / 599: loss 0.5779
#     ROC-AUC score: 0.8392
#     Batch 69 / 599: loss 0.5602
#     ROC-AUC score: 0.8250
#     Batch 72 / 599: loss 0.6124
#     ROC-AUC score: 0.8118
#     Batch 75 / 599: loss 0.5461
#     ROC-AUC score: 0.8583
#     Batch 78 / 599: loss 0.5900
#     ROC-AUC score: 0.8214
#     Batch 81 / 599: loss 0.6018
#     ROC-AUC score: 0.8889
#     Batch 84 / 599: loss 0.5513
#     ROC-AUC score: 0.8167
#     Batch 87 / 599: loss 0.5565
#     ROC-AUC score: 0.6902
#     Batch 90 / 599: loss 0.5424
#     ROC-AUC score: 0.8906
#     Batch 93 / 599: loss 0.5164
#     ROC-AUC score: 0.8918
#     Batch 96 / 599: loss 0.6045
#     ROC-AUC score: 0.7818
#     Batch 99 / 599: loss 0.5489
#     ROC-AUC score: 0.8929
#     Batch 102 / 599: loss 0.5829
#     ROC-AUC score: 0.8947
#     Batch 105 / 599: loss 0.5563
#     ROC-AUC score: 0.8409
#     Batch 108 / 599: loss 0.5660
#     ROC-AUC score: 0.6500
#     Batch 111 / 599: loss 0.6286
#     ROC-AUC score: 0.8941
#     Batch 114 / 599: loss 0.5100
#     ROC-AUC score: 0.9708
#     Batch 117 / 599: loss 0.6009
#     ROC-AUC score: 0.7695
#     Batch 120 / 599: loss 0.5812
#     ROC-AUC score: 0.8000
#     Batch 123 / 599: loss 0.5534
#     ROC-AUC score: 0.8275
#     Batch 126 / 599: loss 0.5881
#     ROC-AUC score: 0.8259
#     Batch 129 / 599: loss 0.5521
#     ROC-AUC score: 0.8125
#     Batch 132 / 599: loss 0.5607
#     ROC-AUC score: 0.9271
#     Batch 135 / 599: loss 0.5750
#     ROC-AUC score: 0.7530
#     Batch 138 / 599: loss 0.5808
#     ROC-AUC score: 0.8750
#     Batch 141 / 599: loss 0.5766
#     ROC-AUC score: 0.8667
#     Batch 144 / 599: loss 0.5945
#     ROC-AUC score: 0.9484
#     Batch 147 / 599: loss 0.5738
#     ROC-AUC score: 0.8789
#     Batch 150 / 599: loss 0.5659
#     ROC-AUC score: 0.9365
#     Batch 153 / 599: loss 0.6066
#     ROC-AUC score: 0.7529
#     Batch 156 / 599: loss 0.5938
#     ROC-AUC score: 0.8532
#     Batch 159 / 599: loss 0.5574
#     ROC-AUC score: 0.9176
#     Batch 162 / 599: loss 0.6357
#     ROC-AUC score: 0.8623
#     Batch 165 / 599: loss 0.5739
#     ROC-AUC score: 0.7922
#     Batch 168 / 599: loss 0.6125
#     ROC-AUC score: 0.8651
#     Batch 171 / 599: loss 0.5414
#     ROC-AUC score: 0.8690
#     Batch 174 / 599: loss 0.5895
#     ROC-AUC score: 0.8745
#     Batch 177 / 599: loss 0.5709
#     ROC-AUC score: 0.6745
#     Batch 180 / 599: loss 0.5498
#     ROC-AUC score: 0.7328
#     Batch 183 / 599: loss 0.6102
#     ROC-AUC score: 0.7344
#     Batch 186 / 599: loss 0.5628
#     ROC-AUC score: 0.8292
#     Batch 189 / 599: loss 0.5839
#     ROC-AUC score: 0.8135
#     Batch 192 / 599: loss 0.5744
#     ROC-AUC score: 0.8810
#     Batch 195 / 599: loss 0.5872
#     ROC-AUC score: 0.8875
#     Batch 198 / 599: loss 0.6053
#     ROC-AUC score: 0.8773
#     Batch 201 / 599: loss 0.5449
#     ROC-AUC score: 0.8651
#     Batch 204 / 599: loss 0.5826
#     ROC-AUC score: 0.7659
#     Batch 207 / 599: loss 0.5380
#     ROC-AUC score: 0.8788
#     Batch 210 / 599: loss 0.6044
#     ROC-AUC score: 0.8477
#     Batch 213 / 599: loss 0.5449
#     ROC-AUC score: 0.8549
#     Batch 216 / 599: loss 0.6089
#     ROC-AUC score: 0.9008
#     Batch 219 / 599: loss 0.5367
#     ROC-AUC score: 0.9453
#     Batch 222 / 599: loss 0.6340
#     ROC-AUC score: 0.6275
#     Batch 225 / 599: loss 0.5395
#     ROC-AUC score: 0.7833
#     Batch 228 / 599: loss 0.5738
#     ROC-AUC score: 0.7897
#     Batch 231 / 599: loss 0.5171
#     ROC-AUC score: 0.8340
#     Batch 234 / 599: loss 0.6170
#     ROC-AUC score: 0.6627
#     Batch 237 / 599: loss 0.5650
#     ROC-AUC score: 0.8611
#     Batch 240 / 599: loss 0.5984
#     ROC-AUC score: 0.8078
#     Batch 243 / 599: loss 0.6030
#     ROC-AUC score: 0.8902
#     Batch 246 / 599: loss 0.5548
#     ROC-AUC score: 0.9405
#     Batch 249 / 599: loss 0.5761
#     ROC-AUC score: 0.8988
#     Batch 252 / 599: loss 0.5322
#     ROC-AUC score: 0.8528
#     Batch 255 / 599: loss 0.6325
#     ROC-AUC score: 0.7500
#     Batch 258 / 599: loss 0.5935
#     ROC-AUC score: 0.8988
#     Batch 261 / 599: loss 0.6038
#     ROC-AUC score: 0.6328
#     Batch 264 / 599: loss 0.5794
#     ROC-AUC score: 0.8333
#     Batch 267 / 599: loss 0.5454
#     ROC-AUC score: 0.8532
#     Batch 270 / 599: loss 0.5503
#     ROC-AUC score: 0.8398
#     Batch 273 / 599: loss 0.5787
#     ROC-AUC score: 0.7749
#     Batch 276 / 599: loss 0.5932
#     ROC-AUC score: 0.8381
#     Batch 279 / 599: loss 0.5927
#     ROC-AUC score: 0.8667
#     Batch 282 / 599: loss 0.5443
#     ROC-AUC score: 0.9484
#     Batch 285 / 599: loss 0.5871
#     ROC-AUC score: 0.8259
#     Batch 288 / 599: loss 0.5825
#     ROC-AUC score: 0.7976
#     Batch 291 / 599: loss 0.5962
#     ROC-AUC score: 0.6958
#     Batch 294 / 599: loss 0.5705
#     ROC-AUC score: 0.8833
#     Batch 297 / 599: loss 0.5522
#     ROC-AUC score: 0.9636
#     Batch 300 / 599: loss 0.5684
#     ROC-AUC score: 0.7765
#     Batch 303 / 599: loss 0.5868
#     ROC-AUC score: 0.8375
#     Batch 306 / 599: loss 0.5537
#     ROC-AUC score: 0.9531
#     Batch 309 / 599: loss 0.5418
#     ROC-AUC score: 0.7729
#     Batch 312 / 599: loss 0.5842
#     ROC-AUC score: 0.9008
#     Batch 315 / 599: loss 0.6028
#     ROC-AUC score: 0.7937
#     Batch 318 / 599: loss 0.5592
#     ROC-AUC score: 0.9333
#     Batch 321 / 599: loss 0.5458
#     ROC-AUC score: 0.8958
#     Batch 324 / 599: loss 0.5826
#     ROC-AUC score: 0.8095
#     Batch 327 / 599: loss 0.6168
#     ROC-AUC score: 0.8594
#     Batch 330 / 599: loss 0.5990
#     ROC-AUC score: 0.7608
#     Batch 333 / 599: loss 0.5798
#     ROC-AUC score: 0.7578
#     Batch 336 / 599: loss 0.6063
#     ROC-AUC score: 0.7004
#     Batch 339 / 599: loss 0.5680
#     ROC-AUC score: 0.8373
#     Batch 342 / 599: loss 0.6052
#     ROC-AUC score: 0.8516
#     Batch 345 / 599: loss 0.5664
#     ROC-AUC score: 0.7647
#     Batch 348 / 599: loss 0.5419
#     ROC-AUC score: 0.9676
#     Batch 351 / 599: loss 0.5886
#     ROC-AUC score: 0.7778
#     Batch 354 / 599: loss 0.5635
#     ROC-AUC score: 0.7198
#     Batch 357 / 599: loss 0.5568
#     ROC-AUC score: 0.7004
#     Batch 360 / 599: loss 0.6038
#     ROC-AUC score: 0.8727
#     Batch 363 / 599: loss 0.6172
#     ROC-AUC score: 0.7529
#     Batch 366 / 599: loss 0.5374
#     ROC-AUC score: 0.8971
#     Batch 369 / 599: loss 0.6073
#     ROC-AUC score: 0.8009
#     Batch 372 / 599: loss 0.5625
#     ROC-AUC score: 0.8167
#     Batch 375 / 599: loss 0.6224
#     ROC-AUC score: 0.8203
#     Batch 378 / 599: loss 0.5232
#     ROC-AUC score: 0.9583
#     Batch 381 / 599: loss 0.5518
#     ROC-AUC score: 0.8571
#     Batch 384 / 599: loss 0.5814
#     ROC-AUC score: 0.9020
#     Batch 387 / 599: loss 0.5506
#     ROC-AUC score: 0.9167
#     Batch 390 / 599: loss 0.5903
#     ROC-AUC score: 0.9264
#     Batch 393 / 599: loss 0.5173
#     ROC-AUC score: 0.9000
#     Batch 396 / 599: loss 0.5876
#     ROC-AUC score: 0.8392
#     Batch 399 / 599: loss 0.5169
#     ROC-AUC score: 0.9529
#     Batch 402 / 599: loss 0.5774
#     ROC-AUC score: 0.7004
#     Batch 405 / 599: loss 0.5997
#     ROC-AUC score: 0.7882
#     Batch 408 / 599: loss 0.5365
#     ROC-AUC score: 0.8968
#     Batch 411 / 599: loss 0.4854
#     ROC-AUC score: 0.8625
#     Batch 414 / 599: loss 0.5835
#     ROC-AUC score: 0.7262
#     Batch 417 / 599: loss 0.5531
#     ROC-AUC score: 0.7576
#     Batch 420 / 599: loss 0.5575
#     ROC-AUC score: 0.8906
#     Batch 423 / 599: loss 0.5526
#     ROC-AUC score: 0.8690
#     Batch 426 / 599: loss 0.5882
#     ROC-AUC score: 0.9603
#     Batch 429 / 599: loss 0.5699
#     ROC-AUC score: 0.6984
#     Batch 432 / 599: loss 0.5308
#     ROC-AUC score: 0.9555
#     Batch 435 / 599: loss 0.5955
#     ROC-AUC score: 0.9042
#     Batch 438 / 599: loss 0.5632
#     ROC-AUC score: 0.9271
#     Batch 441 / 599: loss 0.6230
#     ROC-AUC score: 0.8623
#     Batch 444 / 599: loss 0.5403
#     ROC-AUC score: 0.8937
#     Batch 447 / 599: loss 0.5618
#     ROC-AUC score: 0.7045
#     Batch 450 / 599: loss 0.5192
#     ROC-AUC score: 0.9219
#     Batch 453 / 599: loss 0.5588
#     ROC-AUC score: 0.8413
#     Batch 456 / 599: loss 0.5552
#     ROC-AUC score: 0.8863
#     Batch 459 / 599: loss 0.6198
#     ROC-AUC score: 0.9130
#     Batch 462 / 599: loss 0.5816
#     ROC-AUC score: 0.8745
#     Batch 465 / 599: loss 0.5298
#     ROC-AUC score: 0.9917
#     Batch 468 / 599: loss 0.5143
#     ROC-AUC score: 0.7961
#     Batch 471 / 599: loss 0.5329
#     ROC-AUC score: 0.9219
#     Batch 474 / 599: loss 0.5685
#     ROC-AUC score: 0.8500
#     Batch 477 / 599: loss 0.5804
#     ROC-AUC score: 0.6431
#     Batch 480 / 599: loss 0.5969
#     ROC-AUC score: 0.8225
#     Batch 483 / 599: loss 0.5719
#     ROC-AUC score: 0.8421
#     Batch 486 / 599: loss 0.6019
#     ROC-AUC score: 0.6000
#     Batch 489 / 599: loss 0.5548
#     ROC-AUC score: 0.7773
#     Batch 492 / 599: loss 0.5517
#     ROC-AUC score: 0.8664
#     Batch 495 / 599: loss 0.5218
#     ROC-AUC score: 0.9688
#     Batch 498 / 599: loss 0.5609
#     ROC-AUC score: 0.9365
#     Batch 501 / 599: loss 0.5129
#     ROC-AUC score: 0.9127
#     Batch 504 / 599: loss 0.5034
#     ROC-AUC score: 0.7874
#     Batch 507 / 599: loss 0.5838
#     ROC-AUC score: 0.7083
#     Batch 510 / 599: loss 0.5638
#     ROC-AUC score: 0.9393
#     Batch 513 / 599: loss 0.5824
#     ROC-AUC score: 0.7255
#     Batch 516 / 599: loss 0.6421
#     ROC-AUC score: 0.8047
#     Batch 519 / 599: loss 0.5635
#     ROC-AUC score: 0.8571
#     Batch 522 / 599: loss 0.5745
#     ROC-AUC score: 0.7460
#     Batch 525 / 599: loss 0.5905
#     ROC-AUC score: 0.6641
#     Batch 528 / 599: loss 0.5897
#     ROC-AUC score: 0.8235
#     Batch 531 / 599: loss 0.6089
#     ROC-AUC score: 0.9176
#     Batch 534 / 599: loss 0.5563
#     ROC-AUC score: 0.9437
#     Batch 537 / 599: loss 0.5800
#     ROC-AUC score: 0.7318
#     Batch 540 / 599: loss 0.6099
#     ROC-AUC score: 0.7698
#     Batch 543 / 599: loss 0.5194
#     ROC-AUC score: 0.8555
#     Batch 546 / 599: loss 0.6274
#     ROC-AUC score: 0.7750
#     Batch 549 / 599: loss 0.6198
#     ROC-AUC score: 0.7659
#     Batch 552 / 599: loss 0.6092
#     ROC-AUC score: 0.7843
#     Batch 555 / 599: loss 0.5497
#     ROC-AUC score: 0.9433
#     Batch 558 / 599: loss 0.5220
#     ROC-AUC score: 0.9647
#     Batch 561 / 599: loss 0.5104
#     ROC-AUC score: 0.8929
#     Batch 564 / 599: loss 0.5406
#     ROC-AUC score: 0.8583
#     Batch 567 / 599: loss 0.5417
#     ROC-AUC score: 0.8941
#     Batch 570 / 599: loss 0.5091
#     ROC-AUC score: 0.9490
#     Batch 573 / 599: loss 0.5564
#     ROC-AUC score: 0.8667
#     Batch 576 / 599: loss 0.5756
#     ROC-AUC score: 0.8627
#     Batch 579 / 599: loss 0.5688
#     ROC-AUC score: 0.8452
#     Batch 582 / 599: loss 0.5521
#     ROC-AUC score: 0.9059
#     Batch 585 / 599: loss 0.5320
#     ROC-AUC score: 0.8833
#     Batch 588 / 599: loss 0.5549
#     ROC-AUC score: 0.8849
#     Batch 591 / 599: loss 0.5930
#     ROC-AUC score: 0.7529
#     Batch 594 / 599: loss 0.6114
#     ROC-AUC score: 0.7529
#     Batch 597 / 599: loss 0.5796
#     ROC-AUC score: 0.9565
# Finished training.
# --------------------------------

# %%
if not config['load']:
    if config['save']:
        print('--------------------------------')
        directory = os.path.join(os.path.dirname(os.getcwd()),
                                'trained_models')
        if not os.path.exists(directory):
            os.makedirs(directory)
        fname = utils.get_fname(config)
        path = os.path.join(directory, fname)
        print('Saving model at {}'.format(path))
        torch.save(model.state_dict(), path)
        print('Finished saving model.')
        print('--------------------------------')

# %% [markdown]
# # Compute ROC-AUC score after training.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset after training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset after training.
#     Batch 1 / 599
#     Batch 2 / 599
#     Batch 3 / 599
#     Batch 4 / 599
#     Batch 5 / 599
#     Batch 6 / 599
#     Batch 7 / 599
#     Batch 8 / 599
#     Batch 9 / 599
#     Batch 10 / 599
#     Batch 11 / 599
#     Batch 12 / 599
#     Batch 13 / 599
#     Batch 14 / 599
#     Batch 15 / 599
#     Batch 16 / 599
#     Batch 17 / 599
#     Batch 18 / 599
#     Batch 19 / 599
#     Batch 20 / 599
#     Batch 21 / 599
#     Batch 22 / 599
#     Batch 23 / 599
#     Batch 24 / 599
#     Batch 25 / 599
#     Batch 26 / 599
#     Batch 27 / 599
#     Batch 28 / 599
#     Batch 29 / 599
#     Batch 30 / 599
#     Batch 31 / 599
#     Batch 32 / 599
#     Batch 33 / 599
#     Batch 34 / 599
#     Batch 35 / 599
#     Batch 36 / 599
#     Batch 37 / 599
#     Batch 38 / 599
#     Batch 39 / 599
#     Batch 40 / 599
#     Batch 41 / 599
#     Batch 42 / 599
#     Batch 43 / 599
#     Batch 44 / 599
#     Batch 45 / 599
#     Batch 46 / 599
#     Batch 47 / 599
#     Batch 48 / 599
#     Batch 49 / 599
#     Batch 50 / 599
#     Batch 51 / 599
#     Batch 52 / 599
#     Batch 53 / 599
#     Batch 54 / 599
#     Batch 55 / 599
#     Batch 56 / 599
#     Batch 57 / 599
#     Batch 58 / 599
#     Batch 59 / 599
#     Batch 60 / 599
#     Batch 61 / 599
#     Batch 62 / 599
#     Batch 63 / 599
#     Batch 64 / 599
#     Batch 65 / 599
#     Batch 66 / 599
#     Batch 67 / 599
#     Batch 68 / 599
#     Batch 69 / 599
#     Batch 70 / 599
#     Batch 71 / 599
#     Batch 72 / 599
#     Batch 73 / 599
#     Batch 74 / 599
#     Batch 75 / 599
#     Batch 76 / 599
#     Batch 77 / 599
#     Batch 78 / 599
#     Batch 79 / 599
#     Batch 80 / 599
#     Batch 81 / 599
#     Batch 82 / 599
#     Batch 83 / 599
#     Batch 84 / 599
#     Batch 85 / 599
#     Batch 86 / 599
# ROC-AUC score: 0.8419
# --------------------------------

# %% [markdown]
# # Plot the true positive rate and true negative rate vs threshold.

# %%
if not config['load']:
    tpr, fpr, thresholds = roc_curve(y_true, y_scores)
    tnr = 1 - fpr
    plt.plot(thresholds, tpr, label='tpr')
    plt.plot(thresholds, tnr, label='tnr')
    plt.xlabel('Threshold')
    plt.title('TPR / TNR vs Threshold')
    plt.legend()

# %% [markdown]
# # Choose an appropriate threshold and generate classification report on the train set.

# %%
idx1 = np.where(tpr <= tnr)[0]
idx2 = np.where(tpr >= tnr)[0]
t = thresholds[idx1[-1]]
total_correct, total_examples = 0, 0
y_true, y_pred = [], []
num_batches = int(ceil(len(dataset) / config['batch_size']))
with torch.no_grad():
    for (idx, batch) in enumerate(loader):
        edges, features, node_layers, mappings, rows, labels = batch
        features, labels = features.to(device), labels.to(device)
        out = model(features, node_layers, mappings, rows)
        all_pairs = torch.mm(out, out.t())
        scores = all_pairs[edges.T]
        predictions = (scores >= t).long()
        y_true.extend(labels.detach().numpy())
        y_pred.extend(predictions.detach().numpy())
        total_correct += torch.sum(predictions == labels.long()).item()
        total_examples += len(labels) 
        print('    Batch {} / {}'.format(idx+1, num_batches))
print('Threshold: {:.4f}, accuracy: {:.4f}'.format(t, total_correct / total_examples))
y_true = np.array(y_true).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
print('Classification report\n', report)
# Out:
#     Batch 1 / 599
#     Batch 2 / 599
#     Batch 3 / 599
#     Batch 4 / 599
#     Batch 5 / 599
#     Batch 6 / 599
#     Batch 7 / 599
#     Batch 8 / 599
#     Batch 9 / 599
#     Batch 10 / 599
#     Batch 11 / 599
#     Batch 12 / 599
#     Batch 13 / 599
#     Batch 14 / 599
#     Batch 15 / 599
#     Batch 16 / 599
#     Batch 17 / 599
#     Batch 18 / 599
#     Batch 19 / 599
#     Batch 20 / 599
#     Batch 21 / 599
#     Batch 22 / 599
#     Batch 23 / 599
#     Batch 24 / 599
#     Batch 25 / 599
#     Batch 26 / 599
#     Batch 27 / 599
#     Batch 28 / 599
#     Batch 29 / 599
#     Batch 30 / 599
#     Batch 31 / 599
#     Batch 32 / 599
#     Batch 33 / 599
#     Batch 34 / 599
#     Batch 35 / 599
#     Batch 36 / 599
#     Batch 37 / 599
#     Batch 38 / 599
#     Batch 39 / 599
#     Batch 40 / 599
#     Batch 41 / 599
#     Batch 42 / 599
#     Batch 43 / 599
#     Batch 44 / 599
#     Batch 45 / 599
#     Batch 46 / 599
#     Batch 47 / 599
#     Batch 48 / 599
#     Batch 49 / 599
#     Batch 50 / 599
#     Batch 51 / 599
#     Batch 52 / 599
#     Batch 53 / 599
#     Batch 54 / 599
#     Batch 55 / 599
#     Batch 56 / 599
#     Batch 57 / 599
#     Batch 58 / 599
#     Batch 59 / 599
#     Batch 60 / 599
#     Batch 61 / 599
#     Batch 62 / 599
#     Batch 63 / 599
#     Batch 64 / 599
#     Batch 65 / 599
#     Batch 66 / 599
#     Batch 67 / 599
#     Batch 68 / 599
#     Batch 69 / 599
#     Batch 582 / 599
#     Batch 583 / 599
#     Batch 584 / 599
#     Batch 585 / 599
#     Batch 586 / 599
#     Batch 587 / 599
#     Batch 588 / 599
#     Batch 589 / 599
#     Batch 590 / 599
#     Batch 591 / 599
#     Batch 592 / 599
#     Batch 593 / 599
#     Batch 594 / 599
#     Batch 595 / 599
#     Batch 596 / 599
#     Batch 597 / 599
#     Batch 598 / 599
#     Batch 599 / 599
# Threshold: 0.2210, accuracy: 0.7718
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.77      0.77      0.77      9583
#          1.0       0.77      0.77      0.77      9583
#
#     accuracy                           0.77     19166
#    macro avg       0.77      0.77      0.77     19166
# weighted avg       0.77      0.77      0.77     19166

# %% [markdown]
# # Evaluate on test set.

# %%
if config['load']:
    directory = os.path.join(os.path.dirname(os.getcwd()),
                             'trained_models')
    fname = utils.get_fname(config)
    path = os.path.join(directory, fname)
    model.load_state_dict(torch.load(path))
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'test',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=False, collate_fn=dataset.collate_wrapper)
criterion = utils.get_criterion(config['task'])
stats_per_batch = config['stats_per_batch']
num_batches = int(ceil(len(dataset) / config['batch_size']))
model.eval()
print('--------------------------------')
print('Computing ROC-AUC score for the test dataset after training.')
running_loss, total_loss = 0.0, 0.0
num_correct, num_examples = 0, 0
total_correct, total_examples = 0, 0
y_true, y_scores, y_pred = [], [], []
for (idx, batch) in enumerate(loader):
    edges, features, node_layers, mappings, rows, labels = batch
    features, labels = features.to(device), labels.to(device)
    out = model(features, node_layers, mappings, rows)
    all_pairs = torch.mm(out, out.t())
    scores = all_pairs[edges.T]
    loss = criterion(scores, labels.float())
    running_loss += loss.item()
    total_loss += loss.item()
    predictions = (scores >= t).long()
    num_correct += torch.sum(predictions == labels.long()).item()
    total_correct += torch.sum(predictions == labels.long()).item()
    num_examples += len(labels)
    total_examples += len(labels)
    y_true.extend(labels.detach().numpy())
    y_scores.extend(scores.detach().numpy())
    y_pred.extend(predictions.detach().numpy())
    if (idx + 1) % stats_per_batch == 0:
        running_loss /= stats_per_batch
        accuracy = num_correct / num_examples
        print('    Batch {} / {}: loss {:.4f}, accuracy {:.4f}'.format(
            idx+1, num_batches, running_loss, accuracy))
        if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
            area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
            print('    ROC-AUC score: {:.4f}'.format(area))
        running_loss = 0.0
        num_correct, num_examples = 0, 0
total_loss /= num_batches
total_accuracy = total_correct / total_examples
print('Loss {:.4f}, accuracy {:.4f}'.format(total_loss, total_accuracy))
y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
area = roc_auc_score(y_true, y_scores)
print('ROC-AUC score: {:.4f}'.format(area))
print('Classification report\n', report)
print('Finished testing.')
print('--------------------------------')
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-enron-employees/ia-enron-employees.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: test
# Number of vertices: 151
# Number of static edges: 1888
# Number of temporal edges: 37929
# Number of examples/datapoints: 21070
# --------------------------------
# --------------------------------
# Computing ROC-AUC score for the test dataset after training.
#     Batch 3 / 659: loss 0.6325, accuracy 0.6875
#     ROC-AUC score: 0.6445
#     Batch 6 / 659: loss 0.6772, accuracy 0.6042
#     ROC-AUC score: 0.8455
#     Batch 9 / 659: loss 0.6804, accuracy 0.6042
#     ROC-AUC score: 0.6478
#     Batch 12 / 659: loss 0.7262, accuracy 0.4688
#     ROC-AUC score: 0.4251
#     Batch 15 / 659: loss 0.6711, accuracy 0.5729
#     ROC-AUC score: 0.7733
#     Batch 18 / 659: loss 0.6694, accuracy 0.6562
#     ROC-AUC score: 0.5506
#     Batch 21 / 659: loss 0.6669, accuracy 0.6042
#     ROC-AUC score: 0.6833
#     Batch 24 / 659: loss 0.6581, accuracy 0.5833
#     ROC-AUC score: 0.8196
#     Batch 27 / 659: loss 0.6576, accuracy 0.6146
#     ROC-AUC score: 0.7812
#     Batch 30 / 659: loss 0.6451, accuracy 0.6667
#     ROC-AUC score: 0.8392
#     Batch 33 / 659: loss 0.5831, accuracy 0.6667
#     ROC-AUC score: 0.7961
#     Batch 36 / 659: loss 0.6287, accuracy 0.6667
#     ROC-AUC score: 0.7341
#     Batch 39 / 659: loss 0.6694, accuracy 0.5833
#     ROC-AUC score: 0.9102
#     Batch 42 / 659: loss 0.6321, accuracy 0.6667
#     ROC-AUC score: 0.6875
#     Batch 45 / 659: loss 0.7032, accuracy 0.5938
#     ROC-AUC score: 0.7024
#     Batch 48 / 659: loss 0.6437, accuracy 0.6042
#     ROC-AUC score: 0.5333
#     Batch 51 / 659: loss 0.6163, accuracy 0.6979
#     ROC-AUC score: 0.8042
#     Batch 54 / 659: loss 0.6440, accuracy 0.6458
#     ROC-AUC score: 0.7750
#     Batch 57 / 659: loss 0.6323, accuracy 0.6562
#     ROC-AUC score: 0.7373
#     Batch 60 / 659: loss 0.6091, accuracy 0.6771
#     ROC-AUC score: 0.7843
#     Batch 63 / 659: loss 0.6319, accuracy 0.6354
#     ROC-AUC score: 0.8157
#     Batch 66 / 659: loss 0.5933, accuracy 0.7083
#     ROC-AUC score: 0.8625
#     Batch 69 / 659: loss 0.6822, accuracy 0.5729
#     ROC-AUC score: 0.5833
#     Batch 72 / 659: loss 0.6661, accuracy 0.6042
#     ROC-AUC score: 0.7020
#     Batch 75 / 659: loss 0.6716, accuracy 0.5938
#     ROC-AUC score: 0.7833
#     Batch 78 / 659: loss 0.6256, accuracy 0.6875
#     ROC-AUC score: 0.7857
#     Batch 81 / 659: loss 0.6659, accuracy 0.6458
#     ROC-AUC score: 0.7778
#     Batch 84 / 659: loss 0.6522, accuracy 0.5417
#     ROC-AUC score: 0.6680
#     Batch 87 / 659: loss 0.6467, accuracy 0.6146
#     ROC-AUC score: 0.5961
#     Batch 90 / 659: loss 0.6779, accuracy 0.6354
#     ROC-AUC score: 0.8294
#     Batch 93 / 659: loss 0.6858, accuracy 0.6042
#     ROC-AUC score: 0.8611
#     Batch 96 / 659: loss 0.7081, accuracy 0.5521
#     ROC-AUC score: 0.7314
#     Batch 99 / 659: loss 0.6794, accuracy 0.5833
#     ROC-AUC score: 0.6508
#     Batch 102 / 659: loss 0.6263, accuracy 0.7083
#     ROC-AUC score: 0.7262
#     Batch 105 / 659: loss 0.6642, accuracy 0.6354
#     ROC-AUC score: 0.8471
#     Batch 108 / 659: loss 0.6499, accuracy 0.6562
#     ROC-AUC score: 0.7961
#     Batch 111 / 659: loss 0.5689, accuracy 0.7083
#     ROC-AUC score: 0.7879
#     Batch 114 / 659: loss 0.6441, accuracy 0.5938
#     ROC-AUC score: 0.6523
#     Batch 117 / 659: loss 0.6094, accuracy 0.6354
#     ROC-AUC score: 0.6627
#     Batch 120 / 659: loss 0.6653, accuracy 0.6146
#     ROC-AUC score: 0.7804
#     Batch 123 / 659: loss 0.6755, accuracy 0.5938
#     ROC-AUC score: 0.7143
#     Batch 126 / 659: loss 0.6677, accuracy 0.5729
#     ROC-AUC score: 0.5789
#     Batch 129 / 659: loss 0.6569, accuracy 0.6042
#     ROC-AUC score: 0.6964
#     Batch 132 / 659: loss 0.6367, accuracy 0.7188
#     ROC-AUC score: 0.7451
#     Batch 135 / 659: loss 0.6075, accuracy 0.6458
#     ROC-AUC score: 0.8196
#     Batch 138 / 659: loss 0.6773, accuracy 0.5208
#     ROC-AUC score: 0.4841
#     Batch 141 / 659: loss 0.6805, accuracy 0.6354
#     ROC-AUC score: 0.7328
#     Batch 144 / 659: loss 0.6545, accuracy 0.5833
#     ROC-AUC score: 0.8438
#     Batch 147 / 659: loss 0.6301, accuracy 0.7396
#     ROC-AUC score: 0.8157
#     Batch 150 / 659: loss 0.6607, accuracy 0.6250
#     ROC-AUC score: 0.8281
#     Batch 153 / 659: loss 0.6353, accuracy 0.6458
#     ROC-AUC score: 0.7698
#     Batch 156 / 659: loss 0.6502, accuracy 0.6458
#     ROC-AUC score: 0.6623
#     Batch 159 / 659: loss 0.6577, accuracy 0.6146
#     ROC-AUC score: 0.7922
#     Batch 162 / 659: loss 0.6507, accuracy 0.6562
#     ROC-AUC score: 0.7070
#     Batch 165 / 659: loss 0.6750, accuracy 0.5729
#     ROC-AUC score: 0.9059
#     Batch 168 / 659: loss 0.6333, accuracy 0.6771
#     ROC-AUC score: 0.6397
#     Batch 171 / 659: loss 0.6373, accuracy 0.6250
#     ROC-AUC score: 0.8182
#     Batch 174 / 659: loss 0.6251, accuracy 0.6875
#     ROC-AUC score: 0.8254
#     Batch 177 / 659: loss 0.6442, accuracy 0.5938
#     ROC-AUC score: 0.8118
#     Batch 180 / 659: loss 0.6701, accuracy 0.6562
#     ROC-AUC score: 0.6902
#     Batch 183 / 659: loss 0.6497, accuracy 0.6042
#     ROC-AUC score: 0.6078
#     Batch 186 / 659: loss 0.6220, accuracy 0.6875
#     ROC-AUC score: 0.8968
#     Batch 189 / 659: loss 0.6379, accuracy 0.6875
#     ROC-AUC score: 0.8275
#     Batch 192 / 659: loss 0.6324, accuracy 0.6250
#     ROC-AUC score: 0.6548
#     Batch 195 / 659: loss 0.6426, accuracy 0.6042
#     ROC-AUC score: 0.7148
#     Batch 198 / 659: loss 0.6007, accuracy 0.6979
#     ROC-AUC score: 0.7961
#     Batch 201 / 659: loss 0.6242, accuracy 0.6354
#     ROC-AUC score: 0.5451
#     Batch 204 / 659: loss 0.6893, accuracy 0.6146
#     ROC-AUC score: 0.7383
#     Batch 207 / 659: loss 0.6579, accuracy 0.5729
#     ROC-AUC score: 0.7020
#     Batch 210 / 659: loss 0.6501, accuracy 0.6667
#     ROC-AUC score: 0.7137
#     Batch 213 / 659: loss 0.5896, accuracy 0.6771
#     ROC-AUC score: 0.8225
#     Batch 216 / 659: loss 0.6197, accuracy 0.6562
#     ROC-AUC score: 0.7125
#     Batch 219 / 659: loss 0.6996, accuracy 0.5833
#     ROC-AUC score: 0.6865
#     Batch 222 / 659: loss 0.6498, accuracy 0.6562
#     ROC-AUC score: 0.7542
#     Batch 225 / 659: loss 0.6558, accuracy 0.6042
#     ROC-AUC score: 0.6824
#     Batch 228 / 659: loss 0.6533, accuracy 0.6458
#     ROC-AUC score: 0.7368
#     Batch 231 / 659: loss 0.6548, accuracy 0.6875
#     ROC-AUC score: 0.8047
#     Batch 234 / 659: loss 0.6234, accuracy 0.6771
#     ROC-AUC score: 0.8000
#     Batch 237 / 659: loss 0.6414, accuracy 0.6250
#     ROC-AUC score: 0.8116
#     Batch 240 / 659: loss 0.6459, accuracy 0.6562
#     ROC-AUC score: 0.7500
#     Batch 243 / 659: loss 0.6616, accuracy 0.6458
#     ROC-AUC score: 0.7137
#     Batch 246 / 659: loss 0.6225, accuracy 0.6354
#     ROC-AUC score: 0.8219
#     Batch 249 / 659: loss 0.6235, accuracy 0.6771
#     ROC-AUC score: 0.6680
#     Batch 252 / 659: loss 0.6115, accuracy 0.6562
#     ROC-AUC score: 0.7328
#     Batch 255 / 659: loss 0.5895, accuracy 0.6771
#     ROC-AUC score: 0.8208
#     Batch 258 / 659: loss 0.6704, accuracy 0.5521
#     ROC-AUC score: 0.6797
#     Batch 261 / 659: loss 0.6295, accuracy 0.6562
#     ROC-AUC score: 0.8139
#     Batch 264 / 659: loss 0.6740, accuracy 0.5833
#     ROC-AUC score: 0.6270
#     Batch 267 / 659: loss 0.6521, accuracy 0.6875
#     ROC-AUC score: 0.7698
#     Batch 270 / 659: loss 0.6417, accuracy 0.6562
#     ROC-AUC score: 0.7305
#     Batch 273 / 659: loss 0.6434, accuracy 0.6562
#     ROC-AUC score: 0.7935
#     Batch 276 / 659: loss 0.6883, accuracy 0.5625
#     ROC-AUC score: 0.6151
#     Batch 279 / 659: loss 0.6725, accuracy 0.6042
#     ROC-AUC score: 0.5385
#     Batch 282 / 659: loss 0.6525, accuracy 0.6875
#     ROC-AUC score: 0.8333
#     Batch 285 / 659: loss 0.6440, accuracy 0.6250
#     ROC-AUC score: 0.6000
#     Batch 288 / 659: loss 0.6712, accuracy 0.6042
#     ROC-AUC score: 0.5882
#     Batch 291 / 659: loss 0.6704, accuracy 0.5938
#     ROC-AUC score: 0.7617
#     Batch 294 / 659: loss 0.6801, accuracy 0.5521
#     ROC-AUC score: 0.5792
#     Batch 297 / 659: loss 0.5981, accuracy 0.7500
#     ROC-AUC score: 0.8477
#     Batch 300 / 659: loss 0.5931, accuracy 0.6250
#     ROC-AUC score: 0.6275
#     Batch 303 / 659: loss 0.6210, accuracy 0.5625
#     ROC-AUC score: 0.6955
#     Batch 306 / 659: loss 0.6451, accuracy 0.6354
#     ROC-AUC score: 0.6914
#     Batch 309 / 659: loss 0.6828, accuracy 0.6042
#     ROC-AUC score: 0.7250
#     Batch 312 / 659: loss 0.6748, accuracy 0.5833
#     ROC-AUC score: 0.7302
#     Batch 315 / 659: loss 0.6412, accuracy 0.7083
#     ROC-AUC score: 0.8471
#     Batch 318 / 659: loss 0.6629, accuracy 0.6250
#     ROC-AUC score: 0.7328
#     Batch 321 / 659: loss 0.6901, accuracy 0.5938
#     ROC-AUC score: 0.7328
#     Batch 324 / 659: loss 0.6803, accuracy 0.5938
#     ROC-AUC score: 0.8528
#     Batch 327 / 659: loss 0.6463, accuracy 0.6458
#     ROC-AUC score: 0.6802
#     Batch 330 / 659: loss 0.6835, accuracy 0.4896
#     ROC-AUC score: 0.6478
#     Batch 333 / 659: loss 0.6216, accuracy 0.6771
#     ROC-AUC score: 0.7539
#     Batch 336 / 659: loss 0.6142, accuracy 0.6979
#     ROC-AUC score: 0.8300
#     Batch 339 / 659: loss 0.6305, accuracy 0.6667
#     ROC-AUC score: 0.6875
#     Batch 342 / 659: loss 0.6749, accuracy 0.5729
#     ROC-AUC score: 0.6745
#     Batch 345 / 659: loss 0.6500, accuracy 0.6979
#     ROC-AUC score: 0.7137
#     Batch 348 / 659: loss 0.7085, accuracy 0.5938
#     ROC-AUC score: 0.7773
#     Batch 351 / 659: loss 0.6064, accuracy 0.6771
#     ROC-AUC score: 0.6073
#     Batch 354 / 659: loss 0.6867, accuracy 0.5625
#     ROC-AUC score: 0.6602
#     Batch 357 / 659: loss 0.6631, accuracy 0.6458
#     ROC-AUC score: 0.5931
#     Batch 360 / 659: loss 0.6699, accuracy 0.6458
#     ROC-AUC score: 0.5913
#     Batch 363 / 659: loss 0.6744, accuracy 0.5729
#     ROC-AUC score: 0.5749
#     Batch 366 / 659: loss 0.6672, accuracy 0.5521
#     ROC-AUC score: 0.6289
#     Batch 369 / 659: loss 0.6474, accuracy 0.6458
#     ROC-AUC score: 0.6953
#     Batch 372 / 659: loss 0.6230, accuracy 0.6250
#     ROC-AUC score: 0.7619
#     Batch 375 / 659: loss 0.5866, accuracy 0.7708
#     ROC-AUC score: 0.9028
#     Batch 378 / 659: loss 0.6491, accuracy 0.6146
#     ROC-AUC score: 0.6392
#     Batch 381 / 659: loss 0.6329, accuracy 0.6354
#     ROC-AUC score: 0.7969
#     Batch 384 / 659: loss 0.6569, accuracy 0.6562
#     ROC-AUC score: 0.6032
#     Batch 387 / 659: loss 0.6405, accuracy 0.6354
#     ROC-AUC score: 0.6719
#     Batch 390 / 659: loss 0.6323, accuracy 0.6458
#     ROC-AUC score: 0.7686
#     Batch 393 / 659: loss 0.6342, accuracy 0.6250
#     ROC-AUC score: 0.5754
#     Batch 396 / 659: loss 0.6797, accuracy 0.5938
#     ROC-AUC score: 0.8086
#     Batch 399 / 659: loss 0.6377, accuracy 0.6458
#     ROC-AUC score: 0.7817
#     Batch 402 / 659: loss 0.6112, accuracy 0.6979
#     ROC-AUC score: 0.8138
#     Batch 405 / 659: loss 0.6222, accuracy 0.6562
#     ROC-AUC score: 0.7725
#     Batch 408 / 659: loss 0.6427, accuracy 0.6667
#     ROC-AUC score: 0.8471
#     Batch 411 / 659: loss 0.6465, accuracy 0.6771
#     ROC-AUC score: 0.7287
#     Batch 414 / 659: loss 0.6675, accuracy 0.6250
#     ROC-AUC score: 0.7422
#     Batch 417 / 659: loss 0.6177, accuracy 0.6667
#     ROC-AUC score: 0.7695
#     Batch 420 / 659: loss 0.6021, accuracy 0.7917
#     ROC-AUC score: 0.9286
#     Batch 423 / 659: loss 0.6404, accuracy 0.6042
#     ROC-AUC score: 0.5909
#     Batch 426 / 659: loss 0.6752, accuracy 0.5521
#     ROC-AUC score: 0.5833
#     Batch 429 / 659: loss 0.6761, accuracy 0.5833
#     ROC-AUC score: 0.6500
#     Batch 432 / 659: loss 0.6652, accuracy 0.6354
#     ROC-AUC score: 0.7422
#     Batch 435 / 659: loss 0.6830, accuracy 0.6354
#     ROC-AUC score: 0.7935
#     Batch 438 / 659: loss 0.6496, accuracy 0.6250
#     ROC-AUC score: 0.8492
#     Batch 441 / 659: loss 0.5874, accuracy 0.7292
#     ROC-AUC score: 0.8357
#     Batch 444 / 659: loss 0.6502, accuracy 0.6458
#     ROC-AUC score: 0.7652
#     Batch 447 / 659: loss 0.6126, accuracy 0.6458
#     ROC-AUC score: 0.7579
#     Batch 450 / 659: loss 0.6656, accuracy 0.6354
#     ROC-AUC score: 0.7706
#     Batch 453 / 659: loss 0.6589, accuracy 0.5729
#     ROC-AUC score: 0.8373
#     Batch 456 / 659: loss 0.6232, accuracy 0.6562
#     ROC-AUC score: 0.7188
#     Batch 459 / 659: loss 0.6191, accuracy 0.6354
#     ROC-AUC score: 0.6625
#     Batch 462 / 659: loss 0.6442, accuracy 0.6562
#     ROC-AUC score: 0.7922
#     Batch 465 / 659: loss 0.6518, accuracy 0.5833
#     ROC-AUC score: 0.8294
#     Batch 468 / 659: loss 0.6540, accuracy 0.6250
#     ROC-AUC score: 0.7103
#     Batch 471 / 659: loss 0.7007, accuracy 0.5417
#     ROC-AUC score: 0.7625
#     Batch 474 / 659: loss 0.6640, accuracy 0.6146
#     ROC-AUC score: 0.6875
#     Batch 477 / 659: loss 0.6638, accuracy 0.6042
#     ROC-AUC score: 0.7109
#     Batch 480 / 659: loss 0.6427, accuracy 0.6146
#     ROC-AUC score: 0.6833
#     Batch 483 / 659: loss 0.6450, accuracy 0.6979
#     ROC-AUC score: 0.8711
#     Batch 486 / 659: loss 0.6912, accuracy 0.6042
#     ROC-AUC score: 0.6905
#     Batch 489 / 659: loss 0.6083, accuracy 0.6667
#     ROC-AUC score: 0.7247
#     Batch 492 / 659: loss 0.6772, accuracy 0.5417
#     ROC-AUC score: 0.6902
#     Batch 495 / 659: loss 0.6303, accuracy 0.5833
#     ROC-AUC score: 0.7922
#     Batch 498 / 659: loss 0.6590, accuracy 0.6146
#     ROC-AUC score: 0.6825
#     Batch 501 / 659: loss 0.6307, accuracy 0.6354
#     ROC-AUC score: 0.7529
#     Batch 504 / 659: loss 0.6910, accuracy 0.5417
#     ROC-AUC score: 0.6510
#     Batch 507 / 659: loss 0.6667, accuracy 0.6042
#     ROC-AUC score: 0.5749
#     Batch 510 / 659: loss 0.6864, accuracy 0.6146
#     ROC-AUC score: 0.6518
#     Batch 513 / 659: loss 0.6966, accuracy 0.5938
#     ROC-AUC score: 0.5911
#     Batch 516 / 659: loss 0.6493, accuracy 0.6042
#     ROC-AUC score: 0.7490
#     Batch 519 / 659: loss 0.6404, accuracy 0.6354
#     ROC-AUC score: 0.5992
#     Batch 522 / 659: loss 0.6679, accuracy 0.6667
#     ROC-AUC score: 0.7126
#     Batch 525 / 659: loss 0.7232, accuracy 0.4688
#     ROC-AUC score: 0.5804
#     Batch 528 / 659: loss 0.6378, accuracy 0.6042
#     ROC-AUC score: 0.8083
#     Batch 531 / 659: loss 0.6559, accuracy 0.5938
#     ROC-AUC score: 0.7659
#     Batch 534 / 659: loss 0.6396, accuracy 0.6667
#     ROC-AUC score: 0.7611
#     Batch 537 / 659: loss 0.6819, accuracy 0.6458
#     ROC-AUC score: 0.7206
#     Batch 540 / 659: loss 0.6277, accuracy 0.6458
#     ROC-AUC score: 0.6944
#     Batch 543 / 659: loss 0.6356, accuracy 0.6667
#     ROC-AUC score: 0.7765
#     Batch 546 / 659: loss 0.6887, accuracy 0.6146
#     ROC-AUC score: 0.7176
#     Batch 549 / 659: loss 0.6630, accuracy 0.6146
#     ROC-AUC score: 0.7059
#     Batch 552 / 659: loss 0.6560, accuracy 0.6250
#     ROC-AUC score: 0.8009
#     Batch 555 / 659: loss 0.6943, accuracy 0.5625
#     ROC-AUC score: 0.7137
#     Batch 558 / 659: loss 0.6407, accuracy 0.7188
#     ROC-AUC score: 0.7368
#     Batch 561 / 659: loss 0.6149, accuracy 0.7083
#     ROC-AUC score: 0.7617
#     Batch 564 / 659: loss 0.6798, accuracy 0.6042
#     ROC-AUC score: 0.6000
#     Batch 567 / 659: loss 0.5871, accuracy 0.6458
#     ROC-AUC score: 0.7056
#     Batch 570 / 659: loss 0.6769, accuracy 0.5938
#     ROC-AUC score: 0.7662
#     Batch 573 / 659: loss 0.6621, accuracy 0.5625
#     ROC-AUC score: 0.6708
#     Batch 576 / 659: loss 0.6836, accuracy 0.5312
#     ROC-AUC score: 0.7976
#     Batch 579 / 659: loss 0.6170, accuracy 0.6875
#     ROC-AUC score: 0.7804
#     Batch 582 / 659: loss 0.6644, accuracy 0.6458
#     ROC-AUC score: 0.7109
#     Batch 585 / 659: loss 0.6844, accuracy 0.5833
#     ROC-AUC score: 0.5843
#     Batch 588 / 659: loss 0.6174, accuracy 0.7188
#     ROC-AUC score: 0.7817
#     Batch 591 / 659: loss 0.6620, accuracy 0.6562
#     ROC-AUC score: 0.7000
#     Batch 594 / 659: loss 0.6560, accuracy 0.6146
#     ROC-AUC score: 0.6984
#     Batch 597 / 659: loss 0.6318, accuracy 0.7083
#     ROC-AUC score: 0.7652
#     Batch 600 / 659: loss 0.6518, accuracy 0.6771
#     ROC-AUC score: 0.8000
#     Batch 603 / 659: loss 0.6739, accuracy 0.6250
#     ROC-AUC score: 0.6824
#     Batch 606 / 659: loss 0.6380, accuracy 0.6771
#     ROC-AUC score: 0.8452
#     Batch 609 / 659: loss 0.6195, accuracy 0.6771
#     ROC-AUC score: 0.9231
#     Batch 612 / 659: loss 0.6639, accuracy 0.7083
#     ROC-AUC score: 0.6471
#     Batch 615 / 659: loss 0.6864, accuracy 0.5521
#     ROC-AUC score: 0.8097
#     Batch 618 / 659: loss 0.6781, accuracy 0.5312
#     ROC-AUC score: 0.7063
#     Batch 621 / 659: loss 0.6994, accuracy 0.5729
#     ROC-AUC score: 0.5961
#     Batch 624 / 659: loss 0.6280, accuracy 0.7083
#     ROC-AUC score: 0.8008
#     Batch 627 / 659: loss 0.6470, accuracy 0.6875
#     ROC-AUC score: 0.7765
#     Batch 630 / 659: loss 0.6345, accuracy 0.6667
#     ROC-AUC score: 0.7733
#     Batch 633 / 659: loss 0.6159, accuracy 0.6354
#     ROC-AUC score: 0.6230
#     Batch 636 / 659: loss 0.6397, accuracy 0.5729
#     ROC-AUC score: 0.7126
#     Batch 639 / 659: loss 0.6284, accuracy 0.6562
#     ROC-AUC score: 0.7490
#     Batch 642 / 659: loss 0.6197, accuracy 0.6250
#     ROC-AUC score: 0.7460
#     Batch 645 / 659: loss 0.6829, accuracy 0.6354
#     ROC-AUC score: 0.7143
#     Batch 648 / 659: loss 0.6799, accuracy 0.5833
#     ROC-AUC score: 0.5412
#     Batch 651 / 659: loss 0.6233, accuracy 0.6771
#     ROC-AUC score: 0.8095
#     Batch 654 / 659: loss 0.6400, accuracy 0.6354
#     ROC-AUC score: 0.7100
#     Batch 657 / 659: loss 0.6413, accuracy 0.6458
#     ROC-AUC score: 0.7569
# Loss 0.6504, accuracy 0.6306
# ROC-AUC score: 0.7171
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.67      0.53      0.59     10535
#          1.0       0.61      0.74      0.67     10535
#
#     accuracy                           0.63     21070
#    macro avg       0.64      0.63      0.63     21070
# weighted avg       0.64      0.63      0.63     21070
#
# Finished testing.
# --------------------------------
