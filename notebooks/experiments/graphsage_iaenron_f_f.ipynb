# %% [markdown]
# # Imports

# %%
from math import ceil
import json
import os
import sys

src_path = os.path.join(os.path.dirname(os.path.abspath('')), 'src')
sys.path.append(src_path)

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve, classification_report
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import visdom

from datasets import link_prediction
from layers import MeanAggregator, LSTMAggregator, MaxPoolAggregator, MeanPoolAggregator
import models
import utils

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# # Set up arguments for datasets, models and training.

# %%
args = {
    "task" : "link_prediction",
    
    "dataset" : "IAEnronEmployees",
    "dataset_path" : "/Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-enron-employees/ia-enron-employees.edges",
    "mode" : "train",
    "generate_neg_examples" : False,
    
    "duplicate_examples" : False,
    "repeat_examples" : False,
    
    "self_loop" : True,
    "normalize_adj" : False,
    
    "cuda" : "True",
    "model" : "GraphSAGE",
    "agg_class" : "MaxPoolAggregator",
    "hidden_dims" : [64],
    "dropout" : 0,
    "num_samples" : -1,
    
    "epochs" : 8,
    "batch_size" : 32,
    "lr" : 1e-3,
    "weight_decay" : 5e-4,
    "stats_per_batch" : 3,
    "visdom" : True,
    
    "load" : False,
    "save" : False
}
config = args
config['num_layers'] = len(config['hidden_dims']) + 1


if config['cuda'] and torch.cuda.is_available():
    device = 'cuda:0'
else:
    device = 'cpu'
config['device'] = device

# %% [markdown]
# # Get the dataset, dataloader and model.

# %%
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'train',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-enron-employees/ia-enron-employees.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: train
# Number of vertices: 151
# Number of static edges: 759
# Number of temporal edges: 15171
# Number of examples/datapoints: 2054
# --------------------------------

# %%
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=True, collate_fn=dataset.collate_wrapper)
input_dim, output_dim = dataset.get_dims()

# %%
agg_class = utils.get_agg_class(config['agg_class'])
model = models.GraphSAGE(input_dim, config['hidden_dims'],
                         output_dim, config['dropout'],
                         agg_class, config['num_samples'],
                         config['device'])
model.to(config['device'])
print(model)
# Out:
# GraphSAGE(
#   (aggregators): ModuleList(
#     (0): MaxPoolAggregator(
#       (fc1): Linear(in_features=151, out_features=151, bias=True)
#       (relu): ReLU()
#     )
#     (1): MaxPoolAggregator(
#       (fc1): Linear(in_features=64, out_features=64, bias=True)
#       (relu): ReLU()
#     )
#   )
#   (fcs): ModuleList(
#     (0): Linear(in_features=302, out_features=64, bias=True)
#     (1): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dropout): Dropout(p=0)
#   (relu): ReLU()
# )

# %% [markdown]
# # Compute ROC-AUC score for the untrained model.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset before training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset before training.
#     Batch 1 / 65
#     Batch 2 / 65
#     Batch 3 / 65
#     Batch 4 / 65
#     Batch 5 / 65
#     Batch 6 / 65
#     Batch 7 / 65
#     Batch 8 / 65
#     Batch 9 / 65
#     Batch 10 / 65
#     Batch 11 / 65
#     Batch 12 / 65
#     Batch 13 / 65
#     Batch 14 / 65
#     Batch 15 / 65
#     Batch 16 / 65
#     Batch 17 / 65
#     Batch 18 / 65
#     Batch 19 / 65
#     Batch 20 / 65
#     Batch 21 / 65
#     Batch 22 / 65
#     Batch 23 / 65
#     Batch 24 / 65
#     Batch 25 / 65
#     Batch 26 / 65
#     Batch 27 / 65
#     Batch 28 / 65
#     Batch 29 / 65
#     Batch 30 / 65
#     Batch 31 / 65
#     Batch 32 / 65
#     Batch 33 / 65
#     Batch 34 / 65
#     Batch 35 / 65
#     Batch 36 / 65
#     Batch 37 / 65
#     Batch 38 / 65
#     Batch 39 / 65
#     Batch 40 / 65
#     Batch 41 / 65
#     Batch 42 / 65
#     Batch 43 / 65
#     Batch 44 / 65
#     Batch 45 / 65
#     Batch 46 / 65
#     Batch 47 / 65
#     Batch 48 / 65
#     Batch 49 / 65
#     Batch 50 / 65
#     Batch 51 / 65
#     Batch 52 / 65
#     Batch 53 / 65
#     Batch 54 / 65
#     Batch 55 / 65
#     Batch 56 / 65
#     Batch 57 / 65
#     Batch 58 / 65
#     Batch 59 / 65
#     Batch 60 / 65
#     Batch 61 / 65
#     Batch 62 / 65
#     Batch 63 / 65
#     Batch 64 / 65
#     Batch 65 / 65
# ROC-AUC score: 0.4833
# --------------------------------

# %% [markdown]
# # Train.

# %%
if not config['load']:
    use_visdom = config['visdom']
    if use_visdom:
        vis = visdom.Visdom()
        loss_window = None
    criterion = utils.get_criterion(config['task'])
    optimizer = optim.Adam(model.parameters(), lr=config['lr'],
                           weight_decay=config['weight_decay'])
    epochs = config['epochs']
    stats_per_batch = config['stats_per_batch']
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    # scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=150, gamma=0.8)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[200, 500], gamma=0.7)
    model.train()
    print('--------------------------------')
    print('Training.')
    for epoch in range(epochs):
        print('Epoch {} / {}'.format(epoch+1, epochs))
        running_loss = 0.0
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            loss = criterion(scores, labels.float())
            loss.backward()
            optimizer.step()
            with torch.no_grad():
                running_loss += loss.item()
            if (idx + 1) % stats_per_batch == 0:
                running_loss /= stats_per_batch
                print('    Batch {} / {}: loss {:.4f}'.format(
                    idx+1, num_batches, running_loss))
                if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
                    area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
                    print('    ROC-AUC score: {:.4f}'.format(area))
                running_loss = 0.0
                num_correct, num_examples = 0, 0
            if use_visdom:
                if loss_window is None:
                    loss_window = vis.line(
                        Y=[loss.item()],
                        X=[epoch*num_batches+idx],
                        opts=dict(xlabel='batch', ylabel='Loss', title='Training Loss', legend=['Loss']))
                else:
                    vis.line(
                        [loss.item()],
                        [epoch*num_batches+idx],
                        win=loss_window,
                        update='append')
            scheduler.step()
    if use_visdom:
        vis.close(win=loss_window)
    print('Finished training.')
    print('--------------------------------')
# Out:
# WARNING:root:Setting up a new session...
# --------------------------------
# Training.
# Epoch 1 / 8
#     Batch 3 / 65: loss 0.6922
#     ROC-AUC score: 0.6824
#     Batch 6 / 65: loss 0.6920
#     ROC-AUC score: 0.5437
#     Batch 9 / 65: loss 0.6946
#     ROC-AUC score: 0.4875
#     Batch 12 / 65: loss 0.6978
#     ROC-AUC score: 0.2754
#     Batch 15 / 65: loss 0.6917
#     ROC-AUC score: 0.5333
#     Batch 18 / 65: loss 0.6913
#     ROC-AUC score: 0.5709
#     Batch 21 / 65: loss 0.6916
#     ROC-AUC score: 0.5628
#     Batch 24 / 65: loss 0.6907
#     ROC-AUC score: 0.6518
#     Batch 27 / 65: loss 0.6909
#     ROC-AUC score: 0.6667
#     Batch 30 / 65: loss 0.6919
#     ROC-AUC score: 0.6094
#     Batch 33 / 65: loss 0.6872
#     ROC-AUC score: 0.6784
#     Batch 36 / 65: loss 0.6864
#     ROC-AUC score: 0.7383
#     Batch 39 / 65: loss 0.6818
#     ROC-AUC score: 0.7765
#     Batch 42 / 65: loss 0.6840
#     ROC-AUC score: 0.5273
#     Batch 45 / 65: loss 0.6785
#     ROC-AUC score: 0.6667
#     Batch 48 / 65: loss 0.6881
#     ROC-AUC score: 0.5781
#     Batch 51 / 65: loss 0.6828
#     ROC-AUC score: 0.8571
#     Batch 54 / 65: loss 0.6815
#     ROC-AUC score: 0.6196
#     Batch 57 / 65: loss 0.6853
#     ROC-AUC score: 0.6194
#     Batch 60 / 65: loss 0.6741
#     ROC-AUC score: 0.6786
#     Batch 63 / 65: loss 0.6675
#     ROC-AUC score: 0.8502
# Epoch 2 / 8
#     Batch 3 / 65: loss 0.6683
#     ROC-AUC score: 0.7063
#     Batch 6 / 65: loss 0.6425
#     ROC-AUC score: 0.8398
#     Batch 9 / 65: loss 0.6476
#     ROC-AUC score: 0.7216
#     Batch 12 / 65: loss 0.6483
#     ROC-AUC score: 0.8268
#     Batch 15 / 65: loss 0.6232
#     ROC-AUC score: 0.5894
#     Batch 18 / 65: loss 0.6706
#     ROC-AUC score: 0.7098
#     Batch 21 / 65: loss 0.6099
#     ROC-AUC score: 0.8042
#     Batch 24 / 65: loss 0.6719
#     ROC-AUC score: 0.7292
#     Batch 27 / 65: loss 0.6507
#     ROC-AUC score: 0.8016
#     Batch 30 / 65: loss 0.6682
#     ROC-AUC score: 0.6484
#     Batch 33 / 65: loss 0.6648
#     ROC-AUC score: 0.4494
#     Batch 36 / 65: loss 0.6395
#     ROC-AUC score: 0.7368
#     Batch 39 / 65: loss 0.6702
#     ROC-AUC score: 0.7000
#     Batch 42 / 65: loss 0.6341
#     ROC-AUC score: 0.6211
#     Batch 45 / 65: loss 0.6250
#     ROC-AUC score: 0.8219
#     Batch 48 / 65: loss 0.6655
#     ROC-AUC score: 0.6314
#     Batch 51 / 65: loss 0.6313
#     ROC-AUC score: 0.6640
#     Batch 54 / 65: loss 0.6438
#     ROC-AUC score: 0.7778
#     Batch 57 / 65: loss 0.5868
#     ROC-AUC score: 0.6549
#     Batch 60 / 65: loss 0.5671
#     ROC-AUC score: 0.7403
#     Batch 63 / 65: loss 0.6555
#     ROC-AUC score: 0.7619
# Epoch 3 / 8
#     Batch 3 / 65: loss 0.5842
#     ROC-AUC score: 0.6941
#     Batch 6 / 65: loss 0.6392
#     ROC-AUC score: 0.7814
#     Batch 9 / 65: loss 0.5629
#     ROC-AUC score: 0.8745
#     Batch 12 / 65: loss 0.5801
#     ROC-AUC score: 0.9219
#     Batch 15 / 65: loss 0.5582
#     ROC-AUC score: 0.7305
#     Batch 18 / 65: loss 0.5922
#     ROC-AUC score: 0.9125
#     Batch 21 / 65: loss 0.6429
#     ROC-AUC score: 0.7216
#     Batch 24 / 65: loss 0.6920
#     ROC-AUC score: 0.5142
#     Batch 27 / 65: loss 0.6270
#     ROC-AUC score: 0.7294
#     Batch 30 / 65: loss 0.5118
#     ROC-AUC score: 0.8647
#     Batch 33 / 65: loss 0.6250
#     ROC-AUC score: 0.6905
#     Batch 36 / 65: loss 0.5806
#     ROC-AUC score: 0.9246
#     Batch 39 / 65: loss 0.5693
#     ROC-AUC score: 0.8625
#     Batch 42 / 65: loss 0.5986
#     ROC-AUC score: 0.7695
#     Batch 45 / 65: loss 0.6366
#     ROC-AUC score: 0.8000
#     Batch 48 / 65: loss 0.5690
#     ROC-AUC score: 0.7895
#     Batch 51 / 65: loss 0.6660
#     ROC-AUC score: 0.7126
#     Batch 54 / 65: loss 0.6177
#     ROC-AUC score: 0.8254
#     Batch 57 / 65: loss 0.6315
#     ROC-AUC score: 0.7083
#     Batch 60 / 65: loss 0.6804
#     ROC-AUC score: 0.5451
#     Batch 63 / 65: loss 0.6468
#     ROC-AUC score: 0.8549
# Epoch 4 / 8
#     Batch 3 / 65: loss 0.6044
#     ROC-AUC score: 0.8214
#     Batch 6 / 65: loss 0.5730
#     ROC-AUC score: 0.7540
#     Batch 9 / 65: loss 0.4965
#     ROC-AUC score: 0.8690
#     Batch 12 / 65: loss 0.5841
#     ROC-AUC score: 0.8545
#     Batch 15 / 65: loss 0.5748
#     ROC-AUC score: 0.7734
#     Batch 18 / 65: loss 0.6087
#     ROC-AUC score: 0.8259
#     Batch 21 / 65: loss 0.5644
#     ROC-AUC score: 0.6964
#     Batch 24 / 65: loss 0.6427
#     ROC-AUC score: 0.7529
#     Batch 27 / 65: loss 0.5553
#     ROC-AUC score: 0.8135
#     Batch 30 / 65: loss 0.6398
#     ROC-AUC score: 0.7835
#     Batch 33 / 65: loss 0.6241
#     ROC-AUC score: 0.8745
#     Batch 36 / 65: loss 0.6480
#     ROC-AUC score: 0.6984
#     Batch 39 / 65: loss 0.6245
#     ROC-AUC score: 0.6133
#     Batch 42 / 65: loss 0.5925
#     ROC-AUC score: 0.7976
#     Batch 45 / 65: loss 0.5348
#     ROC-AUC score: 0.8542
#     Batch 48 / 65: loss 0.5938
#     ROC-AUC score: 0.6032
#     Batch 51 / 65: loss 0.5896
#     ROC-AUC score: 0.9020
#     Batch 54 / 65: loss 0.6003
#     ROC-AUC score: 0.6230
#     Batch 57 / 65: loss 0.5850
#     ROC-AUC score: 0.7255
#     Batch 60 / 65: loss 0.6779
#     ROC-AUC score: 0.5352
#     Batch 63 / 65: loss 0.5861
#     ROC-AUC score: 0.6627
# Epoch 5 / 8
#     Batch 3 / 65: loss 0.5762
#     ROC-AUC score: 0.7247
#     Batch 6 / 65: loss 0.5644
#     ROC-AUC score: 0.7692
#     Batch 9 / 65: loss 0.5532
#     ROC-AUC score: 0.7500
#     Batch 12 / 65: loss 0.6090
#     ROC-AUC score: 0.7045
#     Batch 15 / 65: loss 0.5643
#     ROC-AUC score: 0.7222
#     Batch 18 / 65: loss 0.5392
#     ROC-AUC score: 0.8373
#     Batch 21 / 65: loss 0.6267
#     ROC-AUC score: 0.7143
#     Batch 24 / 65: loss 0.5516
#     ROC-AUC score: 0.8353
#     Batch 27 / 65: loss 0.6198
#     ROC-AUC score: 0.6836
#     Batch 30 / 65: loss 0.6567
#     ROC-AUC score: 0.5882
#     Batch 33 / 65: loss 0.6346
#     ROC-AUC score: 0.7053
#     Batch 36 / 65: loss 0.5838
#     ROC-AUC score: 0.6905
#     Batch 39 / 65: loss 0.5770
#     ROC-AUC score: 0.7569
#     Batch 42 / 65: loss 0.5321
#     ROC-AUC score: 0.8770
#     Batch 45 / 65: loss 0.5765
#     ROC-AUC score: 0.7359
#     Batch 48 / 65: loss 0.5151
#     ROC-AUC score: 0.7652
#     Batch 51 / 65: loss 0.6139
#     ROC-AUC score: 0.7619
#     Batch 54 / 65: loss 0.5588
#     ROC-AUC score: 0.7250
#     Batch 57 / 65: loss 0.6359
#     ROC-AUC score: 0.7148
#     Batch 60 / 65: loss 0.6041
#     ROC-AUC score: 0.7013
#     Batch 63 / 65: loss 0.6791
#     ROC-AUC score: 0.5789
# Epoch 6 / 8
#     Batch 3 / 65: loss 0.5967
#     ROC-AUC score: 0.6706
#     Batch 6 / 65: loss 0.6236
#     ROC-AUC score: 0.8039
#     Batch 9 / 65: loss 0.5427
#     ROC-AUC score: 0.8333
#     Batch 12 / 65: loss 0.5829
#     ROC-AUC score: 0.7417
#     Batch 15 / 65: loss 0.5662
#     ROC-AUC score: 0.8672
#     Batch 18 / 65: loss 0.5912
#     ROC-AUC score: 0.8542
#     Batch 21 / 65: loss 0.5743
#     ROC-AUC score: 0.7576
#     Batch 24 / 65: loss 0.6237
#     ROC-AUC score: 0.7063
#     Batch 27 / 65: loss 0.5474
#     ROC-AUC score: 0.8664
#     Batch 30 / 65: loss 0.5883
#     ROC-AUC score: 0.7500
#     Batch 33 / 65: loss 0.6230
#     ROC-AUC score: 0.6645
#     Batch 36 / 65: loss 0.5838
#     ROC-AUC score: 0.7412
#     Batch 39 / 65: loss 0.5643
#     ROC-AUC score: 0.8135
#     Batch 42 / 65: loss 0.6089
#     ROC-AUC score: 0.7882
#     Batch 45 / 65: loss 0.5826
#     ROC-AUC score: 0.7937
#     Batch 48 / 65: loss 0.5696
#     ROC-AUC score: 0.7804
#     Batch 51 / 65: loss 0.4642
#     ROC-AUC score: 0.8875
#     Batch 54 / 65: loss 0.6032
#     ROC-AUC score: 0.6758
#     Batch 57 / 65: loss 0.7096
#     ROC-AUC score: 0.6599
#     Batch 60 / 65: loss 0.6197
#     ROC-AUC score: 0.8125
#     Batch 63 / 65: loss 0.5207
#     ROC-AUC score: 0.8789
# Epoch 7 / 8
#     Batch 3 / 65: loss 0.6280
#     ROC-AUC score: 0.7188
#     Batch 6 / 65: loss 0.5851
#     ROC-AUC score: 0.9059
#     Batch 9 / 65: loss 0.5819
#     ROC-AUC score: 0.7489
#     Batch 12 / 65: loss 0.5668
#     ROC-AUC score: 0.7421
#     Batch 15 / 65: loss 0.5650
#     ROC-AUC score: 0.6602
#     Batch 18 / 65: loss 0.6156
#     ROC-AUC score: 0.6667
#     Batch 21 / 65: loss 0.6133
#     ROC-AUC score: 0.6941
#     Batch 24 / 65: loss 0.5715
#     ROC-AUC score: 0.8849
#     Batch 27 / 65: loss 0.5745
#     ROC-AUC score: 0.7891
#     Batch 30 / 65: loss 0.5135
#     ROC-AUC score: 0.9246
#     Batch 33 / 65: loss 0.5798
#     ROC-AUC score: 0.8745
#     Batch 36 / 65: loss 0.5390
#     ROC-AUC score: 0.7368
#     Batch 39 / 65: loss 0.5292
#     ROC-AUC score: 0.7917
#     Batch 42 / 65: loss 0.6139
#     ROC-AUC score: 0.8000
#     Batch 45 / 65: loss 0.5604
#     ROC-AUC score: 0.7619
#     Batch 48 / 65: loss 0.5933
#     ROC-AUC score: 0.7045
#     Batch 51 / 65: loss 0.6567
#     ROC-AUC score: 0.8254
#     Batch 54 / 65: loss 0.5968
#     ROC-AUC score: 0.7137
#     Batch 57 / 65: loss 0.5631
#     ROC-AUC score: 0.6518
#     Batch 60 / 65: loss 0.5218
#     ROC-AUC score: 0.9137
#     Batch 63 / 65: loss 0.6544
#     ROC-AUC score: 0.6640
# Epoch 8 / 8
#     Batch 3 / 65: loss 0.5397
#     ROC-AUC score: 0.7461
#     Batch 6 / 65: loss 0.5485
#     ROC-AUC score: 0.8242
#     Batch 9 / 65: loss 0.5234
#     ROC-AUC score: 0.8471
#     Batch 12 / 65: loss 0.5598
#     ROC-AUC score: 0.7617
#     Batch 15 / 65: loss 0.6067
#     ROC-AUC score: 0.6721
#     Batch 18 / 65: loss 0.6605
#     ROC-AUC score: 0.7490
#     Batch 21 / 65: loss 0.6154
#     ROC-AUC score: 0.6039
#     Batch 24 / 65: loss 0.5316
#     ROC-AUC score: 0.6964
#     Batch 27 / 65: loss 0.5457
#     ROC-AUC score: 0.8000
#     Batch 30 / 65: loss 0.5451
#     ROC-AUC score: 0.7733
#     Batch 33 / 65: loss 0.5308
#     ROC-AUC score: 0.6167
#     Batch 36 / 65: loss 0.5621
#     ROC-AUC score: 0.8196
#     Batch 39 / 65: loss 0.5877
#     ROC-AUC score: 0.6458
#     Batch 42 / 65: loss 0.5676
#     ROC-AUC score: 0.7227
#     Batch 45 / 65: loss 0.6217
#     ROC-AUC score: 0.8636
#     Batch 48 / 65: loss 0.5677
#     ROC-AUC score: 0.8086
#     Batch 51 / 65: loss 0.5680
#     ROC-AUC score: 0.8125
#     Batch 54 / 65: loss 0.6309
#     ROC-AUC score: 0.7725
#     Batch 57 / 65: loss 0.6486
#     ROC-AUC score: 0.7176
#     Batch 60 / 65: loss 0.6380
#     ROC-AUC score: 0.8157
#     Batch 63 / 65: loss 0.5716
#     ROC-AUC score: 0.8314
# Finished training.
# --------------------------------

# %%
if not config['load']:
    if config['save']:
        print('--------------------------------')
        directory = os.path.join(os.path.dirname(os.getcwd()),
                                'trained_models')
        if not os.path.exists(directory):
            os.makedirs(directory)
        fname = utils.get_fname(config)
        path = os.path.join(directory, fname)
        print('Saving model at {}'.format(path))
        torch.save(model.state_dict(), path)
        print('Finished saving model.')
        print('--------------------------------')

# %% [markdown]
# # Compute ROC-AUC score after training.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset after training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset after training.
#     Batch 1 / 65
#     Batch 2 / 65
#     Batch 3 / 65
#     Batch 4 / 65
#     Batch 5 / 65
#     Batch 6 / 65
#     Batch 7 / 65
#     Batch 8 / 65
#     Batch 9 / 65
#     Batch 10 / 65
#     Batch 11 / 65
#     Batch 12 / 65
#     Batch 13 / 65
#     Batch 14 / 65
#     Batch 15 / 65
#     Batch 16 / 65
#     Batch 17 / 65
#     Batch 18 / 65
#     Batch 19 / 65
#     Batch 20 / 65
#     Batch 21 / 65
#     Batch 22 / 65
#     Batch 23 / 65
#     Batch 24 / 65
#     Batch 25 / 65
#     Batch 26 / 65
#     Batch 27 / 65
#     Batch 28 / 65
#     Batch 29 / 65
#     Batch 30 / 65
#     Batch 31 / 65
#     Batch 32 / 65
#     Batch 33 / 65
#     Batch 34 / 65
#     Batch 35 / 65
#     Batch 36 / 65
#     Batch 37 / 65
#     Batch 38 / 65
#     Batch 39 / 65
#     Batch 40 / 65
#     Batch 41 / 65
#     Batch 42 / 65
#     Batch 43 / 65
#     Batch 44 / 65
#     Batch 45 / 65
#     Batch 46 / 65
#     Batch 47 / 65
#     Batch 48 / 65
#     Batch 49 / 65
#     Batch 50 / 65
#     Batch 51 / 65
#     Batch 52 / 65
#     Batch 53 / 65
#     Batch 54 / 65
#     Batch 55 / 65
#     Batch 56 / 65
#     Batch 57 / 65
#     Batch 58 / 65
#     Batch 59 / 65
#     Batch 60 / 65
#     Batch 61 / 65
#     Batch 62 / 65
#     Batch 63 / 65
#     Batch 64 / 65
#     Batch 65 / 65
# ROC-AUC score: 0.7874
# --------------------------------

# %% [markdown]
# # Plot the true positive rate and true negative rate vs threshold.

# %%
if not config['load']:
    tpr, fpr, thresholds = roc_curve(y_true, y_scores)
    tnr = 1 - fpr
    plt.plot(thresholds, tpr, label='tpr')
    plt.plot(thresholds, tnr, label='tnr')
    plt.xlabel('Threshold')
    plt.title('TPR / TNR vs Threshold')
    plt.legend()

# %% [markdown]
# # Choose an appropriate threshold and generate classification report on the train set.

# %%
idx1 = np.where(tpr <= tnr)[0]
idx2 = np.where(tpr >= tnr)[0]
t = thresholds[idx1[-1]]
total_correct, total_examples = 0, 0
y_true, y_pred = [], []
num_batches = int(ceil(len(dataset) / config['batch_size']))
with torch.no_grad():
    for (idx, batch) in enumerate(loader):
        edges, features, node_layers, mappings, rows, labels = batch
        features, labels = features.to(device), labels.to(device)
        out = model(features, node_layers, mappings, rows)
        all_pairs = torch.mm(out, out.t())
        scores = all_pairs[edges.T]
        predictions = (scores >= t).long()
        y_true.extend(labels.detach().numpy())
        y_pred.extend(predictions.detach().numpy())
        total_correct += torch.sum(predictions == labels.long()).item()
        total_examples += len(labels) 
        print('    Batch {} / {}'.format(idx+1, num_batches))
print('Threshold: {:.4f}, accuracy: {:.4f}'.format(t, total_correct / total_examples))
y_true = np.array(y_true).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
print('Classification report\n', report)
# Out:
#     Batch 1 / 65
#     Batch 2 / 65
#     Batch 3 / 65
#     Batch 4 / 65
#     Batch 5 / 65
#     Batch 6 / 65
#     Batch 7 / 65
#     Batch 8 / 65
#     Batch 9 / 65
#     Batch 10 / 65
#     Batch 11 / 65
#     Batch 12 / 65
#     Batch 13 / 65
#     Batch 14 / 65
#     Batch 15 / 65
#     Batch 16 / 65
#     Batch 17 / 65
#     Batch 18 / 65
#     Batch 19 / 65
#     Batch 20 / 65
#     Batch 21 / 65
#     Batch 22 / 65
#     Batch 23 / 65
#     Batch 24 / 65
#     Batch 25 / 65
#     Batch 26 / 65
#     Batch 27 / 65
#     Batch 28 / 65
#     Batch 29 / 65
#     Batch 30 / 65
#     Batch 31 / 65
#     Batch 32 / 65
#     Batch 33 / 65
#     Batch 34 / 65
#     Batch 35 / 65
#     Batch 36 / 65
#     Batch 37 / 65
#     Batch 38 / 65
#     Batch 39 / 65
#     Batch 40 / 65
#     Batch 41 / 65
#     Batch 42 / 65
#     Batch 43 / 65
#     Batch 44 / 65
#     Batch 45 / 65
#     Batch 46 / 65
#     Batch 47 / 65
#     Batch 48 / 65
#     Batch 49 / 65
#     Batch 50 / 65
#     Batch 51 / 65
#     Batch 52 / 65
#     Batch 53 / 65
#     Batch 54 / 65
#     Batch 55 / 65
#     Batch 56 / 65
#     Batch 57 / 65
#     Batch 58 / 65
#     Batch 59 / 65
#     Batch 60 / 65
#     Batch 61 / 65
#     Batch 62 / 65
#     Batch 63 / 65
#     Batch 64 / 65
#     Batch 65 / 65
# Threshold: 0.1539, accuracy: 0.7001
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.70      0.70      1027
#          1.0       0.70      0.70      0.70      1027
#
#     accuracy                           0.70      2054
#    macro avg       0.70      0.70      0.70      2054
# weighted avg       0.70      0.70      0.70      2054

# %% [markdown]
# # Evaluate on validation set.

# %%
if config['load']:
    directory = os.path.join(os.path.dirname(os.getcwd()),
                             'trained_models')
    fname = utils.get_fname(config)
    path = os.path.join(directory, fname)
    model.load_state_dict(torch.load(path))
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'val',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=False, collate_fn=dataset.collate_wrapper)
criterion = utils.get_criterion(config['task'])
stats_per_batch = config['stats_per_batch']
num_batches = int(ceil(len(dataset) / config['batch_size']))
model.eval()
print('--------------------------------')
print('Computing ROC-AUC score for the validation dataset after training.')
running_loss, total_loss = 0.0, 0.0
num_correct, num_examples = 0, 0
total_correct, total_examples = 0, 0
y_true, y_scores, y_pred = [], [], []
for (idx, batch) in enumerate(loader):
    edges, features, node_layers, mappings, rows, labels = batch
    features, labels = features.to(device), labels.to(device)
    out = model(features, node_layers, mappings, rows)
    all_pairs = torch.mm(out, out.t())
    scores = all_pairs[edges.T]
    loss = criterion(scores, labels.float())
    running_loss += loss.item()
    total_loss += loss.item()
    predictions = (scores >= t).long()
    num_correct += torch.sum(predictions == labels.long()).item()
    total_correct += torch.sum(predictions == labels.long()).item()
    num_examples += len(labels)
    total_examples += len(labels)
    y_true.extend(labels.detach().numpy())
    y_scores.extend(scores.detach().numpy())
    y_pred.extend(predictions.detach().numpy())
    if (idx + 1) % stats_per_batch == 0:
        running_loss /= stats_per_batch
        accuracy = num_correct / num_examples
        print('    Batch {} / {}: loss {:.4f}, accuracy {:.4f}'.format(
            idx+1, num_batches, running_loss, accuracy))
        if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
            area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
            print('    ROC-AUC score: {:.4f}'.format(area))
        running_loss = 0.0
        num_correct, num_examples = 0, 0
total_loss /= num_batches
total_accuracy = total_correct / total_examples
print('Loss {:.4f}, accuracy {:.4f}'.format(total_loss, total_accuracy))
y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
area = roc_auc_score(y_true, y_scores)
print('ROC-AUC score: {:.4f}'.format(area))
print('Classification report\n', report)
print('Finished validating.')
print('--------------------------------')
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-enron-employees/ia-enron-employees.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: val
# Number of vertices: 151
# Number of static edges: 1488
# Number of temporal edges: 25286
# Number of examples/datapoints: 1718
# --------------------------------
# --------------------------------
# Computing ROC-AUC score for the validation dataset after training.
#     Batch 3 / 54: loss 0.6984, accuracy 0.5729
#     ROC-AUC score: 0.6508
#     Batch 6 / 54: loss 0.6892, accuracy 0.6042
#     ROC-AUC score: 0.6314
#     Batch 9 / 54: loss 0.6275, accuracy 0.6354
#     ROC-AUC score: 0.7583
#     Batch 12 / 54: loss 0.6377, accuracy 0.5833
#     ROC-AUC score: 0.5992
#     Batch 15 / 54: loss 0.6319, accuracy 0.6042
#     ROC-AUC score: 0.6708
#     Batch 18 / 54: loss 0.6380, accuracy 0.6979
#     ROC-AUC score: 0.6625
#     Batch 21 / 54: loss 0.5966, accuracy 0.6771
#     ROC-AUC score: 0.7542
#     Batch 24 / 54: loss 0.6537, accuracy 0.6667
#     ROC-AUC score: 0.6824
#     Batch 27 / 54: loss 0.6336, accuracy 0.6771
#     ROC-AUC score: 0.7773
#     Batch 30 / 54: loss 0.6964, accuracy 0.6667
#     ROC-AUC score: 0.6275
#     Batch 33 / 54: loss 0.6751, accuracy 0.6667
#     ROC-AUC score: 0.7725
#     Batch 36 / 54: loss 0.5925, accuracy 0.6667
#     ROC-AUC score: 0.8275
#     Batch 39 / 54: loss 0.7000, accuracy 0.5729
#     ROC-AUC score: 0.6275
#     Batch 42 / 54: loss 0.6367, accuracy 0.6667
#     ROC-AUC score: 0.7843
#     Batch 45 / 54: loss 0.6755, accuracy 0.6562
#     ROC-AUC score: 0.6549
#     Batch 48 / 54: loss 0.6337, accuracy 0.6667
#     ROC-AUC score: 0.8219
#     Batch 51 / 54: loss 0.7020, accuracy 0.6250
#     ROC-AUC score: 0.5137
#     Batch 54 / 54: loss 0.6690, accuracy 0.5930
#     ROC-AUC score: 0.7009
# Loss 0.6549, accuracy 0.6391
# ROC-AUC score: 0.6947
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.64      0.65      0.64       859
#          1.0       0.64      0.63      0.64       859
#
#     accuracy                           0.64      1718
#    macro avg       0.64      0.64      0.64      1718
# weighted avg       0.64      0.64      0.64      1718
#
# Finished validating.
# --------------------------------

# %% [markdown]
# # Evaluate on test set.

# %%
if config['load']:
    directory = os.path.join(os.path.dirname(os.getcwd()),
                             'trained_models')
    fname = utils.get_fname(config)
    path = os.path.join(directory, fname)
    model.load_state_dict(torch.load(path))
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'test',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=False, collate_fn=dataset.collate_wrapper)
criterion = utils.get_criterion(config['task'])
stats_per_batch = config['stats_per_batch']
num_batches = int(ceil(len(dataset) / config['batch_size']))
model.eval()
print('--------------------------------')
print('Computing ROC-AUC score for the test dataset after training.')
running_loss, total_loss = 0.0, 0.0
num_correct, num_examples = 0, 0
total_correct, total_examples = 0, 0
y_true, y_scores, y_pred = [], [], []
for (idx, batch) in enumerate(loader):
    edges, features, node_layers, mappings, rows, labels = batch
    features, labels = features.to(device), labels.to(device)
    out = model(features, node_layers, mappings, rows)
    all_pairs = torch.mm(out, out.t())
    scores = all_pairs[edges.T]
    loss = criterion(scores, labels.float())
    running_loss += loss.item()
    total_loss += loss.item()
    predictions = (scores >= t).long()
    num_correct += torch.sum(predictions == labels.long()).item()
    total_correct += torch.sum(predictions == labels.long()).item()
    num_examples += len(labels)
    total_examples += len(labels)
    y_true.extend(labels.detach().numpy())
    y_scores.extend(scores.detach().numpy())
    y_pred.extend(predictions.detach().numpy())
    if (idx + 1) % stats_per_batch == 0:
        running_loss /= stats_per_batch
        accuracy = num_correct / num_examples
        print('    Batch {} / {}: loss {:.4f}, accuracy {:.4f}'.format(
            idx+1, num_batches, running_loss, accuracy))
        if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
            area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
            print('    ROC-AUC score: {:.4f}'.format(area))
        running_loss = 0.0
        num_correct, num_examples = 0, 0
total_loss /= num_batches
total_accuracy = total_correct / total_examples
print('Loss {:.4f}, accuracy {:.4f}'.format(total_loss, total_accuracy))
y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
area = roc_auc_score(y_true, y_scores)
print('ROC-AUC score: {:.4f}'.format(area))
print('Classification report\n', report)
print('Finished testing.')
print('--------------------------------')
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-enron-employees/ia-enron-employees.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: test
# Number of vertices: 151
# Number of static edges: 1888
# Number of temporal edges: 37929
# Number of examples/datapoints: 1660
# --------------------------------
# --------------------------------
# Computing ROC-AUC score for the test dataset after training.
#     Batch 3 / 52: loss 0.6764, accuracy 0.6875
#     ROC-AUC score: 0.6104
#     Batch 6 / 52: loss 0.6218, accuracy 0.6250
#     ROC-AUC score: 0.7895
#     Batch 9 / 52: loss 0.6532, accuracy 0.6562
#     ROC-AUC score: 0.6375
#     Batch 12 / 52: loss 0.7105, accuracy 0.6042
#     ROC-AUC score: 0.5833
#     Batch 15 / 52: loss 0.6570, accuracy 0.6458
#     ROC-AUC score: 0.7333
#     Batch 18 / 52: loss 0.6386, accuracy 0.6771
#     ROC-AUC score: 0.7611
#     Batch 21 / 52: loss 0.6607, accuracy 0.6562
#     ROC-AUC score: 0.6875
#     Batch 24 / 52: loss 0.6232, accuracy 0.7396
#     ROC-AUC score: 0.7656
#     Batch 27 / 52: loss 0.6972, accuracy 0.6146
#     ROC-AUC score: 0.6349
#     Batch 30 / 52: loss 0.6895, accuracy 0.5729
#     ROC-AUC score: 0.6667
#     Batch 33 / 52: loss 0.6356, accuracy 0.6354
#     ROC-AUC score: 0.6111
#     Batch 36 / 52: loss 0.7021, accuracy 0.5208
#     ROC-AUC score: 0.6437
#     Batch 39 / 52: loss 0.5842, accuracy 0.7083
#     ROC-AUC score: 0.7344
#     Batch 42 / 52: loss 0.6795, accuracy 0.6354
#     ROC-AUC score: 0.7059
#     Batch 45 / 52: loss 0.7124, accuracy 0.5729
#     ROC-AUC score: 0.6196
#     Batch 48 / 52: loss 0.6644, accuracy 0.6146
#     ROC-AUC score: 0.7529
#     Batch 51 / 52: loss 0.6510, accuracy 0.6458
#     ROC-AUC score: 0.6784
# Loss 0.6656, accuracy 0.6331
# ROC-AUC score: 0.6804
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.63      0.64      0.64       830
#          1.0       0.64      0.62      0.63       830
#
#     accuracy                           0.63      1660
#    macro avg       0.63      0.63      0.63      1660
# weighted avg       0.63      0.63      0.63      1660
#
# Finished testing.
# --------------------------------
