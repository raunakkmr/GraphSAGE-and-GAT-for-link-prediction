# %% [markdown]
# # Imports

# %%
from math import ceil
import json
import os
import sys

src_path = os.path.join(os.path.dirname(os.path.abspath('')), 'src')
sys.path.append(src_path)

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve, classification_report
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import visdom

from datasets import link_prediction
from layers import MeanAggregator, LSTMAggregator, MaxPoolAggregator, MeanPoolAggregator
import models
import utils

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set up arguments for datasets, models and training.

# %%
args = {
    "task" : "link_prediction",
    
    "dataset" : "IAContact",
    "dataset_path" : "/Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contact/ia-contact.edges",
    "mode" : "train",
    "generate_neg_examples" : True,
    
    "duplicate_examples" : False,
    "repeat_examples" : False,
    
    "self_loop" : True,
    "normalize_adj" : False,
    
    "cuda" : "True",
    "model" : "GraphSAGE",
    "agg_class" : "MaxPoolAggregator",
    "hidden_dims" : [64],
    "dropout" : 0,
    "num_samples" : -1,
    
    "epochs" : 10,
    "batch_size" : 32,
    "lr" : 5e-4,
    "weight_decay" : 1e-3,
    "stats_per_batch" : 3,
    "visdom" : True,
    
    "load" : False,
    "save" : False
}
config = args
config['num_layers'] = len(config['hidden_dims']) + 1


if config['cuda'] and torch.cuda.is_available():
    device = 'cuda:0'
else:
    device = 'cpu'
config['device'] = device

# %% [markdown]
# # Get the dataset, dataloader and model.

# %%
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'train',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contact/ia-contact.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: train
# Number of vertices: 274
# Number of static edges: 1686
# Number of temporal edges: 8473
# Number of examples/datapoints: 1290
# --------------------------------

# %%
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=True, collate_fn=dataset.collate_wrapper)
input_dim, output_dim = dataset.get_dims()

# %%
agg_class = utils.get_agg_class(config['agg_class'])
model = models.GraphSAGE(input_dim, config['hidden_dims'],
                         output_dim, config['dropout'],
                         agg_class, config['num_samples'],
                         config['device'])
model.to(config['device'])
print(model)
# Out:
# GraphSAGE(
#   (aggregators): ModuleList(
#     (0): MaxPoolAggregator(
#       (fc1): Linear(in_features=274, out_features=274, bias=True)
#       (relu): ReLU()
#     )
#     (1): MaxPoolAggregator(
#       (fc1): Linear(in_features=64, out_features=64, bias=True)
#       (relu): ReLU()
#     )
#   )
#   (fcs): ModuleList(
#     (0): Linear(in_features=548, out_features=64, bias=True)
#     (1): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dropout): Dropout(p=0)
#   (relu): ReLU()
# )

# %% [markdown]
# # Compute ROC-AUC score for the untrained model.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset before training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset before training.
#     Batch 1 / 41
#     Batch 2 / 41
#     Batch 3 / 41
#     Batch 4 / 41
#     Batch 5 / 41
#     Batch 6 / 41
#     Batch 7 / 41
#     Batch 8 / 41
#     Batch 9 / 41
#     Batch 10 / 41
#     Batch 11 / 41
#     Batch 12 / 41
#     Batch 13 / 41
#     Batch 14 / 41
#     Batch 15 / 41
#     Batch 16 / 41
#     Batch 17 / 41
#     Batch 18 / 41
#     Batch 19 / 41
#     Batch 20 / 41
#     Batch 21 / 41
#     Batch 22 / 41
#     Batch 23 / 41
#     Batch 24 / 41
#     Batch 25 / 41
#     Batch 26 / 41
#     Batch 27 / 41
#     Batch 28 / 41
#     Batch 29 / 41
#     Batch 30 / 41
#     Batch 31 / 41
#     Batch 32 / 41
#     Batch 33 / 41
#     Batch 34 / 41
#     Batch 35 / 41
#     Batch 36 / 41
#     Batch 37 / 41
#     Batch 38 / 41
#     Batch 39 / 41
#     Batch 40 / 41
#     Batch 41 / 41
# ROC-AUC score: 0.3920
# --------------------------------

# %% [markdown]
# # Train.

# %%
if not config['load']:
    use_visdom = config['visdom']
    if use_visdom:
        vis = visdom.Visdom()
        loss_window = None
    criterion = utils.get_criterion(config['task'])
    optimizer = optim.Adam(model.parameters(), lr=config['lr'],
                           weight_decay=config['weight_decay'])
    epochs = config['epochs']
    stats_per_batch = config['stats_per_batch']
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    # scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=150, gamma=0.8)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[200, 400], gamma=0.7)
    model.train()
    print('--------------------------------')
    print('Training.')
    for epoch in range(epochs):
        print('Epoch {} / {}'.format(epoch+1, epochs))
        running_loss = 0.0
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            loss = criterion(scores, labels.float())
            loss.backward()
            optimizer.step()
            with torch.no_grad():
                running_loss += loss.item()
            if (idx + 1) % stats_per_batch == 0:
                running_loss /= stats_per_batch
                print('    Batch {} / {}: loss {:.4f}'.format(
                    idx+1, num_batches, running_loss))
                if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
                    area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
                    print('    ROC-AUC score: {:.4f}'.format(area))
                running_loss = 0.0
                num_correct, num_examples = 0, 0
            if use_visdom:
                if loss_window is None:
                    loss_window = vis.line(
                        Y=[loss.item()],
                        X=[epoch*num_batches+idx],
                        opts=dict(xlabel='batch', ylabel='Loss', title='Training Loss', legend=['Loss']))
                else:
                    vis.line(
                        [loss.item()],
                        [epoch*num_batches+idx],
                        win=loss_window,
                        update='append')
            scheduler.step()
    if use_visdom:
        vis.close(win=loss_window)
    print('Finished training.')
    print('--------------------------------')
# Out:
# WARNING:root:Setting up a new session...
# --------------------------------
# Training.
# Epoch 1 / 10
#     Batch 3 / 41: loss 0.6930
#     ROC-AUC score: 0.7150
#     Batch 6 / 41: loss 0.6915
#     ROC-AUC score: 0.5545
#     Batch 9 / 41: loss 0.6896
#     ROC-AUC score: 0.7930
#     Batch 12 / 41: loss 0.6842
#     ROC-AUC score: 0.8863
#     Batch 15 / 41: loss 0.6804
#     ROC-AUC score: 0.9405
#     Batch 18 / 41: loss 0.6736
#     ROC-AUC score: 0.9206
#     Batch 21 / 41: loss 0.6723
#     ROC-AUC score: 0.9667
#     Batch 24 / 41: loss 0.6603
#     ROC-AUC score: 0.9843
#     Batch 27 / 41: loss 0.6444
#     ROC-AUC score: 0.9451
#     Batch 30 / 41: loss 0.6551
#     ROC-AUC score: 0.9514
#     Batch 33 / 41: loss 0.6318
#     ROC-AUC score: 0.9766
#     Batch 36 / 41: loss 0.6203
#     ROC-AUC score: 0.9542
#     Batch 39 / 41: loss 0.6191
#     ROC-AUC score: 0.9647
# Epoch 2 / 10
#     Batch 3 / 41: loss 0.5804
#     ROC-AUC score: 1.0000
#     Batch 6 / 41: loss 0.5687
#     ROC-AUC score: 1.0000
#     Batch 9 / 41: loss 0.5750
#     ROC-AUC score: 0.9758
#     Batch 12 / 41: loss 0.5199
#     ROC-AUC score: 0.9583
#     Batch 15 / 41: loss 0.5205
#     ROC-AUC score: 0.9333
#     Batch 18 / 41: loss 0.4871
#     ROC-AUC score: 1.0000
#     Batch 21 / 41: loss 0.4931
#     ROC-AUC score: 0.9804
#     Batch 24 / 41: loss 0.4976
#     ROC-AUC score: 1.0000
#     Batch 27 / 41: loss 0.5335
#     ROC-AUC score: 0.9864
#     Batch 30 / 41: loss 0.4245
#     ROC-AUC score: 1.0000
#     Batch 33 / 41: loss 0.3989
#     ROC-AUC score: 0.9805
#     Batch 36 / 41: loss 0.4729
#     ROC-AUC score: 0.9365
#     Batch 39 / 41: loss 0.4611
#     ROC-AUC score: 1.0000
# Epoch 3 / 10
#     Batch 3 / 41: loss 0.4851
#     ROC-AUC score: 0.9453
#     Batch 6 / 41: loss 0.3731
#     ROC-AUC score: 0.9805
#     Batch 9 / 41: loss 0.4272
#     ROC-AUC score: 0.9957
#     Batch 12 / 41: loss 0.3976
#     ROC-AUC score: 1.0000
#     Batch 15 / 41: loss 0.3861
#     ROC-AUC score: 0.9569
#     Batch 18 / 41: loss 0.4581
#     ROC-AUC score: 0.9412
#     Batch 21 / 41: loss 0.3812
#     ROC-AUC score: 0.9921
#     Batch 24 / 41: loss 0.3708
#     ROC-AUC score: 1.0000
#     Batch 27 / 41: loss 0.4329
#     ROC-AUC score: 1.0000
#     Batch 30 / 41: loss 0.3694
#     ROC-AUC score: 1.0000
#     Batch 33 / 41: loss 0.4448
#     ROC-AUC score: 0.9255
#     Batch 36 / 41: loss 0.3484
#     ROC-AUC score: 1.0000
#     Batch 39 / 41: loss 0.3387
#     ROC-AUC score: 0.9843
# Epoch 4 / 10
#     Batch 3 / 41: loss 0.3276
#     ROC-AUC score: 0.9921
#     Batch 6 / 41: loss 0.3453
#     ROC-AUC score: 0.9961
#     Batch 9 / 41: loss 0.3237
#     ROC-AUC score: 0.9453
#     Batch 12 / 41: loss 0.4165
#     ROC-AUC score: 1.0000
#     Batch 15 / 41: loss 0.4058
#     ROC-AUC score: 1.0000
#     Batch 18 / 41: loss 0.3382
#     ROC-AUC score: 1.0000
#     Batch 21 / 41: loss 0.3854
#     ROC-AUC score: 0.9414
#     Batch 24 / 41: loss 0.3315
#     ROC-AUC score: 0.9773
#     Batch 27 / 41: loss 0.3605
#     ROC-AUC score: 1.0000
#     Batch 30 / 41: loss 0.3415
#     ROC-AUC score: 1.0000
#     Batch 33 / 41: loss 0.3287
#     ROC-AUC score: 1.0000
#     Batch 36 / 41: loss 0.3661
#     ROC-AUC score: 1.0000
#     Batch 39 / 41: loss 0.3654
#     ROC-AUC score: 0.9393
# Epoch 5 / 10
#     Batch 3 / 41: loss 0.3242
#     ROC-AUC score: 1.0000
#     Batch 6 / 41: loss 0.3343
#     ROC-AUC score: 0.9961
#     Batch 9 / 41: loss 0.3116
#     ROC-AUC score: 0.9688
#     Batch 12 / 41: loss 0.3109
#     ROC-AUC score: 1.0000
#     Batch 15 / 41: loss 0.3690
#     ROC-AUC score: 0.9569
#     Batch 18 / 41: loss 0.3030
#     ROC-AUC score: 0.9762
#     Batch 21 / 41: loss 0.2768
#     ROC-AUC score: 1.0000
#     Batch 24 / 41: loss 0.3253
#     ROC-AUC score: 1.0000
#     Batch 27 / 41: loss 0.3745
#     ROC-AUC score: 0.9417
#     Batch 30 / 41: loss 0.4320
#     ROC-AUC score: 0.9879
#     Batch 33 / 41: loss 0.3266
#     ROC-AUC score: 0.9921
#     Batch 36 / 41: loss 0.3110
#     ROC-AUC score: 0.9524
#     Batch 39 / 41: loss 0.3564
#     ROC-AUC score: 0.9176
# Epoch 6 / 10
#     Batch 3 / 41: loss 0.2705
#     ROC-AUC score: 1.0000
#     Batch 6 / 41: loss 0.2972
#     ROC-AUC score: 1.0000
#     Batch 9 / 41: loss 0.2810
#     ROC-AUC score: 1.0000
#     Batch 12 / 41: loss 0.3969
#     ROC-AUC score: 0.9028
#     Batch 15 / 41: loss 0.2480
#     ROC-AUC score: 1.0000
#     Batch 18 / 41: loss 0.2929
#     ROC-AUC score: 1.0000
#     Batch 21 / 41: loss 0.3311
#     ROC-AUC score: 0.9762
#     Batch 24 / 41: loss 0.3033
#     ROC-AUC score: 0.9524
#     Batch 27 / 41: loss 0.3968
#     ROC-AUC score: 0.9921
#     Batch 30 / 41: loss 0.3190
#     ROC-AUC score: 1.0000
#     Batch 33 / 41: loss 0.3612
#     ROC-AUC score: 0.9773
#     Batch 36 / 41: loss 0.2970
#     ROC-AUC score: 0.9961
#     Batch 39 / 41: loss 0.3166
#     ROC-AUC score: 0.9960
# Epoch 7 / 10
#     Batch 3 / 41: loss 0.4043
#     ROC-AUC score: 0.9524
#     Batch 6 / 41: loss 0.2278
#     ROC-AUC score: 1.0000
#     Batch 9 / 41: loss 0.3318
#     ROC-AUC score: 0.9569
#     Batch 12 / 41: loss 0.3630
#     ROC-AUC score: 1.0000
#     Batch 15 / 41: loss 0.3284
#     ROC-AUC score: 0.9683
#     Batch 18 / 41: loss 0.3234
#     ROC-AUC score: 0.9960
#     Batch 21 / 41: loss 0.3147
#     ROC-AUC score: 0.9708
#     Batch 24 / 41: loss 0.2975
#     ROC-AUC score: 1.0000
#     Batch 27 / 41: loss 0.2860
#     ROC-AUC score: 1.0000
#     Batch 30 / 41: loss 0.2212
#     ROC-AUC score: 1.0000
#     Batch 33 / 41: loss 0.3249
#     ROC-AUC score: 1.0000
#     Batch 36 / 41: loss 0.3497
#     ROC-AUC score: 0.9917
#     Batch 39 / 41: loss 0.2546
#     ROC-AUC score: 1.0000
# Epoch 8 / 10
#     Batch 3 / 41: loss 0.3119
#     ROC-AUC score: 0.9960
#     Batch 6 / 41: loss 0.2497
#     ROC-AUC score: 1.0000
#     Batch 9 / 41: loss 0.2483
#     ROC-AUC score: 1.0000
#     Batch 12 / 41: loss 0.2933
#     ROC-AUC score: 0.9667
#     Batch 15 / 41: loss 0.3225
#     ROC-AUC score: 0.9177
#     Batch 18 / 41: loss 0.3434
#     ROC-AUC score: 1.0000
#     Batch 21 / 41: loss 0.2708
#     ROC-AUC score: 1.0000
#     Batch 24 / 41: loss 0.2612
#     ROC-AUC score: 1.0000
#     Batch 27 / 41: loss 0.2636
#     ROC-AUC score: 1.0000
#     Batch 30 / 41: loss 0.3339
#     ROC-AUC score: 0.9757
#     Batch 33 / 41: loss 0.2931
#     ROC-AUC score: 0.9961
#     Batch 36 / 41: loss 0.3609
#     ROC-AUC score: 0.9717
#     Batch 39 / 41: loss 0.3616
#     ROC-AUC score: 1.0000
# Epoch 9 / 10
#     Batch 3 / 41: loss 0.2610
#     ROC-AUC score: 1.0000
#     Batch 6 / 41: loss 0.2504
#     ROC-AUC score: 1.0000
#     Batch 9 / 41: loss 0.3383
#     ROC-AUC score: 1.0000
#     Batch 12 / 41: loss 0.3379
#     ROC-AUC score: 1.0000
#     Batch 15 / 41: loss 0.4135
#     ROC-AUC score: 0.9881
#     Batch 18 / 41: loss 0.3404
#     ROC-AUC score: 1.0000
#     Batch 21 / 41: loss 0.3006
#     ROC-AUC score: 0.9881
#     Batch 24 / 41: loss 0.2541
#     ROC-AUC score: 0.9807
#     Batch 27 / 41: loss 0.2538
#     ROC-AUC score: 0.9922
#     Batch 30 / 41: loss 0.3099
#     ROC-AUC score: 0.9922
#     Batch 33 / 41: loss 0.2851
#     ROC-AUC score: 1.0000
#     Batch 36 / 41: loss 0.2433
#     ROC-AUC score: 0.9686
#     Batch 39 / 41: loss 0.2850
#     ROC-AUC score: 1.0000
# Epoch 10 / 10
#     Batch 3 / 41: loss 0.3880
#     ROC-AUC score: 0.9922
#     Batch 6 / 41: loss 0.2709
#     ROC-AUC score: 0.9881
#     Batch 9 / 41: loss 0.3130
#     ROC-AUC score: 0.9881
#     Batch 12 / 41: loss 0.2740
#     ROC-AUC score: 1.0000
#     Batch 15 / 41: loss 0.3043
#     ROC-AUC score: 0.9921
#     Batch 18 / 41: loss 0.3329
#     ROC-AUC score: 1.0000
#     Batch 21 / 41: loss 0.2603
#     ROC-AUC score: 1.0000
#     Batch 24 / 41: loss 0.2250
#     ROC-AUC score: 1.0000
#     Batch 27 / 41: loss 0.2434
#     ROC-AUC score: 1.0000
#     Batch 30 / 41: loss 0.2856
#     ROC-AUC score: 0.9960
#     Batch 33 / 41: loss 0.2662
#     ROC-AUC score: 1.0000
#     Batch 36 / 41: loss 0.2300
#     ROC-AUC score: 0.9838
#     Batch 39 / 41: loss 0.3365
#     ROC-AUC score: 0.9750
# Finished training.
# --------------------------------

# %%
if not config['load']:
    if config['save']:
        print('--------------------------------')
        directory = os.path.join(os.path.dirname(os.getcwd()),
                                'trained_models')
        if not os.path.exists(directory):
            os.makedirs(directory)
        fname = utils.get_fname(config)
        path = os.path.join(directory, fname)
        print('Saving model at {}'.format(path))
        torch.save(model.state_dict(), path)
        print('Finished saving model.')
        print('--------------------------------')

# %% [markdown]
# # Compute ROC-AUC score after training.

# %%
if not config['load']:
    print('--------------------------------')
    print('Computing ROC-AUC score for the training dataset after training.')
    y_true, y_scores = [], []
    num_batches = int(ceil(len(dataset) / config['batch_size']))
    with torch.no_grad():
        for (idx, batch) in enumerate(loader):
            edges, features, node_layers, mappings, rows, labels = batch
            features, labels = features.to(device), labels.to(device)
            out = model(features, node_layers, mappings, rows)
            all_pairs = torch.mm(out, out.t())
            scores = all_pairs[edges.T]
            y_true.extend(labels.detach().numpy())
            y_scores.extend(scores.detach().numpy())
            print('    Batch {} / {}'.format(idx+1, num_batches))
    y_true = np.array(y_true).flatten()
    y_scores = np.array(y_scores).flatten()
    area = roc_auc_score(y_true, y_scores)
    print('ROC-AUC score: {:.4f}'.format(area))
    print('--------------------------------')
# Out:
# --------------------------------
# Computing ROC-AUC score for the training dataset after training.
#     Batch 1 / 41
#     Batch 2 / 41
#     Batch 3 / 41
#     Batch 4 / 41
#     Batch 5 / 41
#     Batch 6 / 41
#     Batch 7 / 41
#     Batch 8 / 41
#     Batch 9 / 41
#     Batch 10 / 41
#     Batch 11 / 41
#     Batch 12 / 41
#     Batch 13 / 41
#     Batch 14 / 41
#     Batch 15 / 41
#     Batch 16 / 41
#     Batch 17 / 41
#     Batch 18 / 41
#     Batch 19 / 41
#     Batch 20 / 41
#     Batch 21 / 41
#     Batch 22 / 41
#     Batch 23 / 41
#     Batch 24 / 41
#     Batch 25 / 41
#     Batch 26 / 41
#     Batch 27 / 41
#     Batch 28 / 41
#     Batch 29 / 41
#     Batch 30 / 41
#     Batch 31 / 41
#     Batch 32 / 41
#     Batch 33 / 41
#     Batch 34 / 41
#     Batch 35 / 41
#     Batch 36 / 41
#     Batch 37 / 41
#     Batch 38 / 41
#     Batch 39 / 41
#     Batch 40 / 41
#     Batch 41 / 41
# ROC-AUC score: 0.9909
# --------------------------------

# %% [markdown]
# # Plot the true positive rate and true negative rate vs threshold.

# %%
if not config['load']:
    tpr, fpr, thresholds = roc_curve(y_true, y_scores)
    tnr = 1 - fpr
    plt.plot(thresholds, tpr, label='tpr')
    plt.plot(thresholds, tnr, label='tnr')
    plt.xlabel('Threshold')
    plt.title('TPR / TNR vs Threshold')
    plt.legend()

# %% [markdown]
# # Choose an appropriate threshold and generate classification report on the train set.

# %%
idx1 = np.where(tpr <= tnr)[0]
idx2 = np.where(tpr >= tnr)[0]
t = thresholds[idx1[-1]]
total_correct, total_examples = 0, 0
y_true, y_pred = [], []
num_batches = int(ceil(len(dataset) / config['batch_size']))
with torch.no_grad():
    for (idx, batch) in enumerate(loader):
        edges, features, node_layers, mappings, rows, labels = batch
        features, labels = features.to(device), labels.to(device)
        out = model(features, node_layers, mappings, rows)
        all_pairs = torch.mm(out, out.t())
        scores = all_pairs[edges.T]
        predictions = (scores >= t).long()
        y_true.extend(labels.detach().numpy())
        y_pred.extend(predictions.detach().numpy())
        total_correct += torch.sum(predictions == labels.long()).item()
        total_examples += len(labels) 
        print('    Batch {} / {}'.format(idx+1, num_batches))
print('Threshold: {:.4f}, accuracy: {:.4f}'.format(t, total_correct / total_examples))
y_true = np.array(y_true).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
print('Classification report\n', report)
# Out:
#     Batch 1 / 41
#     Batch 2 / 41
#     Batch 3 / 41
#     Batch 4 / 41
#     Batch 5 / 41
#     Batch 6 / 41
#     Batch 7 / 41
#     Batch 8 / 41
#     Batch 9 / 41
#     Batch 10 / 41
#     Batch 11 / 41
#     Batch 12 / 41
#     Batch 13 / 41
#     Batch 14 / 41
#     Batch 15 / 41
#     Batch 16 / 41
#     Batch 17 / 41
#     Batch 18 / 41
#     Batch 19 / 41
#     Batch 20 / 41
#     Batch 21 / 41
#     Batch 22 / 41
#     Batch 23 / 41
#     Batch 24 / 41
#     Batch 25 / 41
#     Batch 26 / 41
#     Batch 27 / 41
#     Batch 28 / 41
#     Batch 29 / 41
#     Batch 30 / 41
#     Batch 31 / 41
#     Batch 32 / 41
#     Batch 33 / 41
#     Batch 34 / 41
#     Batch 35 / 41
#     Batch 36 / 41
#     Batch 37 / 41
#     Batch 38 / 41
#     Batch 39 / 41
#     Batch 40 / 41
#     Batch 41 / 41
# Threshold: 1.2812, accuracy: 0.9628
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96       645
#          1.0       0.96      0.96      0.96       645
#
#     accuracy                           0.96      1290
#    macro avg       0.96      0.96      0.96      1290
# weighted avg       0.96      0.96      0.96      1290

# %% [markdown]
# # Evaluate on validation set.

# %%
if config['load']:
    directory = os.path.join(os.path.dirname(os.getcwd()),
                             'trained_models')
    fname = utils.get_fname(config)
    path = os.path.join(directory, fname)
    model.load_state_dict(torch.load(path))
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'val',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=False, collate_fn=dataset.collate_wrapper)
criterion = utils.get_criterion(config['task'])
stats_per_batch = config['stats_per_batch']
num_batches = int(ceil(len(dataset) / config['batch_size']))
model.eval()
print('--------------------------------')
print('Computing ROC-AUC score for the validation dataset after training.')
running_loss, total_loss = 0.0, 0.0
num_correct, num_examples = 0, 0
total_correct, total_examples = 0, 0
y_true, y_scores, y_pred = [], [], []
for (idx, batch) in enumerate(loader):
    edges, features, node_layers, mappings, rows, labels = batch
    features, labels = features.to(device), labels.to(device)
    out = model(features, node_layers, mappings, rows)
    all_pairs = torch.mm(out, out.t())
    scores = all_pairs[edges.T]
    loss = criterion(scores, labels.float())
    running_loss += loss.item()
    total_loss += loss.item()
    predictions = (scores >= t).long()
    num_correct += torch.sum(predictions == labels.long()).item()
    total_correct += torch.sum(predictions == labels.long()).item()
    num_examples += len(labels)
    total_examples += len(labels)
    y_true.extend(labels.detach().numpy())
    y_scores.extend(scores.detach().numpy())
    y_pred.extend(predictions.detach().numpy())
    if (idx + 1) % stats_per_batch == 0:
        running_loss /= stats_per_batch
        accuracy = num_correct / num_examples
        print('    Batch {} / {}: loss {:.4f}, accuracy {:.4f}'.format(
            idx+1, num_batches, running_loss, accuracy))
        if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
            area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
            print('    ROC-AUC score: {:.4f}'.format(area))
        running_loss = 0.0
        num_correct, num_examples = 0, 0
total_loss /= num_batches
total_accuracy = total_correct / total_examples
print('Loss {:.4f}, accuracy {:.4f}'.format(total_loss, total_accuracy))
y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
area = roc_auc_score(y_true, y_scores)
print('ROC-AUC score: {:.4f}'.format(area))
print('Classification report\n', report)
print('Finished validating.')
print('--------------------------------')
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contact/ia-contact.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: val
# Number of vertices: 274
# Number of static edges: 2112
# Number of temporal edges: 14122
# Number of examples/datapoints: 1204
# --------------------------------
# --------------------------------
# Computing ROC-AUC score for the validation dataset after training.
#     Batch 3 / 38: loss 1.0424, accuracy 0.7292
#     ROC-AUC score: 0.7188
#     Batch 6 / 38: loss 0.6341, accuracy 0.7917
#     ROC-AUC score: 0.8627
#     Batch 9 / 38: loss 0.9407, accuracy 0.7917
#     ROC-AUC score: 0.7222
#     Batch 12 / 38: loss 0.7041, accuracy 0.8542
#     ROC-AUC score: 0.7579
#     Batch 15 / 38: loss 0.6897, accuracy 0.8021
#     ROC-AUC score: 0.9292
#     Batch 18 / 38: loss 0.6992, accuracy 0.8438
#     ROC-AUC score: 0.9020
#     Batch 21 / 38: loss 0.7693, accuracy 0.8021
#     ROC-AUC score: 0.8016
#     Batch 24 / 38: loss 0.6829, accuracy 0.8542
#     ROC-AUC score: 0.8704
#     Batch 27 / 38: loss 0.8356, accuracy 0.8125
#     ROC-AUC score: 0.7778
#     Batch 30 / 38: loss 0.6865, accuracy 0.8229
#     ROC-AUC score: 0.8658
#     Batch 33 / 38: loss 0.7831, accuracy 0.8438
#     ROC-AUC score: 0.8320
#     Batch 36 / 38: loss 0.8211, accuracy 0.8021
#     ROC-AUC score: 0.8633
# Loss 0.7646, accuracy 0.8140
# ROC-AUC score: 0.8109
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.83      0.82       602
#          1.0       0.83      0.80      0.81       602
#
#     accuracy                           0.81      1204
#    macro avg       0.81      0.81      0.81      1204
# weighted avg       0.81      0.81      0.81      1204
#
# Finished validating.
# --------------------------------

# %% [markdown]
# # Evaluate on test set.

# %%
if config['load']:
    directory = os.path.join(os.path.dirname(os.getcwd()),
                             'trained_models')
    fname = utils.get_fname(config)
    path = os.path.join(directory, fname)
    model.load_state_dict(torch.load(path))
dataset_args = (config['task'], config['dataset'], config['dataset_path'],
                config['generate_neg_examples'], 'test',
                config['duplicate_examples'], config['repeat_examples'],
                config['num_layers'], config['self_loop'],
                config['normalize_adj'])
dataset = utils.get_dataset(dataset_args)
loader = DataLoader(dataset=dataset, batch_size=config['batch_size'],
                    shuffle=False, collate_fn=dataset.collate_wrapper)
criterion = utils.get_criterion(config['task'])
stats_per_batch = config['stats_per_batch']
num_batches = int(ceil(len(dataset) / config['batch_size']))
model.eval()
print('--------------------------------')
print('Computing ROC-AUC score for the test dataset after training.')
running_loss, total_loss = 0.0, 0.0
num_correct, num_examples = 0, 0
total_correct, total_examples = 0, 0
y_true, y_scores, y_pred = [], [], []
for (idx, batch) in enumerate(loader):
    edges, features, node_layers, mappings, rows, labels = batch
    features, labels = features.to(device), labels.to(device)
    out = model(features, node_layers, mappings, rows)
    all_pairs = torch.mm(out, out.t())
    scores = all_pairs[edges.T]
    loss = criterion(scores, labels.float())
    running_loss += loss.item()
    total_loss += loss.item()
    predictions = (scores >= t).long()
    num_correct += torch.sum(predictions == labels.long()).item()
    total_correct += torch.sum(predictions == labels.long()).item()
    num_examples += len(labels)
    total_examples += len(labels)
    y_true.extend(labels.detach().numpy())
    y_scores.extend(scores.detach().numpy())
    y_pred.extend(predictions.detach().numpy())
    if (idx + 1) % stats_per_batch == 0:
        running_loss /= stats_per_batch
        accuracy = num_correct / num_examples
        print('    Batch {} / {}: loss {:.4f}, accuracy {:.4f}'.format(
            idx+1, num_batches, running_loss, accuracy))
        if (torch.sum(labels.long() == 0).item() > 0) and (torch.sum(labels.long() == 1).item() > 0):
            area = roc_auc_score(labels.detach().numpy(), scores.detach().numpy())
            print('    ROC-AUC score: {:.4f}'.format(area))
        running_loss = 0.0
        num_correct, num_examples = 0, 0
total_loss /= num_batches
total_accuracy = total_correct / total_examples
print('Loss {:.4f}, accuracy {:.4f}'.format(total_loss, total_accuracy))
y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()
y_pred = np.array(y_pred).flatten()
report = classification_report(y_true, y_pred)
area = roc_auc_score(y_true, y_scores)
print('ROC-AUC score: {:.4f}'.format(area))
print('Classification report\n', report)
print('Finished testing.')
print('--------------------------------')
# Out:
# --------------------------------
# Reading dataset from /Users/raunak/Documents/Datasets/temporal-networks-network-repository/ia-contact/ia-contact.edges
# Finished reading data.
# Setting up graph.
# Finished setting up graph.
# Setting up examples.
# Finished setting up examples.
# Dataset properties:
# Mode: test
# Number of vertices: 274
# Number of static edges: 2472
# Number of temporal edges: 21183
# Number of examples/datapoints: 1348
# --------------------------------
# --------------------------------
# Computing ROC-AUC score for the test dataset after training.
#     Batch 3 / 43: loss 0.8300, accuracy 0.7083
#     ROC-AUC score: 0.7835
#     Batch 6 / 43: loss 0.5856, accuracy 0.7604
#     ROC-AUC score: 0.7273
#     Batch 9 / 43: loss 0.8842, accuracy 0.7396
#     ROC-AUC score: 0.7227
#     Batch 12 / 43: loss 0.8776, accuracy 0.7500
#     ROC-AUC score: 0.7569
#     Batch 15 / 43: loss 0.7183, accuracy 0.7812
#     ROC-AUC score: 0.7882
#     Batch 18 / 43: loss 0.8936, accuracy 0.8021
#     ROC-AUC score: 0.8745
#     Batch 21 / 43: loss 1.0726, accuracy 0.7500
#     ROC-AUC score: 0.7222
#     Batch 24 / 43: loss 0.8772, accuracy 0.7708
#     ROC-AUC score: 0.7449
#     Batch 27 / 43: loss 0.7411, accuracy 0.7917
#     ROC-AUC score: 0.7422
#     Batch 30 / 43: loss 0.8258, accuracy 0.7292
#     ROC-AUC score: 0.7266
#     Batch 33 / 43: loss 0.9703, accuracy 0.7708
#     ROC-AUC score: 0.6758
#     Batch 36 / 43: loss 0.6041, accuracy 0.8021
#     ROC-AUC score: 0.8333
#     Batch 39 / 43: loss 1.0046, accuracy 0.7292
#     ROC-AUC score: 0.7765
#     Batch 42 / 43: loss 0.8696, accuracy 0.7500
#     ROC-AUC score: 0.7148
# Loss 0.8306, accuracy 0.7596
# ROC-AUC score: 0.7668
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.74      0.79      0.77       674
#          1.0       0.78      0.73      0.75       674
#
#     accuracy                           0.76      1348
#    macro avg       0.76      0.76      0.76      1348
# weighted avg       0.76      0.76      0.76      1348
#
# Finished testing.
# --------------------------------
